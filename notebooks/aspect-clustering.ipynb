# %%
import pandas as pd
import numpy as np
import json

# %%
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))

# %%
from gensim.models import Word2Vec

# %%
absa_data = pd.read_json('../data/absa-result.json')

# %%
absa_data
# Out:
#                                                sentence  \
# 0     I had a wonderful experience at Jonat Hotel Th...
# 1     I enjoyed my stay here For a serene environmen...
# 2     The couple of times I have been there were ver...
# 3     Everything there was nice and super clean thum...
# 4     I had a splendid stay at Jonat Hotel It might ...
# ...                                                 ...
# 3673                      Enjoy their music on weekends
# 3674  It very attractive Nice and i really love this...
# 3675                          Nice place with good view
# 3676                                   Nice place to be
# 3677  They have good facilities and a wonderful view...
#
#                                                     IOB  \
# 0     [O, O, O, O, O, O, O, O, O, B-ASP, O, O, O, O,...
# 1          [O, O, O, B-ASP, O, O, O, O, B-ASP, O, O, O]
# 2     [O, O, O, O, O, O, O, O, O, O, O, B-ASP, O, O,...
# 3     [O, O, O, O, O, O, O, B-ASP, I-ASP, I-ASP, O, ...
# 4     [O, O, O, O, B-ASP, O, O, O, O, O, O, O, O, O,...
# ...                                                 ...
# 3673                                [O, O, B-ASP, O, O]
# 3674                 [O, O, O, O, O, O, O, O, O, B-ASP]
# 3675                            [O, B-ASP, O, O, B-ASP]
# 3676                                   [O, B-ASP, O, O]
# 3677   [O, O, O, B-ASP, O, O, O, B-ASP, I-ASP, O, O, O]
#
#                                                  tokens  \
# 0     [I, had, a, wonderful, experience, at, Jonat, ...
# 1     [I, enjoyed, my, stay, here, For, a, serene, e...
# 2     [The, couple, of, times, I, have, been, there,...
# 3     [Everything, there, was, nice, and, super, cle...
# 4     [I, had, a, splendid, stay, at, Jonat, Hotel, ...
# ...                                                 ...
# 3673                [Enjoy, their, music, on, weekends]
# 3674  [It, very, attractive, Nice, and, i, really, l...
# 3675                    [Nice, place, with, good, view]
# 3676                              [Nice, place, to, be]
# 3677  [They, have, good, facilities, and, a, wonderf...
#
#                         aspect            position  \
# 0            [rooms, services]         [[9], [14]]
# 1          [stay, environment]          [[3], [8]]
# 2     [times, ambiance, rooms]  [[11], [21], [27]]
# 3          [thumbs _ upthumbs]         [[7, 8, 9]]
# 4        [stay, service, food]   [[4], [14], [20]]
# ...                        ...                 ...
# 3673                   [music]               [[2]]
# 3674                   [place]               [[9]]
# 3675             [place, view]          [[1], [4]]
# 3676                   [place]               [[1]]
# 3677     [facilities, view of]       [[3], [7, 8]]
#
#                            sentiment  \
# 0               [Positive, Positive]
# 1               [Positive, Positive]
# 2     [Positive, Positive, Positive]
# 3                         [Positive]
# 4     [Positive, Positive, Positive]
# ...                              ...
# 3673                      [Positive]
# 3674                      [Positive]
# 3675            [Positive, Positive]
# 3676                      [Positive]
# 3677            [Positive, Positive]
#
#                                                   probs  \
# 0     [[0.000128242201753, 0.001082240254618, 0.9987...
# 1     [[0.000272165372734, 0.00027510660584, 0.99945...
# 2     [[0.0010324807371940002, 0.000496298074722, 0....
# 3     [[0.000327858200762, 0.000272918812697, 0.9993...
# 4     [[0.00045543559826900006, 0.000300917774438000...
# ...                                                 ...
# 3673  [[0.000182744232006, 0.00030094798421400004, 0...
# 3674  [[0.000340952858095, 0.00020609609782600003, 0...
# 3675  [[0.00023386089014800003, 0.000251896592089, 0...
# 3676  [[0.000200089925783, 0.000286172027699, 0.9995...
# 3677  [[0.000385794643079, 0.000277445302344, 0.9993...
#
#                                              confidence
# 0                                      [0.9988, 0.9995]
# 1                          [0.9995, 0.9994000000000001]
# 2                   [0.9985, 0.9992000000000001, 0.999]
# 3                                  [0.9994000000000001]
# 4     [0.9992000000000001, 0.9993000000000001, 0.999...
# ...                                                 ...
# 3673                                           [0.9995]
# 3674                                           [0.9995]
# 3675                                   [0.9995, 0.9995]
# 3676                                           [0.9995]
# 3677                       [0.9993000000000001, 0.9996]
#
# [3678 rows x 8 columns]

# %%
aspect_column = absa_data['aspect']
aspects =  []
for item in aspect_column:
    aspects.extend(item)

# %% [markdown]
# Training Word2Vec Model

# %%
import modules.text_processor as text_prep

# %%
sent = ["I love this dress so much", "I hate that show fom the depth of my heart"]
new_sent = text_prep.bigram_tokenizer(sent)

# %%
new_sent
# Out:
# [['I love', 'love dress', 'dress much'],
#  ['I hate', 'hate show', 'show fom', 'fom depth', 'depth heart']]

# %%
text_prep.bigram_tokenizer(sent)
# Out:
# [['I love', 'love dress', 'dress much'],
#  ['I hate', 'hate show', 'show fom', 'fom depth', 'depth heart']]

# %%
reviews = absa_data['sentence']

# %%
reviews_list = reviews.tolist()

# %%
unigram_data = text_prep.unigram_tokenizer(reviews_list)

# %%
bigram_data = text_prep.bigram_tokenizer(reviews_list)

# %%
unigram_data
# Out:
# [['I',
#   'wonderful',
#   'experience',
#   'Jonat',
#   'Hotel',
#   'Their',
#   'room',
#   'new',
#   'service',
#   'top',
#   'notch',
#   'I',
#   'definitely',
#   'recommend',
#   'anyone',
#   'visiting',
#   'Cape',
#   'Coast',
#   'folded',
#   '_',
#   'hand',
#   '_',
#   'dark',
#   '_',
#   'skin',
#   '_',
#   'tone'],
#  ['I',
#   'enjoyed',
#   'stay',
#   'For',
#   'serene',
#   'environment',
#   'choose',
#   'Jonat',
#   'Hotel'],
#  ['The',
#   'couple',
#   'time',
#   'I',
#   'peaceful',
#   'time',
#   'I',
#   'really',
#   'enjoyed',
#   'serenity',
#   'calm',
#   'ambiance',
#   'place',
#   'Really',
#   'nice',
#   'room',
#   'affordable',
#   'well'],
#  ['Everything',
#   'nice',
#   'super',
#   'clean',
#   'thumb',
#   '_',
#   'upthumbs',
#   '_',
#   'upthumbs',
#   '_'],
#  ['I',
#   'splendid',
#   'stay',
#   'Jonat',
#   'Hotel',
#   'It',
#   'might',
#   'new',
#   'service',
#   'great',
#   'food',
#   'delish'],
#  ['Staff',
#   'provide',
#   'warm',
#   'reception',
#   'neat',
#   'room',
#   'room',
#   'service',
#   'available'],
#  ['It',
#   'nice',
#   'place',
#   'stay',
#   'Pretty',
#   'clean',
#   'price',
#   'room',
#   'great',
#   'They',
#   'also',
#   'serve',
#   'everyone',
#   'breakfast',
#   'plus'],
#  ['The',
#   'Drowaa',
#   'Plus',
#   'Hotel',
#   'go',
#   'place',
#   'stop',
#   'night',
#   'sleep',
#   'Great',
#   'design',
#   'room',
#   'great',
#   'ventilation',
#   'AC',
#   'Fan',
#   'room',
#   'etc',
#   'I',
#   'recommend',
#   'place',
#   'organizing',
#   'event',
#   'looking',
#   'great',
#   'place',
#   'lodge'],
#  ['Very', 'quite', 'location', 'Cape', 'Coast'],
#  ['In', 'town', 'around', 'IBB'],
#  ['The',
#   'room',
#   'beautiful',
#   'Elegant',
#   'design',
#   'But',
#   'washroom',
#   'poor',
#   'condition',
#   'And',
#   'poor',
#   'customer',
#   'service'],
#  ['drink',
#   'pub',
#   'place',
#   'hold',
#   'sentimental',
#   'value',
#   'well',
#   'old',
#   'junior',
#   'high',
#   'half',
#   'kilometre',
#   'away',
#   'friendly',
#   'accommodating',
#   'staff'],
#  ['Close', 'beach'],
#  ['Not',
#   'good',
#   'condition',
#   'moment',
#   'It',
#   'left',
#   'without',
#   'form',
#   'maintenance'],
#  ['Its', 'nice', 'place'],
#  ['This',
#   'great',
#   'establishment',
#   'striving',
#   'part',
#   'community',
#   'This',
#   'place',
#   'alll',
#   'type',
#   'loving',
#   'event',
#   'Thanks',
#   'everyone',
#   'community'],
#  ['We', 'spent', 'saturday', 'place', 'magic'],
#  ['Unique', 'conjunction', 'pristine', 'beach', 'good', 'food'],
#  ['Wonderfull', 'nothing', 'else'],
#  ['Situated',
#   'paradise',
#   'place',
#   'Very',
#   'quiet',
#   'beautiful',
#   'landscape',
#   'Access',
#   'easy',
#   'good',
#   'never',
#   'easy'],
#  ['Excellent',
#   'place',
#   'thumb',
#   '_',
#   'upbeaming',
#   '_',
#   'face',
#   '_',
#   '_',
#   'smiling',
#   '_',
#   'eye'],
#  ['Magnificent',
#   'place',
#   'comfortable',
#   'accommodation',
#   'taste',
#   'refined',
#   'kitchen',
#   'careful',
#   'welcome'],
#  ['Fantas',
#   'Folly',
#   'favourite',
#   'place',
#   'spend',
#   'relaxing',
#   'time',
#   'Philip',
#   'Fanta',
#   'wonderful',
#   'host',
#   'always',
#   'spend',
#   'time',
#   'make',
#   'feel',
#   'welcome',
#   'The',
#   'food',
#   'great',
#   'good',
#   'value',
#   'money',
#   'The',
#   'room',
#   'comfortable',
#   'well',
#   'thought',
#   'The',
#   'location',
#   'piece',
#   'Paradise',
#   'Earth',
#   'We',
#   'lot',
#   'wonderful',
#   'memory',
#   'time',
#   'spent',
#   'Fantas',
#   'Highly',
#   'recommended'],
#  ['No', 'wish', 'remains', 'unfulfilled', 'A', 'little', 'paradise', 'earth'],
#  ['Very',
#   'poor',
#   'service',
#   'I',
#   'received',
#   'fantas',
#   'folly',
#   'Food',
#   'took',
#   '2',
#   'hour',
#   'waiter',
#   'smart',
#   'They',
#   'could',
#   'even',
#   'recommend',
#   'listed',
#   'food',
#   'menu',
#   'best',
#   'one',
#   'waitress',
#   'mentioned',
#   'recommend',
#   'allowed',
#   'Their',
#   'appearance',
#   'also',
#   'Imagine',
#   'going',
#   'long',
#   'journey',
#   'given',
#   'poor',
#   'service',
#   'heart',
#   'breaking'],
#  ['This',
#   'worse',
#   'place',
#   'I',
#   'ever',
#   'They',
#   'rude',
#   'service',
#   'bad',
#   'The',
#   'owner',
#   'wife',
#   'wanted',
#   'fight',
#   'costumer',
#   'never',
#   'go',
#   'want',
#   'good',
#   'time'],
#  ['An',
#   'idyllic',
#   'place',
#   'European',
#   'cuisine',
#   'unfortunately',
#   'difficult',
#   'achieve',
#   'Use',
#   'road',
#   'car',
#   'possible'],
#  ['Nice',
#   'place',
#   'quiet',
#   'peaceful',
#   'amazing',
#   'view',
#   'The',
#   'minus',
#   'water',
#   'shower',
#   'tap',
#   'clean',
#   'used',
#   'big',
#   'minus'],
#  ['This',
#   'best',
#   'get',
#   'away',
#   'hectic',
#   'traffic',
#   'busyness',
#   'dirty',
#   'beach',
#   'Accra',
#   'Though',
#   'said',
#   'road',
#   'lead',
#   'heaven',
#   'narrow',
#   'get',
#   'ready',
#   'narrow',
#   'drive',
#   'haha',
#   'worth',
#   'end',
#   'Clean',
#   'environment',
#   'good',
#   'group',
#   'good',
#   'couple',
#   'spend',
#   'quality',
#   'time',
#   'together',
#   'Good',
#   'family',
#   'vacation',
#   'good',
#   'kid',
#   'good',
#   'long',
#   'walk',
#   'beach',
#   'I',
#   'strongly',
#   'recommend'],
#  ['Very', 'nice', 'beach'],
#  ['Amazing', 'stay', 'mouth', 'watering', 'food'],
#  ['Great',
#   'food',
#   'beach',
#   'relaxing',
#   'Awesome',
#   'place',
#   'getaway',
#   'road',
#   'bumpy',
#   'prepared',
#   'going',
#   'definitely',
#   'gem',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   '_',
#   'hearteyes',
#   'OK',
#   '_',
#   'hand',
#   'dark',
#   '_',
#   'skin',
#   '_',
#   'tone'],
#  ['The',
#   'worst',
#   'ever',
#   'customer',
#   'service',
#   'I',
#   'ever',
#   'experienced',
#   'I',
#   'checked',
#   'ordered',
#   'two',
#   'meal',
#   'wife',
#   'surprised',
#   'bottle',
#   'wine',
#   'I',
#   'requested',
#   'glass',
#   'brought',
#   'manager',
#   'owner',
#   'came',
#   'request',
#   '29ghs',
#   'bringing',
#   'wine',
#   'guest',
#   'accommodated',
#   'I',
#   'objected',
#   'poured',
#   'wine',
#   'glass',
#   'away',
#   'took',
#   'glass',
#   'And',
#   'told',
#   'check',
#   'leave',
#   'I',
#   'want',
#   'I'],
#  ['Best',
#   'beach',
#   'resort',
#   'takoradi',
#   'clean',
#   'beach',
#   'helpful',
#   'personal'],
#  ['A',
#   'peaceful',
#   'surrounded',
#   'overloaded',
#   'package',
#   'nature',
#   'tree',
#   'bird',
#   'sky',
#   'sun',
#   'moon',
#   'star',
#   'course',
#   'ocean',
#   'Amazing',
#   'Thank',
#   'Fanta',
#   'Philippe',
#   'Janet',
#   'Chef',
#   'Deborah',
#   'Ebo',
#   'whole',
#   'team',
#   'You',
#   'make',
#   'Fantas',
#   'Folly',
#   'living',
#   'I',
#   'coming',
#   'back'],
#  ['Great', 'meal', 'peaceful', 'atmosphere'],
#  ['Paradise', 'earth', 'road', 'difficult'],
#  ['Warm',
#   'reception',
#   'Philip',
#   'team',
#   'Always',
#   'ready',
#   'listen',
#   'serve',
#   'guest',
#   'well',
#   'For',
#   'meal',
#   'love'],
#  ['One',
#   'Cleanest',
#   'Beaches',
#   'beach',
#   '_',
#   '_',
#   'umbrella',
#   'Great',
#   'food',
#   'fresh',
#   'sea',
#   'water',
#   '_',
#   'wave',
#   'Ambiance',
#   'TOP',
#   '_',
#   'arrow',
#   'notch',
#   'Moderate',
#   'pricing'],
#  ['Really', 'nice', 'Proprio', 'Franc', 'Comtois', 'Heavenly', 'beach'],
#  ['An', 'amazing', 'place', 'weekend', 'getaway'],
#  ['An',
#   'fantastic',
#   'place',
#   'serene',
#   'atmosphere',
#   'located',
#   'right',
#   'Butre',
#   'beach',
#   'It',
#   'perfect',
#   'place',
#   'calm',
#   'enjoy',
#   'The',
#   'resort',
#   'built',
#   'great',
#   'sense',
#   'design',
#   'atmosphere',
#   'nice',
#   'couple',
#   'taking',
#   'good',
#   'care',
#   'I',
#   'really',
#   'loved',
#   'place',
#   'The',
#   'bad',
#   'thing',
#   'internet',
#   'connection',
#   'weak',
#   'depending',
#   'internet',
#   'perfect',
#   'place'],
#  ['Nestled',
#   'among',
#   'tropical',
#   'vegetation',
#   'sound',
#   'Atlantic',
#   'Ocean',
#   'rolling',
#   'shore',
#   'feel',
#   'far',
#   'away',
#   'hustle',
#   'bustle',
#   'yet',
#   'le',
#   'hour',
#   'drive',
#   'city',
#   'Takoradi',
#   'Caution',
#   'Road',
#   'rough',
#   'Consider',
#   'Pick',
#   'van',
#   'Beautiful',
#   'sea',
#   'beach',
#   'photogenic',
#   'view',
#   'Clean',
#   'area',
#   'water',
#   'The',
#   'beauty',
#   'place',
#   'small',
#   'rocky',
#   'mountain',
#   'mountain',
#   'walk',
#   '3',
#   '4',
#   'minute',
#   'click',
#   'picture',
#   'video',
#   'Adding',
#   'picture',
#   'water',
#   'green',
#   'grey',
#   'yellow',
#   'lol',
#   'mix',
#   'colour',
#   'Make',
#   'sure',
#   'order',
#   'food',
#   'advance',
#   'take',
#   '2',
#   'hour',
#   'saying',
#   '5',
#   'minute',
#   'I',
#   'omelette',
#   'bread',
#   'waited',
#   '1',
#   'one',
#   'hour'],
#  ['An',
#   'excellent',
#   'hideaway',
#   'vacation',
#   'spot',
#   'couple',
#   'want',
#   'get',
#   'away',
#   'busy',
#   'city',
#   'atmosphere',
#   'A',
#   'serene',
#   'area',
#   'beautiful',
#   'beach',
#   'The',
#   'food',
#   'great',
#   'take',
#   'long',
#   'time',
#   'prepare',
#   'I',
#   'recommend',
#   'ordering',
#   'early',
#   'enough',
#   'disappointed',
#   'One',
#   'need',
#   'note',
#   'however',
#   'resort',
#   'far',
#   'away',
#   'main',
#   'road',
#   'The',
#   'road',
#   'generally',
#   'smooth',
#   'though',
#   'We',
#   'could',
#   'find',
#   'sign',
#   'main',
#   'junction',
#   'missed',
#   'turn',
#   'got',
#   'lost',
#   'Be',
#   'sure',
#   'ask',
#   'direction',
#   'You',
#   'spend',
#   '20',
#   '30',
#   'min',
#   'drive',
#   'main',
#   'road',
#   'dirt',
#   'road',
#   'get',
#   'resort',
#   'After',
#   'main',
#   'junction',
#   'sign',
#   'junction',
#   'find',
#   'way',
#   'I',
#   'recommend',
#   'resort',
#   'couple',
#   'want',
#   'quiet',
#   'low',
#   'key',
#   'affordable',
#   'vacation',
#   'Just',
#   'make',
#   'sure',
#   '4x4',
#   'face',
#   '_',
#   '_',
#   'tear',
#   '_',
#   '_',
#   'joy'],
#  ['Wonderful', 'experience', 'middle', 'nowhere'],
#  ['Always',
#   'one',
#   'fav',
#   'place',
#   'visit',
#   'Food',
#   'great',
#   'beach',
#   'always',
#   'clean',
#   'Rooms',
#   'affordable',
#   'clean'],
#  ['Serene',
#   'atmosphere',
#   'perfect',
#   'OK',
#   '_',
#   'hand',
#   '_',
#   'mediumdark',
#   '_',
#   'skin',
#   '_',
#   'tone',
#   'get',
#   'away',
#   'trip',
#   'wonderful',
#   'people',
#   'hotel',
#   'Love',
#   'place',
#   'Would',
#   'always',
#   'choose',
#   'place'],
#  ['It', 'serene', 'Atmosphere'],
#  ['Amazing',
#   'getaway',
#   'everyone',
#   'Beautiful',
#   'sunset',
#   'serene',
#   'atmosphere'],
#  ['Sure', 'wonderful', 'place', 'enjoy', 'breeze'],
#  ['To', 'honest', 'visited', 'place', 'find', 'time', 'go', 'relax'],
#  ['Perfect',
#   'value',
#   'money',
#   'Clean',
#   'room',
#   'AC',
#   'nice',
#   'guy',
#   'reception'],
#  ['Has', 'beautiful', 'view', 'estuary', 'service', 'facility', 'commendable'],
#  ['Good',
#   'atmosphere',
#   'great',
#   'environment',
#   'right',
#   'place',
#   'Ankobra',
#   'river',
#   'join',
#   'sea',
#   'good',
#   'service',
#   'There',
#   'room',
#   'improvement',
#   'however'],
#  ['A',
#   'wonderful',
#   'experience',
#   'Neat',
#   'environment',
#   'courteous',
#   'worker',
#   'food',
#   'A'],
#  ['Nice', 'serene', 'environment', 'relaxing'],
#  ['Loved',
#   'serene',
#   'atmosphere',
#   'Loved',
#   'waking',
#   'sound',
#   'rumbling',
#   'wave',
#   'Relaxing',
#   'max',
#   'Don',
#   'miss',
#   'sunset',
#   'sunrise',
#   'The',
#   'food',
#   'breakfast',
#   'dinner',
#   'superb',
#   'I',
#   'definitely'],
#  ['The',
#   'Beach',
#   'Ankobra',
#   'view',
#   'best',
#   'room',
#   'stay',
#   'privacy',
#   'leisure'],
#  ['Ankobra',
#   'Bridge',
#   'Hotel',
#   'amazing',
#   'place',
#   'Nice',
#   'facility',
#   'room',
#   'serene',
#   'environment',
#   'The',
#   'food',
#   'great',
#   'Rooms',
#   'range',
#   'Ghc200',
#   '400',
#   'Great',
#   'place',
#   'get',
#   'city',
#   'relax',
#   'It',
#   'great'],
#  ['Home', 'away', 'home'],
#  ['heart',
#   '_',
#   'exclamation',
#   'heart',
#   '_',
#   'exclamation',
#   'heart',
#   '_',
#   'exclamation',
#   'heart',
#   '_',
#   'exclamation',
#   'heart',
#   '_',
#   'exclamation',
#   'food',
#   'Room',
#   'mouth',
#   'mouth',
#   'mouth',
#   'mouth',
#   'mouth',
#   'mouth'],
#  ['Very', 'nice', 'place', 'relaxation'],
#  ['One', 'best', 'place', 'relax', 'western', 'part', 'Ghana'],
#  ['Great', 'experience'],
#  ['Excellent',
#   'amenity',
#   'room',
#   'smell',
#   'good',
#   'breakfast',
#   'top',
#   'notch',
#   'Will',
#   'recommend',
#   'hotel'],
#  ['Its',
#   'close',
#   'ankobra',
#   'River',
#   'calm',
#   'refreshing',
#   'staff',
#   'welcoming',
#   'friendly',
#   'food',
#   'great'],
#  ['Passed', 'briefly', 'Excellent', 'service', 'Good', 'location'],
#  ['Comfortable', 'friendly', 'staff'],
#  ['The', 'place', 'amazing', 'guy', 'got', 'ta', 'go'],
#  ['Nice', 'place', 'good', 'customer', 'service'],
#  ['Fantastic'],
#  ['Nice', 'ambiance'],
#  ['Nice', 'neat', 'new'],
#  ['Green',
#   'Zion',
#   'Garden',
#   'host',
#   'Ellis',
#   'left',
#   'imprint',
#   'heart',
#   'I',
#   'never',
#   'forget',
#   'Thank'],
#  ['Green',
#   'Zion',
#   'Garden',
#   'actual',
#   'paradise',
#   'The',
#   'various',
#   'little',
#   'large',
#   'room',
#   'like',
#   'natural',
#   'hobbit',
#   'house',
#   'No',
#   'Aircon',
#   'sure',
#   'fan',
#   'grand',
#   'There',
#   'tree',
#   'house',
#   'The',
#   'garden',
#   'immaculate',
#   'green',
#   'indeed',
#   'Beautiful',
#   'flower',
#   'plant',
#   'tree',
#   'There',
#   'bird',
#   'dragonfly',
#   'friendly',
#   'goat',
#   'couple',
#   'friendly',
#   'dog',
#   'It',
#   'right',
#   'beach',
#   'Ellis',
#   'beautifully',
#   'decorated',
#   'wooden',
#   'bar',
#   'He',
#   'feed',
#   'delicious',
#   'veggie',
#   'food',
#   'serve',
#   'tasty',
#   'drink',
#   'He',
#   'got',
#   'best',
#   'smile',
#   'growing',
#   '_',
#   'heartThere',
#   'seat',
#   'shaded',
#   'bed',
#   'ocean',
#   'The',
#   'beach',
#   'clean',
#   'rubbish',
#   'The',
#   'cleanest',
#   'I',
#   'seen',
#   'Ghana',
#   'I',
#   'stayed',
#   'longer',
#   'I',
#   'go',
#   'back',
#   'one',
#   'day',
#   'The',
#   'village',
#   'Butre',
#   'across',
#   'rickety',
#   'Indiana',
#   'Jones',
#   'style',
#   'bridge',
#   'bustling',
#   'lively',
#   'fishy',
#   'place',
#   'The',
#   'child',
#   'ran',
#   'fistbumps',
#   'hi',
#   'five',
#   'Goats',
#   'chicken',
#   'dog',
#   'everywhere',
#   'We',
#   'got',
#   'motorbike',
#   'Asa',
#   'Baako',
#   'Festival',
#   'Busua',
#   'walked',
#   'back',
#   'full',
#   'moon',
#   'illuminating',
#   'way',
#   'across',
#   'beach',
#   'headtorches',
#   'helping',
#   'path',
#   'bush',
#   'hilly',
#   'headland',
#   'bird',
#   'frog',
#   'insect',
#   'providing',
#   'soundtrack',
#   'A',
#   'magical',
#   'special',
#   'place',
#   'seems',
#   'growing',
#   'even',
#   'better',
#   'new',
#   'build',
#   'idea',
#   'Loved',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   '_',
#   'smiling',
#   '_',
#   'eye'],
#  ['I',
#   'crossed',
#   'rendomly',
#   'Green',
#   'garden',
#   'eco',
#   'lodge',
#   'I',
#   'trekking',
#   'coast',
#   'I',
#   'met',
#   'Ellis',
#   'positive',
#   'funny',
#   'man',
#   'We',
#   'ate',
#   'together',
#   'good',
#   'fun',
#   'He',
#   'show',
#   'lodge',
#   'clean',
#   'nice',
#   'place',
#   'The',
#   'garden',
#   'crazy',
#   'good',
#   'moment',
#   'vibe'],
#  ['Very',
#   'green',
#   'space',
#   'cool',
#   'environment',
#   'Great',
#   'gardening',
#   'eco',
#   'lodge',
#   'experience'],
#  ['They',
#   'OM',
#   'sign',
#   'outside',
#   'board',
#   'You',
#   'see',
#   'cat',
#   'around',
#   '10',
#   'minute',
#   'drive',
#   'fantas',
#   'folly',
#   'He',
#   'know',
#   'cook',
#   'indian',
#   'food',
#   'The',
#   'man',
#   'offer',
#   'everything',
#   'want',
#   'Posting',
#   'picture',
#   'review',
#   'Offering',
#   'free',
#   'private',
#   'parking',
#   'onsite',
#   'Green',
#   'Zion',
#   'Garden',
#   'offer',
#   'pet',
#   'friendly',
#   'accommodation',
#   'Butre',
#   'The',
#   'bed',
#   'breakfast',
#   'lawn',
#   'hammock',
#   'guest',
#   'located',
#   'garden',
#   'Guests',
#   'enjoy',
#   'meal',
#   'outside',
#   'garden',
#   'restaurant',
#   'serf',
#   'local',
#   'Indian',
#   'International',
#   'cuisine',
#   'The',
#   'property',
#   'onsite',
#   'bar',
#   'garden',
#   'also',
#   'coffee',
#   'shop',
#   'You',
#   'find',
#   'shared',
#   'lounge',
#   'property',
#   'Thai',
#   'yoga',
#   'massage',
#   'treatment',
#   'available'],
#  ['Paradise', 'Ghana'],
#  ['Wooow', 'special', 'place', 'incredible'],
#  ['I',
#   'almost',
#   'want',
#   'recommend',
#   'green',
#   'zion',
#   'garden',
#   'Hidden',
#   'gem',
#   'Moreover',
#   'Ellis',
#   'host',
#   'honestly',
#   'best',
#   'Guy',
#   'met',
#   'Ghana',
#   'If',
#   'want',
#   'best',
#   'round',
#   'experience',
#   'Ghana',
#   'visit',
#   'Ellis',
#   'place',
#   'welcome',
#   'Zion',
#   'garden'],
#  ['Affable',
#   'owner',
#   'good',
#   'food',
#   'great',
#   'relax',
#   'All',
#   'sited',
#   'beautiful',
#   'skilfully',
#   'elaborated',
#   'garden',
#   'Will',
#   'come'],
#  ['A',
#   'place',
#   'amazing',
#   'garden',
#   'Ellis',
#   'great',
#   'job',
#   'care',
#   'guest',
#   'good',
#   'food',
#   'clean',
#   'room'],
#  ['Amazing', 'place', 'butre'],
#  ['Super',
#   'lovely',
#   'place',
#   'Set',
#   'serene',
#   'beautiful',
#   'ambiance',
#   'one',
#   'Ghana',
#   'beautiful',
#   'coastline',
#   'Green',
#   'Zion',
#   'Garden',
#   'perfect',
#   'location',
#   'good',
#   'relaxation',
#   'good',
#   'peaceful',
#   'unwinding',
#   'My',
#   'host',
#   'Ellis',
#   'super',
#   'amazing',
#   'A',
#   'super',
#   'friendly',
#   'hardworking',
#   'open',
#   'minded',
#   'gentle',
#   'rasta',
#   'man',
#   'His',
#   'vegetarian',
#   'cooking',
#   'top',
#   'notch',
#   'His',
#   'knowledge',
#   'sharing',
#   'experience',
#   'great',
#   'He',
#   'prepared',
#   'bonfire',
#   'kind',
#   'good',
#   'drummer',
#   'pretty',
#   'please',
#   'let',
#   'sing',
#   'The',
#   'various',
#   'lodge',
#   'dormitory',
#   'upper',
#   'deck',
#   'tree',
#   'house',
#   'neat',
#   'lovely',
#   'awash',
#   'beautiful',
#   'color',
#   'traditional',
#   'fabric',
#   'Bonus',
#   'request',
#   'coconut',
#   'get',
#   'fresh',
#   'one',
#   'cut',
#   'tree',
#   'right',
#   'face',
#   'I',
#   'sure'],
#  ['We',
#   'passed',
#   'dinner',
#   '06',
#   '2018',
#   'atmosphere',
#   'restaurant',
#   'lounge',
#   'indescribable',
#   'After',
#   'fantastic',
#   'food',
#   'grabbed',
#   'Djembe',
#   'guitar',
#   'sang',
#   'together',
#   'host',
#   'moonlight',
#   'garden',
#   'late',
#   'night',
#   'Nice',
#   'place',
#   'An',
#   'unforgettable',
#   'evening'],
#  ['Green',
#   'zion',
#   'garden',
#   'offer',
#   'nice',
#   'stay',
#   'great',
#   'garden',
#   'djungle',
#   'feeling',
#   'friendly',
#   'host',
#   'gladly',
#   'show',
#   'around',
#   'area',
#   'Pancakes',
#   'recommended'],
#  ['A',
#   'friend',
#   'wedding',
#   'refreshment',
#   'held',
#   'venue',
#   'Warm',
#   'reception',
#   'given',
#   'u'],
#  ['Very',
#   'fun',
#   'see',
#   'distance',
#   'Agartha',
#   'Overlords',
#   'Da',
#   'God',
#   'Squad'],
#  ['The',
#   'customer',
#   'service',
#   'excellent',
#   'worker',
#   'friendly',
#   'give',
#   'wonderful',
#   'reception',
#   'room',
#   'clean',
#   'I',
#   'lodge'],
#  ['It', 'best', 'Spend', 'night', 'love', 'It', 'great'],
#  ['A', 'great', 'place'],
#  ['Good', 'environment'],
#  ['The',
#   'pool',
#   'side',
#   'spacious',
#   'parking',
#   'space',
#   'say',
#   'reception',
#   'security',
#   'give',
#   'entry',
#   'premise',
#   'say'],
#  ['Nice', 'hotel', 'An', 'ok', 'rest', 'place'],
#  ['The', 'hotel', 'nice', 'beautiful', 'I', 'always', 'recommend', 'anyone'],
#  ['Is', 'nice', 'plce', 'bushy', 'area'],
#  ['Very', 'cool', 'environment'],
#  ['Simply', 'home', 'away', 'home'],
#  ['Love', 'hotel'],
#  ['Very',
#   'hospitable',
#   'staff',
#   'helpful',
#   'improve',
#   'restaurant',
#   'service'],
#  ['Most',
#   'quiet',
#   'perfect',
#   'place',
#   'stay',
#   'away',
#   'busy',
#   'street',
#   'tadi'],
#  ['Nice', 'place', 'rest'],
#  ['Good', 'service'],
#  ['Nice', 'cheap', 'place', 'kindly', 'team'],
#  ['It', 'cool', 'place', 'great', 'view', 'Very', 'serene'],
#  ['Very', 'nice', 'affordable', 'place', 'visit'],
#  ['Great', 'place'],
#  ['The',
#   'amenity',
#   'room',
#   'poolside',
#   'restaurant',
#   'etc',
#   'world',
#   'class',
#   'Their',
#   'meal',
#   'equally',
#   'tasty',
#   'cost',
#   'Ghc100',
#   '9',
#   '10',
#   'They',
#   'amiable',
#   'staff'],
#  ['The',
#   'experience',
#   'Alliance',
#   'super',
#   'good',
#   'OK',
#   '_',
#   'hand',
#   'beautiful',
#   'environment',
#   'service',
#   'importantly',
#   'staff',
#   'To',
#   'mention',
#   'Hnel',
#   '5',
#   'star',
#   'manager',
#   'sense',
#   'humour',
#   'HUMILITY',
#   'Samuel',
#   'ever',
#   'smiling',
#   'dude',
#   'service',
#   'etc',
#   'Kafui',
#   'Front',
#   'Desk',
#   'personnel',
#   'swag',
#   'Jacqueline',
#   'calm',
#   'wonderful',
#   'person',
#   'ensuring',
#   'everything',
#   'OK',
#   'Thanks',
#   'smiling',
#   '_',
#   'face'],
#  ['It',
#   'quiet',
#   'hotel',
#   'room',
#   'need',
#   'cleaning',
#   'The',
#   'furniture',
#   'bathroom',
#   'outdated'],
#  ['Absolutely',
#   'exquisite',
#   'nestled',
#   'beach',
#   'road',
#   'area',
#   'Takoradi',
#   'Alliance',
#   'home',
#   'away',
#   'home',
#   'For',
#   'business',
#   'traveller',
#   'well',
#   'seeking',
#   'pleasure'],
#  ['Not',
#   'beautiful',
#   'picture',
#   'review',
#   'I',
#   'saw',
#   'looked',
#   'quite',
#   'tight',
#   'spacious',
#   'enough',
#   'But',
#   'good',
#   'side',
#   'stay',
#   'long',
#   'enough',
#   'find',
#   'though'],
#  ['Worthy', 'experience'],
#  ['Clean',
#   'serene',
#   'location',
#   'friendly',
#   'staff',
#   'The',
#   'room',
#   'small',
#   'well',
#   'maintained'],
#  ['Don',
#   'know',
#   'whether',
#   'season',
#   'thus',
#   'staff',
#   'overwhelmed',
#   'service',
#   'left',
#   'soo',
#   'much',
#   'desired'],
#  ['Their', 'food', 'exquisite'],
#  ['Cozy', 'place', 'great', 'service', 'value', 'money'],
#  ['This',
#   'one',
#   'nice',
#   'big',
#   'hotel',
#   'Takoradi',
#   'I',
#   'hoping',
#   'better',
#   'experience',
#   'I',
#   'especially',
#   'knowing',
#   'owned',
#   'Eagles',
#   'Their',
#   'staff',
#   'generally',
#   'nice',
#   'service',
#   'poor',
#   'The',
#   'breakfast',
#   'buffet',
#   'limited',
#   'We',
#   'option',
#   'food',
#   '3',
#   'night',
#   'stay',
#   'breakfast',
#   'I',
#   'add',
#   'favourite',
#   'place',
#   'Takoradi',
#   'Hopefully',
#   'improve',
#   'soon'],
#  ['Nice', 'place'],
#  ['If',
#   'best',
#   'among',
#   'best',
#   'hotel',
#   'Takoradi',
#   'Ghana',
#   'whole',
#   'hundred',
#   '_',
#   'point',
#   'red',
#   '_',
#   'heart'],
#  ['I', 'sound', 'mind', 'learning'],
#  ['We',
#   'stayed',
#   'hotel',
#   'family',
#   'vacation',
#   'amazing',
#   'time',
#   'The',
#   'staff',
#   'friendly',
#   'went',
#   'beyond',
#   'make',
#   'stay',
#   'enjoyable'],
#  ['My',
#   'staying',
#   'Alliance',
#   'peaceful',
#   'perfect',
#   'The',
#   'access',
#   'road',
#   'hotel',
#   'must',
#   'looked'],
#  ['Bad',
#   'experience',
#   'Had',
#   'change',
#   'room',
#   'Stained',
#   'mattress',
#   'broken',
#   'window',
#   'broken',
#   'toilet',
#   'seat',
#   'many',
#   'issue'],
#  ['Unpaved',
#   'road',
#   'leading',
#   'hotel',
#   'roomservice',
#   'taking',
#   'almost',
#   '1',
#   '5hours',
#   'deliver',
#   'simple',
#   'meal',
#   'diarrhea',
#   'food',
#   'water',
#   'shower',
#   'spraying',
#   'water',
#   'ceiling',
#   'floor',
#   'guest',
#   'playing',
#   'loud',
#   'music',
#   'pool',
#   'male',
#   'guest',
#   'staring',
#   'inappropriately',
#   'gym',
#   'reception',
#   'taking',
#   'immediate',
#   'action',
#   'afterwards',
#   'recommend',
#   'hotel',
#   'anyone',
#   'especially',
#   'female',
#   'foreigner'],
#  ['It',
#   'amazingly',
#   'serene',
#   'luxurious',
#   'place',
#   'spend',
#   'night',
#   'forget',
#   'world'],
#  ['Very', 'nice', 'lodge'],
#  ['Nice', 'place'],
#  ['I',
#   'stayed',
#   'hotel',
#   'work',
#   'related',
#   'retreat',
#   'liked',
#   'experience',
#   'The',
#   'room',
#   'clean',
#   'facility',
#   'standard',
#   'Their',
#   'front',
#   'desk',
#   'staff',
#   'friendly',
#   'welcoming',
#   'two',
#   'staff',
#   'depict',
#   'trait',
#   'Their',
#   'conference',
#   'room',
#   'ok',
#   'even',
#   'though',
#   'I',
#   'think',
#   'arrangement',
#   'furniture',
#   'fit',
#   'purpose',
#   'given',
#   'nature',
#   'engagement',
#   'I',
#   'get',
#   'use',
#   'facility',
#   'gym',
#   'I',
#   'attest',
#   'availability',
#   'state',
#   'Overall',
#   'lovely',
#   'place',
#   'especially',
#   'weekend',
#   'getaway'],
#  ['There', 'lovely', 'ambience', 'I', 'really', 'enjoyed', 'buffet', 'dinner'],
#  ['Serene', 'environment'],
#  ['The', 'best', 'come', 'West'],
#  ['Hotel',
#   'normal',
#   'I',
#   'wrote',
#   'pool',
#   'I',
#   'kicked',
#   'I',
#   'would',
#   'like',
#   'write',
#   'pool',
#   'high',
#   'Fix',
#   'bug',
#   'pancreas',
#   'norm',
#   'P',
#   'S',
#   'I',
#   'left',
#   'goose',
#   'room',
#   'throw',
#   'Tinkoff',
#   'Bitoch'],
#  ['smiling',
#   '_',
#   'face',
#   '_',
#   '_',
#   'hearteyes',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   '_',
#   'hearteyes',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   '_',
#   'hearteyes',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   '_',
#   'hearteyes',
#   'I',
#   'loved',
#   'stay',
#   'hotel',
#   'The',
#   'room',
#   'fabulous',
#   'Furniture',
#   'adorable',
#   'The',
#   'bedstead',
#   'classy',
#   'display',
#   'transparent',
#   'material',
#   'super',
#   'comfortable',
#   'mattress',
#   'bedding',
#   'The',
#   'view',
#   'window',
#   'beautiful',
#   'Showing',
#   'pool',
#   'vast',
#   'green',
#   'field',
#   'around',
#   'hotel',
#   'Washroom',
#   'housekeeping',
#   'breakfast',
#   'point',
#   'Rooms',
#   'Rates',
#   'little',
#   'high',
#   'side',
#   'In',
#   'evening',
#   'holiday',
#   'live',
#   'band',
#   'music',
#   'must',
#   'Anytime',
#   'I',
#   'back',
#   'Takoradi',
#   'I',
#   'surely',
#   'visit'],
#  ['Management',
#   'look',
#   'thing',
#   'thing',
#   'way',
#   'expensive',
#   '4pcs',
#   'spring',
#   'roll',
#   '100gh',
#   'n',
#   'opinion',
#   'u',
#   'guy',
#   'losing',
#   'customer',
#   'co',
#   'alot',
#   'pple',
#   'complaining',
#   'price',
#   'thanks'],
#  ['Great', 'hotel', 'Takoradi', 'nice', 'view', 'ocean'],
#  ['indeed',
#   'play',
#   'play',
#   'Eiiii',
#   'takodi',
#   'We',
#   'something',
#   'red',
#   '_',
#   'heart',
#   'globe',
#   '_',
#   'showing',
#   '_',
#   'EuropeAfrica',
#   'ry',
#   'folded',
#   '_',
#   'hand',
#   'Takoradi',
#   'World',
#   'wind',
#   '_',
#   'face'],
#  ['Walk',
#   'inn',
#   'shower',
#   'Moderate',
#   'neat',
#   'comfortable',
#   'room',
#   'There',
#   '3',
#   'swimming',
#   'pool',
#   'kid',
#   'normal',
#   'Olympic',
#   'size',
#   'Well',
#   'maintained',
#   'Dining',
#   'either',
#   'pool',
#   'side',
#   'dinning',
#   'area',
#   'whatever',
#   'comfortable',
#   'relaxing',
#   'lover',
#   'family',
#   'business',
#   'meeting',
#   'indoors',
#   'outdoors',
#   'I',
#   'view',
#   'go',
#   'beach',
#   'golf',
#   'course',
#   'football',
#   'pitch',
#   'swimming',
#   'pool',
#   'comfort',
#   'room',
#   'This',
#   'OK',
#   '_',
#   'hand',
#   'Guess',
#   'The',
#   'meal',
#   'expensive',
#   'I',
#   'imagined',
#   'Wifi',
#   'unreliable'],
#  ['Calm', 'space', 'accessible', 'Takoradi', 'city', 'It', 'beach', 'road'],
#  ['Clean',
#   'room',
#   'warm',
#   'staff',
#   'reception',
#   'good',
#   'variety',
#   'option',
#   'buffet',
#   'breakfast',
#   'menu',
#   'Lovely',
#   'view',
#   'ocean',
#   'lovely',
#   'landscape',
#   'hotel',
#   'room'],
#  ['Great', 'view', 'Serene', 'environment'],
#  ['Pizza', 'nice', 'Friendly', 'lovely', 'environment', 'scenic', 'view'],
#  ['Awesome', 'relaxing', 'hotel', 'good', 'business', 'family'],
#  ['The',
#   'Ghana',
#   'Institution',
#   'Engineering',
#   'held',
#   'annual',
#   'banquet',
#   'dinner',
#   'food',
#   'tasty',
#   'Set',
#   'AGM',
#   'also',
#   'great',
#   'Nice',
#   'place'],
#  ['Still', 'great', 'place', 'Takoradi'],
#  ['Nice', 'wonderful', 'place', 'relax', 'work'],
#  ['5',
#   'star',
#   'This',
#   'said',
#   'Everything',
#   'super',
#   'food',
#   'rest',
#   'amenity',
#   'etc'],
#  ['Thank', 'management', 'Staff', 'Excellent', 'service'],
#  ['Fantastic'],
#  ['The',
#   'hotel',
#   'nice',
#   'however',
#   'price',
#   'resort',
#   'cheap',
#   '4',
#   'star',
#   'hotel',
#   'I',
#   'expecting',
#   'higher',
#   'standard',
#   'We',
#   'booked',
#   'seaview',
#   'chalet',
#   'could',
#   'see',
#   'sea',
#   'due',
#   'back',
#   'gate',
#   'tree',
#   'The',
#   'building',
#   'need',
#   'renovated',
#   'The',
#   'shower',
#   'draining',
#   'properly',
#   'swimming',
#   'pool',
#   'lounge',
#   'chair',
#   'good',
#   'condition',
#   'pool',
#   'bed',
#   'dirty',
#   'We',
#   'hot',
#   'water',
#   'first',
#   'day',
#   'night',
#   'rectified',
#   'first',
#   'shower',
#   'cold',
#   'We',
#   'power',
#   'cut',
#   'lasted',
#   'hour',
#   'The',
#   'hotel',
#   'operational',
#   'generator',
#   'The',
#   'positive',
#   'thing',
#   'breakfast',
#   'buffet',
#   'continental',
#   'freshly',
#   'cooked',
#   'food',
#   'including',
#   'local',
#   'food',
#   'tasty'],
#  ['Air',
#   'conditioning',
#   'poor',
#   'I',
#   'hardly',
#   'slept',
#   'night',
#   'Pillows',
#   'like',
#   'big',
#   'gummy',
#   'bear',
#   'extremely',
#   'firm',
#   'round',
#   'Had',
#   'food',
#   'outside',
#   'back',
#   'ok'],
#  ['Very',
#   'good',
#   'hotel',
#   'clean',
#   'room',
#   'comfortable',
#   'delicious',
#   'food',
#   'best',
#   'hotel',
#   'stay',
#   'Takoradi',
#   'opinion'],
#  ['Great', 'resort'],
#  ['It',
#   'absolutely',
#   'beautiful',
#   'Staff',
#   'friendly',
#   'caring',
#   'An',
#   'excellent',
#   'selection',
#   'food',
#   'menu',
#   'Perhaps',
#   'larger',
#   'selection',
#   'onsite',
#   'entertainment',
#   'would',
#   'make',
#   'perfect',
#   'getaway',
#   'stay'],
#  ['I',
#   'absolutely',
#   'loved',
#   'stay',
#   'Red',
#   'Mango',
#   'I',
#   'honeymoon',
#   'lovely',
#   'Their',
#   'room',
#   'really',
#   'neat',
#   'modern',
#   'staff',
#   'welcoming',
#   'friendly',
#   'professional',
#   'pool',
#   'food',
#   'environment',
#   'access',
#   'town',
#   'etc',
#   'It',
#   'perfect',
#   'hideout',
#   'u'],
#  ['Service',
#   'location',
#   'top',
#   'notch',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   '_',
#   'smiling',
#   '_',
#   'eyesOK',
#   '_',
#   'hand'],
#  ['I', 'recommend', 'everyone', 'best', 'place'],
#  ['Well',
#   'arranged',
#   'apartment',
#   'good',
#   'comfort',
#   'couple',
#   'family',
#   'Well',
#   'located',
#   'heart',
#   'Takoradi'],
#  ['I',
#   'great',
#   'time',
#   'Red',
#   'mango',
#   'hotel',
#   'The',
#   'service',
#   'excellent',
#   'food',
#   'room',
#   'nice'],
#  ['This',
#   'located',
#   'serene',
#   'area',
#   'Takoradi',
#   'Very',
#   'close',
#   'road',
#   'easily',
#   'accessible',
#   'The',
#   'room',
#   'cool',
#   'quite',
#   'average',
#   'Their',
#   'service',
#   'nice',
#   'The',
#   'one',
#   'attended',
#   'smart',
#   'professional'],
#  ['The',
#   'environment',
#   'serene',
#   'Great',
#   'view',
#   'night',
#   'Good',
#   'dinner',
#   'couple',
#   'night'],
#  ['The', 'room', 'nice', 'comfy', 'Beautiful', 'experience'],
#  ['I',
#   'amazing',
#   'experience',
#   'would',
#   'definitely',
#   'recommend',
#   'anyone',
#   'looking',
#   'visit',
#   'Takoradi',
#   'soon'],
#  ['Couldn', 'asked', 'better', 'Services', 'top', 'notch'],
#  ['Red',
#   'Mango',
#   'awesome',
#   'interior',
#   'design',
#   'And',
#   'room',
#   'really',
#   'neat',
#   'I',
#   'personally',
#   'loved',
#   'washroom',
#   'Top',
#   'class'],
#  ['It',
#   'lovely',
#   'Clean',
#   'room',
#   'Staff',
#   'polite',
#   'professional',
#   'I',
#   'enjoyed',
#   'stay',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   '_',
#   'heart'],
#  ['I', 'enjoyed', 'stay'],
#  ['Very', 'comfortable', 'serene', 'environment', 'I', 'go'],
#  ['The',
#   'facility',
#   'exceeded',
#   'expectation',
#   'The',
#   'bed',
#   'comfortable',
#   'living',
#   'room',
#   'spacious',
#   'kitchenette',
#   'useful',
#   'breastfeeding',
#   'mum',
#   'I',
#   'love',
#   'fridge',
#   'sizeable',
#   'freezer',
#   'unit',
#   'However',
#   'smell',
#   'room',
#   'quite',
#   'strong',
#   'Smelt',
#   'like',
#   'sewage',
#   'something',
#   'dump',
#   'dry',
#   'properly',
#   'especially',
#   'area',
#   'around',
#   'vent',
#   'kitchen',
#   'Regardless',
#   'I',
#   'impressed',
#   'enjoyed',
#   'stay'],
#  ['It',
#   'really',
#   'lovely',
#   'place',
#   'Apartments',
#   'neat',
#   'feel',
#   'like',
#   'home',
#   'Their',
#   'pool',
#   'tidy',
#   'customer',
#   'service',
#   'excellent'],
#  ['Excellent', 'OK', '_', 'hand'],
#  ['Love', 'pool'],
#  ['Best',
#   'New',
#   'hide',
#   'takoradi',
#   'Lovely',
#   'room',
#   'Very',
#   'friendly',
#   'staff',
#   'Will',
#   'go',
#   'get',
#   'request',
#   'met',
#   'Only',
#   'problem',
#   'pool',
#   'unattended',
#   'And',
#   'I',
#   'saw',
#   'crow',
#   'bathing',
#   'Not',
#   'healthy',
#   'Hopefully',
#   'addressed'],
#  ['The',
#   'best',
#   'hotel',
#   'business',
#   'vacation',
#   'nutritious',
#   'assorted',
#   'food',
#   'every',
#   'occasion'],
#  ['Nice', 'place'],
#  ['Lovely',
#   'apartment',
#   'high',
#   'quality',
#   'finishing',
#   'kitchenette',
#   'facility',
#   'provides',
#   'catering',
#   'service',
#   'well',
#   'There',
#   'daily',
#   'room',
#   'cleaning',
#   'staff',
#   'top',
#   'notch',
#   'professional',
#   'friendly',
#   'There',
#   'infinity',
#   'pool',
#   'set',
#   'peaceful',
#   'garden',
#   'Great',
#   'place',
#   'work',
#   'travel',
#   'get',
#   'away'],
#  ['A', 'cozy', 'relaxing', 'place', 'whole', 'family'],
#  ['Lovely',
#   'serene',
#   'place',
#   'The',
#   'waitress',
#   'happy',
#   'serve',
#   'u',
#   'It',
#   'good',
#   'accommodation',
#   'pick',
#   'In',
#   'Takoradi',
#   'day'],
#  ['Nice', 'place', 'bar', 'area'],
#  ['What',
#   'place',
#   'siren',
#   'environment',
#   'perfect',
#   'come',
#   'service',
#   'render',
#   'guest'],
#  ['Best', 'Place', 'ever', 'visit'],
#  ['Gives', 'comfortable', 'home', 'away', 'home'],
#  ['W'],
#  ['Great'],
#  ['Indeed', 'nice', 'place'],
#  ['Beautiful', 'Compound'],
#  ['Cozy', 'room', 'Serene', 'environment'],
#  ['Nice', 'environment'],
#  ['Nice'],
#  ['Sedelam',
#   'Lodge',
#   'home',
#   'away',
#   'home',
#   'U',
#   'never',
#   'regret',
#   'cherish',
#   'comfort',
#   'Cousy',
#   'serene',
#   'Will',
#   'recommend',
#   'Sedelam',
#   'day',
#   '100',
#   'OK',
#   '_',
#   'hand'],
#  ['A', 'Good', 'hotel', 'Aboadzi', 'enclave'],
#  ['Nice', 'place', 'thumb', '_'],
#  ['A',
#   'Cool',
#   'Nice',
#   'place',
#   'lodge',
#   'Excellent',
#   'client',
#   'service',
#   'I',
#   'highly',
#   'recommend',
#   'Sedelam',
#   'Lodge',
#   'anyone',
#   'looking',
#   'cool',
#   'place',
#   'lodge',
#   'Takoradi',
#   'red',
#   '_',
#   'heart'],
#  ['Friendly',
#   'staff',
#   'well',
#   'managed',
#   'Serene',
#   'environment',
#   'It',
#   'must',
#   'looking',
#   'change',
#   'usual',
#   'buzz',
#   'city',
#   'relax',
#   'fun'],
#  ['A',
#   'nice',
#   'place',
#   'countryside',
#   'vacation',
#   'Beautiful',
#   'environment',
#   'great',
#   'reception',
#   'I',
#   'recommend',
#   'place'],
#  ['Beautiful',
#   'environment',
#   'excellent',
#   'service',
#   'I',
#   'really',
#   'enjoyed',
#   'stay',
#   'great',
#   'customer',
#   'service',
#   'provided',
#   'I',
#   'recommend',
#   'visit',
#   'More',
#   'home'],
#  ['My',
#   'Honeymoon',
#   'stay',
#   'Sedelam',
#   'Lodge',
#   'best',
#   'It',
#   'serene',
#   'beautiful',
#   'edifice',
#   'comfortable',
#   'king',
#   'Queen',
#   'size',
#   'bed',
#   'sedelam',
#   'red',
#   '_',
#   'heart',
#   'red',
#   '_',
#   'heart'],
#  ['Great',
#   'environment',
#   'Nice',
#   'comfortable',
#   'room',
#   'My',
#   'family',
#   'I',
#   'totally',
#   'enjoyed',
#   'stay'],
#  ['VERY', 'COMFORTABLE', 'LODGE', 'TO', 'BE', 'BEST', 'EXPERIENCE'],
#  ['Great',
#   'place',
#   'serene',
#   'area',
#   'If',
#   'need',
#   'place',
#   'away',
#   'hustle',
#   'bustle',
#   'city',
#   'get',
#   'business',
#   'Sedelam',
#   'place'],
#  ['Excellent',
#   'Hotel',
#   'Service',
#   'Serene',
#   'Environment',
#   'Nice',
#   'room',
#   'I',
#   'loved',
#   'stay'],
#  ['Serene'],
#  ['Nice'],
#  ['Nice', 'serene', 'view'],
#  ['A',
#   'well',
#   'managed',
#   'lodge',
#   'decent',
#   'facility',
#   'I',
#   'rate',
#   '3',
#   'star',
#   'minor',
#   'factor'],
#  ['Boarding', 'facility', 'provided', 'College'],
#  ['The', 'place', 'cool', 'refreshing'],
#  ['Guest',
#   'House',
#   'located',
#   'top',
#   'volley',
#   'irregular',
#   'staircase',
#   'steeped',
#   'inconvenient',
#   'access',
#   'Superb',
#   'view',
#   'city',
#   'sea',
#   'Vast',
#   'clean',
#   'without',
#   'insured',
#   'running',
#   'water',
#   'Staff',
#   'empathy',
#   'Ni',
#   'wifi',
#   'contrary',
#   'mentioned',
#   'This',
#   'little',
#   'complicated',
#   'center',
#   'manage',
#   'past',
#   '18',
#   'hour',
#   'end',
#   'service',
#   'Taxi',
#   'Taxis'],
#  ['Not', 'bad', 'careful', 'address', 'provided'],
#  ['I',
#   'enjoyed',
#   'stay',
#   'Very',
#   'big',
#   'room',
#   'good',
#   'location',
#   'great',
#   'sea',
#   'view',
#   'even',
#   'community',
#   'view',
#   'I',
#   'wake',
#   'every',
#   'morning',
#   'standing',
#   'corridor',
#   'viewing',
#   'sea',
#   'also',
#   'see',
#   'people',
#   'passing',
#   'It',
#   'life',
#   'worth',
#   'Just',
#   'little',
#   'challenge',
#   'booking',
#   'com',
#   'breakfast',
#   'started',
#   'understood',
#   'mistake',
#   'booking',
#   'page',
#   'Apart',
#   'good'],
#  ['Nice',
#   'place',
#   'affordable',
#   'I',
#   'wished',
#   'constant',
#   'water',
#   'flow',
#   'Wifi',
#   'Aside',
#   'everything',
#   'else',
#   'average'],
#  ['Was', 'fantastic'],
#  ['Nice', 'place'],
#  ['Cool', 'place'],
#  ['It', 'cool', 'I', 'love'],
#  ['Room', 'quite', 'spacious', 'No', 'running', 'water'],
#  ['It', 'ok'],
#  ['Was', 'really', 'happy', 'long', 'time', 'residing', 'wonderful', 'year'],
#  ['Cool'],
#  ['oh', 'like', 'see', 'township', 'room', 'spacious', 'bar', 'spa'],
#  ['Free', 'WiFi', 'Internet', 'access'],
#  ['Affordable', 'beautiful'],
#  ['They',
#   'use',
#   'breakfast',
#   'Access',
#   'complex',
#   'several',
#   'step',
#   'It',
#   'moderately',
#   'decent',
#   'price',
#   'ask',
#   'The',
#   'view',
#   'pretty'],
#  ['Yaa'],
#  ['This',
#   'guest',
#   'house',
#   'treat',
#   'visitor',
#   'nice',
#   'place',
#   'indeed',
#   'meant',
#   'relaxation'],
#  ['Perfect',
#   'sense',
#   'peaceful',
#   'place',
#   'well',
#   'situated',
#   'lovely',
#   'staff',
#   'always',
#   'help',
#   'It',
#   'pleasure',
#   'I',
#   'highly',
#   'recommend'],
#  ['Comfortable', 'peaceful'],
#  ['Good'],
#  ['The', 'place', 'well', 'equipped', 'specially', 'room', 'good', 'offer'],
#  ['Vacation', 'went', 'swim'],
#  ['Bad', 'network', 'serene', 'environment'],
#  ['Incredibly',
#   'nice',
#   'helpful',
#   'staff',
#   'willing',
#   'always',
#   'advise',
#   'help',
#   'We',
#   'enjoyed',
#   'lot'],
#  ['Nice',
#   'pool',
#   'good',
#   'place',
#   'socialise',
#   'especially',
#   'weekend',
#   'holiday'],
#  ['Nice',
#   'hotel',
#   'affordable',
#   'hotel',
#   'Got',
#   'pool',
#   'gym',
#   'restaurant',
#   'friendly',
#   'effective',
#   'staff'],
#  ['FRIENDLY',
#   'STAFF',
#   'AND',
#   'GREAT',
#   'ENVIRONMENT',
#   'AS',
#   'WELL',
#   'I',
#   'RECOMMEND',
#   'TO',
#   'EVERYONE',
#   'VISITING',
#   'CAPE',
#   'COAST',
#   'LODGE',
#   'THERE'],
#  ['It', 'nice', 'place'],
#  ['It', 'nice', 'place'],
#  ['Nice',
#   'place',
#   'Kindly',
#   'fix',
#   'road',
#   'leading',
#   'facility',
#   'The',
#   'network',
#   'terrible',
#   'great',
#   'place'],
#  ['Very', 'good', 'Services'],
#  ['It',
#   'good',
#   'hotel',
#   'serene',
#   'area',
#   'It',
#   'fitness',
#   'center',
#   'bar',
#   'swimming',
#   'pool'],
#  ['I',
#   'enjoyed',
#   'place',
#   'safe',
#   'room',
#   'neat',
#   'service',
#   'nice',
#   'location',
#   'awesome'],
#  ['Nice', 'place', 'cool', 'family', 'event'],
#  ['Infact', 'I', 'design', 'room', 'spacious', 'You', 'comfort'],
#  ['Very', 'serene', 'environment'],
#  ['It', 'nice', 'place', 'amazing', 'envernoment'],
#  ['Excited'],
#  ['Good'],
#  ['Nice', 'atmosphere'],
#  ['Cool', 'place'],
#  ['Its',
#   'nice',
#   'place',
#   'We',
#   'went',
#   'swim',
#   'pool',
#   'student',
#   'We',
#   'enjoyed',
#   'clean',
#   'water',
#   'fun'],
#  ['Fun'],
#  ['Cool', 'place'],
#  ['I',
#   'met',
#   'one',
#   'manager',
#   'Richard',
#   'super',
#   'good',
#   'Excellent',
#   'customer',
#   'service',
#   'They',
#   'clean',
#   'room',
#   'get',
#   'little',
#   'heated',
#   'afternoon'],
#  ['I',
#   'think',
#   'management',
#   'need',
#   'step',
#   'game',
#   'Room',
#   'service',
#   'good',
#   'I',
#   'yet',
#   'know',
#   'guest',
#   'house',
#   'charge',
#   'Gh100',
#   'night',
#   'without',
#   'serving',
#   'Breakfast',
#   'even',
#   'tying',
#   'get',
#   'food',
#   'around',
#   'area',
#   'quite',
#   'challenge'],
#  ['Friendly', 'staff'],
#  ['To',
#   'recommend',
#   'dirty',
#   'hot',
#   'place',
#   'common',
#   'toilet',
#   'locate',
#   'towel',
#   'soap',
#   'shower',
#   'trash',
#   'bedroom',
#   'dust',
#   'hair',
#   'hair',
#   'pillow',
#   'Awakened',
#   '06',
#   '45',
#   'phone',
#   'number',
#   'hour',
#   'later',
#   'number',
#   'work',
#   'In',
#   'short',
#   'flee'],
#  ['Below', 'expectation', 'guest', 'experience', 'good'],
#  ['Love', 'place', 'Cool', 'n', 'serine', 'environment'],
#  ['Rates', 'moderate'],
#  ['It', 'nice', 'place', 'I', 'really', 'enjoy', 'stay'],
#  ['Will'],
#  ['Sirens', 'atmosphere'],
#  ['Facilities',
#   'good',
#   'Human',
#   'relationship',
#   'average',
#   'No',
#   'bar',
#   'service',
#   'restaurant',
#   'provide',
#   'food',
#   'client',
#   'register',
#   'stay',
#   'Guest',
#   'House',
#   'late',
#   'night'],
#  ['Cool', 'place', 'But', 'expect', 'much'],
#  ['They', 'best', 'customer', 'service'],
#  ['Cheap', 'place', 'I', 'go', '2', 'star', 'receptionist', 'nice'],
#  ['Beach', 'side', 'guest', 'house', 'rate', 'cool'],
#  ['It',
#   'moderate',
#   'consideration',
#   'financially',
#   'Very',
#   'serene',
#   'great',
#   'place',
#   'sea',
#   'public',
#   'beach',
#   'much',
#   'people',
#   'relax',
#   'peace',
#   'Good',
#   'staff',
#   'take',
#   'satisfy',
#   'customer',
#   'The',
#   'owner',
#   'great',
#   'human',
#   'skill',
#   'One',
#   'thing',
#   'I',
#   'loved',
#   'mosquito',
#   'strong',
#   'breeze',
#   'always',
#   'around'],
#  ['Good', 'place', 'centre', 'town'],
#  ['Serine', 'environment', 'A', 'cool', 'place', 'relax'],
#  ['nice',
#   'clean',
#   'room',
#   'breakfast',
#   'superb',
#   'night',
#   'manager',
#   'awesome'],
#  ['Cool', 'place'],
#  ['Quite', 'quiet'],
#  ['Great', 'Hospitality', 'generally', 'clean', 'place'],
#  ['Was', 'nice', 'environment', 'I', 'drink'],
#  ['Staf',
#   'Amazing',
#   'especially',
#   'Fredrick',
#   'help',
#   'everything',
#   'Loved',
#   'energy',
#   'environment',
#   'serene'],
#  ['In',
#   'middle',
#   'impressive',
#   'green',
#   'setting',
#   'Ahanta',
#   'Eco',
#   'Lodge',
#   'conceals',
#   'magnificent',
#   'garden',
#   'decor',
#   'stay',
#   'Very',
#   'diverse',
#   'room',
#   'ranging',
#   'suite',
#   'bathroom',
#   'apparently',
#   'without',
#   'Beach',
#   'House',
#   'attached',
#   'surf',
#   'school',
#   'lodge',
#   'note',
#   'latter',
#   'relatively',
#   'distant',
#   'rest',
#   'lodge',
#   'necessaryCount',
#   'least',
#   '5',
#   'minute',
#   'walking',
#   'crossing',
#   'lagoon',
#   'low',
#   'tide',
#   'passing',
#   'village',
#   'In',
#   'general',
#   'road',
#   'leading',
#   'Busua',
#   'therefore',
#   'eco',
#   'lodge',
#   'rather',
#   'chaotic',
#   'damaged',
#   'Count',
#   'good',
#   'driver',
#   'afraid',
#   'bridge',
#   'lagoon',
#   'The',
#   'team',
#   'responsive',
#   'accommodating',
#   'able',
#   'change',
#   'room',
#   'last',
#   'moment',
#   'request',
#   'thank',
#   'Fredrick',
#   'The',
#   'kitchen',
#   'cleanly',
#   'fabulous',
#   'various',
#   'dish',
#   'different',
#   'menu',
#   'every',
#   'day',
#   'local',
#   'product',
#   'The',
#   'chef',
#   'able',
#   'surprise',
#   'authentic',
#   'homemade',
#   'cuisine',
#   'At',
#   'bar',
#   'Francis',
#   'prepare',
#   'whole',
#   'range',
#   'cocktail',
#   'tasty',
#   'Special',
#   'mention',
#   'homemade',
#   'akpetesthie',
#   'good',
#   'humor',
#   'Our',
#   'stay',
#   'pleasant',
#   'hope',
#   'able',
#   'come',
#   'back',
#   'soon'],
#  ['I',
#   'stayed',
#   'Ahanta',
#   'several',
#   'day',
#   'long',
#   'journey',
#   'Ghana',
#   'enjoyed',
#   'calm',
#   'relaxing',
#   'atmosphere',
#   'lot',
#   'The',
#   'location',
#   'beautiful',
#   'I',
#   'loved',
#   'tree',
#   'shower',
#   'I',
#   'felt',
#   'close',
#   'nature',
#   'next',
#   'beach',
#   'side',
#   'The',
#   'staff',
#   'friendly',
#   'even',
#   'though',
#   'information',
#   'would',
#   'helpful',
#   'check',
#   'We',
#   'approach',
#   'staff',
#   'several',
#   'time',
#   'upcoming',
#   'question',
#   'could',
#   'cleared',
#   'beginning',
#   'The',
#   'food',
#   'amazing',
#   'even',
#   'though',
#   'bit',
#   'pricier',
#   'place',
#   'outside',
#   'sitting',
#   'relax',
#   'area',
#   'wonderful',
#   'The',
#   'thing',
#   'really',
#   'disturbed',
#   'u',
#   'rat',
#   'bedroom',
#   'washroom',
#   'We',
#   'tried',
#   'pack',
#   'drink',
#   'snack',
#   'good',
#   'could',
#   'several',
#   'plastic',
#   'bag',
#   'backpack',
#   'still',
#   'entered',
#   'room',
#   'went',
#   'stuff',
#   'I',
#   'personally',
#   'scared',
#   'night',
#   'could',
#   'hear',
#   'saw',
#   'entered',
#   'room',
#   'day',
#   'beach',
#   'I',
#   'called',
#   'reception',
#   'night',
#   'couldnt',
#   'anything',
#   'point',
#   'The',
#   'next',
#   'day',
#   'offered',
#   'clean',
#   'room',
#   'fill',
#   'certain',
#   'hole',
#   'wooden',
#   'roof',
#   'didnt',
#   'help',
#   'They',
#   'asked',
#   'understanding',
#   'ecolodge',
#   'animal',
#   'friendly',
#   'place',
#   'talking',
#   'rat',
#   'I',
#   'accept',
#   'argument',
#   'Especially',
#   'later',
#   'offered',
#   'u',
#   'place',
#   'trap',
#   'room',
#   'animal',
#   'friendly',
#   'Moreover',
#   'next',
#   'night',
#   'I',
#   'used',
#   'washroom',
#   'rat',
#   'bin',
#   'supposed',
#   'emptied',
#   'afternoon',
#   'cleaning',
#   'I',
#   'read',
#   'people',
#   'rat',
#   'problem',
#   'Ahanta',
#   'made',
#   'sleeping',
#   'almost',
#   'impossible',
#   'Still',
#   'really',
#   'amazing',
#   'place',
#   'I',
#   'guess',
#   'one',
#   'beautiful',
#   'stay',
#   'Busua',
#   'rat',
#   'experience',
#   'diminished',
#   'overall',
#   'good',
#   'experience'],
#  ['For',
#   'best',
#   'hotel',
#   'Busua',
#   'Super',
#   'nice',
#   'staff',
#   'flexible',
#   'come',
#   'wish',
#   'guest',
#   'grandiose',
#   'cocktail',
#   'excellent',
#   'food',
#   'The',
#   'bridge',
#   'lodge',
#   'unfortunately',
#   'imposition',
#   'unfortunately',
#   'I',
#   'confirm',
#   'story',
#   'rat',
#   'review',
#   'Therefore',
#   '4',
#   'star'],
#  ['Nice',
#   'accommodation',
#   'end',
#   'beach',
#   'There',
#   'room',
#   'different',
#   'comfort',
#   'We',
#   'Wood',
#   'House',
#   'rather',
#   'comfortable',
#   'However',
#   'photo',
#   'first',
#   'bungalow',
#   'garden',
#   'front',
#   'restaurant',
#   'The',
#   'food',
#   'excellent',
#   'cocktail',
#   'also',
#   'recommended',
#   'Because',
#   'standing',
#   'water',
#   'front',
#   'garden',
#   'mosquito',
#   'spray',
#   'strongly',
#   'recommended',
#   'So',
#   'sit',
#   'outside'],
#  ['Everything', 'great', 'Essen', 'drink', 'accommodation'],
#  ['We',
#   'much',
#   'enjoyed',
#   'stay',
#   'Ahanta',
#   'The',
#   'room',
#   'communal',
#   'area',
#   'nicely',
#   'done',
#   'cosy',
#   'clean',
#   '3',
#   'option',
#   'offered',
#   'dinner',
#   'daily',
#   '40',
#   '70ish',
#   'GHS',
#   'always',
#   'tasty',
#   'one',
#   'big',
#   'table',
#   'provides',
#   'opportunity',
#   'get',
#   'know',
#   'guest',
#   'There',
#   'also',
#   'cocktail',
#   'available',
#   'breakfast',
#   'better',
#   'standard',
#   'hotel',
#   'fare',
#   'Busua',
#   'offer',
#   'lot',
#   'surfing',
#   'offered',
#   'lovely',
#   'instructor',
#   'Ahanta',
#   'come',
#   'prepared',
#   'quiet',
#   'stay',
#   'lot',
#   'reading',
#   'We',
#   'also',
#   'ate',
#   'almost',
#   'exclusively',
#   'lodge',
#   'many',
#   'option',
#   'There',
#   'also',
#   'Ahanta',
#   'surf',
#   'beach',
#   'hut',
#   'beach',
#   'nice',
#   'spot',
#   'hang',
#   'To',
#   'get',
#   'village',
#   'main',
#   'beach',
#   'stretch',
#   'cross',
#   'lagoon',
#   'pleasant',
#   'several',
#   'time',
#   'day',
#   'bit',
#   'dangerous',
#   'high',
#   'fast',
#   'water',
#   'level',
#   'You',
#   'also',
#   'walk',
#   'long',
#   'way',
#   'around',
#   'across',
#   'patchy',
#   'bridge',
#   'small',
#   'touristy',
#   'village',
#   'One',
#   'two',
#   'thing',
#   'le',
#   'ideal',
#   'daily',
#   'wake',
#   'call',
#   'round',
#   '6',
#   '15',
#   'local',
#   'rooster',
#   'general',
#   'enjoyed',
#   'observing',
#   'chicken',
#   'rooster',
#   'goat',
#   'dog',
#   'lodge',
#   'though',
#   'Sometimes',
#   'woken',
#   'animal',
#   'noise',
#   'night',
#   'due',
#   'rainy',
#   'season',
#   'everything',
#   'slightly',
#   'damp',
#   'bed',
#   'sheet',
#   'towel',
#   'clothes',
#   'drying',
#   'difficult',
#   'thing',
#   'started',
#   'smell',
#   'little',
#   'moldy',
#   'outside',
#   'area',
#   'could',
#   'improved',
#   'place',
#   'sit',
#   'especially',
#   'sun',
#   'Other',
#   'lovely',
#   'albeit',
#   'quiet',
#   'time',
#   'staff',
#   'really',
#   'great',
#   'come',
#   'back',
#   'Busua',
#   'return'],
#  ['Great',
#   'little',
#   'eco',
#   'lodge',
#   'cornered',
#   'lagoon',
#   'Stayed',
#   'budget',
#   'room',
#   'name',
#   'suggests',
#   'pretty',
#   'budget',
#   'still',
#   'good',
#   'value',
#   'money',
#   'Showering',
#   'gigantic',
#   'tree',
#   'definitely',
#   'experience',
#   'Relaxing',
#   'atmosphere',
#   'great',
#   'food',
#   'WiFi',
#   'Prob',
#   'one',
#   'best',
#   'place',
#   'stay',
#   'Busua',
#   'hence',
#   'popularity',
#   'Make',
#   'sure',
#   'book',
#   'advance'],
#  ['A',
#   'wonderful',
#   'place',
#   'beautiful',
#   'room',
#   'good',
#   'cuisine',
#   'great',
#   'bar',
#   'Unfortunately',
#   'associated',
#   'surf',
#   'school',
#   'made',
#   'opposite',
#   'impression',
#   'unpunctual',
#   'unmotivated',
#   'guide',
#   'old',
#   'sometimes',
#   'bad',
#   'material'],
#  ['What',
#   'great',
#   'experience',
#   'My',
#   'friend',
#   'I',
#   'arrived',
#   'day',
#   'checking',
#   'space',
#   'The',
#   'beautiful',
#   'environment',
#   'absolutely',
#   'stunning',
#   'The',
#   'tall',
#   'old',
#   'tree',
#   'little',
#   'garden',
#   'use',
#   'every',
#   'living',
#   'thing',
#   'breath',
#   'taking',
#   'You',
#   'option',
#   'use',
#   'big',
#   'metal',
#   'bridge',
#   'get',
#   'place',
#   'use',
#   'small',
#   'river',
#   'collides',
#   'sea',
#   'That',
#   'magical',
#   'My',
#   'first',
#   'two',
#   'night',
#   'got',
#   'beach',
#   'house',
#   'detached',
#   'eco',
#   'lodge',
#   'It',
#   'right',
#   'beach',
#   'surf',
#   'school',
#   'small',
#   'coffee',
#   'shop',
#   'The',
#   'beach',
#   'house',
#   'beautiful',
#   'lively',
#   'vibrant',
#   'color',
#   'There',
#   'two',
#   'pet',
#   'around',
#   'A',
#   'cat',
#   'dog',
#   'friendly',
#   'You',
#   'take',
#   'dog',
#   'walk',
#   'I',
#   'guess',
#   'ask',
#   'permission',
#   'first',
#   'And',
#   'allergic',
#   'like',
#   'around',
#   'ask',
#   'removal',
#   'while',
#   'stay',
#   'The',
#   'inside',
#   'space',
#   'beautiful',
#   'well',
#   'taken',
#   'care',
#   'We',
#   'checked',
#   'eco',
#   'lodge',
#   'space',
#   'next',
#   'day',
#   'beautiful',
#   'natural',
#   'undertone',
#   'interior',
#   'Warm',
#   'shower',
#   'free',
#   'Wi',
#   'Fi',
#   'quite',
#   'siren',
#   'environment',
#   'The',
#   'worker',
#   'friendly',
#   'especially',
#   'Frederick',
#   'Joy',
#   'helpful',
#   'whenever',
#   'question',
#   'issue',
#   'concerning',
#   'stay',
#   'The',
#   'breakfast',
#   'included',
#   'room',
#   'rate',
#   'absolutely',
#   'mouth',
#   'watering',
#   'They',
#   'good',
#   'option',
#   'choose',
#   'They',
#   'offer',
#   'dinner',
#   'option',
#   'day',
#   'took',
#   'dinner',
#   'night',
#   'checked',
#   'regretted',
#   'eat',
#   'whole',
# ...
#   'functional',
#   'Alas',
#   'due',
#   'full',
#   'booking',
#   'place',
#   'I',
#   'stay',
#   'They',
#   'also',
#   'working',
#   'WiFi',
#   'Plus',
#   'cellphone',
#   'reception',
#   'terrible',
#   'The',
#   'Hotel',
#   'rate',
#   'hand',
#   'good'],
#  ['Has',
#   'serene',
#   'environment',
#   'nice',
#   'accessible',
#   'road',
#   'easy',
#   'locate'],
#  ['It', 'changed'],
#  ['This', 'place', 'nice', 'wedding', 'reception', 'engagement'],
#  ['Manageable'],
#  ['Savoy', 'best'],
#  ['Not', 'bad'],
#  ['I', 'live', 'der', 'nd', 'de', 'many', 'change', 'savoy'],
#  ['Neat', 'comfortable', 'place'],
#  ['Not', 'much', 'say', 'place', 'great'],
#  ['It', 'help'],
#  ['It', 'rated', '3', 'star', 'hotel', 'Cape', 'Coast'],
#  ['Classic', 'looking', 'hotel'],
#  ['Still', 'Operating', 'good', 'crash', 'night', 'travel'],
#  ['It', 'average', 'hotel', 'I', 'like', 'environment'],
#  ['Good'],
#  ['Home', 'based'],
#  ['smirking', '_', 'face'],
#  ['Very', 'unique'],
#  ['Average', 'facility'],
#  ['Cool', 'place'],
#  ['Lovely',
#   'place',
#   'Big',
#   'bed',
#   'calm',
#   'environment',
#   'Nice',
#   'service',
#   'Will',
#   'go',
#   'back',
#   'ad'],
#  ['The', 'accommodation', 'nice', 'clean', 'perfect', 'place'],
#  ['Savoy',
#   'Hotel',
#   'use',
#   'iconic',
#   'hotel',
#   'hotel',
#   'good',
#   'condition',
#   'use',
#   'It',
#   'Rehabilitated'],
#  ['No',
#   'wifi',
#   'break',
#   'fast',
#   'water',
#   'heater',
#   'swimming',
#   'pool',
#   'restaurant'],
#  ['It', 'old', 'place', 'spend', 'night'],
#  ['It', 'nice', 'place'],
#  ['An',
#   'amazing',
#   'school',
#   'set',
#   'aim',
#   'providing',
#   'quality',
#   'education'],
#  ['Lovely', 'environment'],
#  ['Good', 'location'],
#  ['This',
#   'place',
#   'indeed',
#   'paradise',
#   'I',
#   'spent',
#   'three',
#   'day',
#   'resort',
#   'service',
#   'environment',
#   'superb',
#   'The',
#   'staff',
#   'friendly',
#   'food',
#   'WOW',
#   'good',
#   'room',
#   'tidy',
#   'spacious',
#   'I',
#   'wait',
#   'go',
#   'back',
#   'future'],
#  ['Impeccable',
#   'service',
#   'The',
#   'staff',
#   'attractive',
#   'kind',
#   'discreet',
#   'The',
#   'location',
#   'pleasant',
#   'large',
#   'garden',
#   'play',
#   'area',
#   'access',
#   'lake',
#   'Nice',
#   'environment',
#   'peaceful',
#   'Perfect',
#   'observation',
#   'bird',
#   'provide',
#   'twin',
#   'long',
#   'lived',
#   'Excellent',
#   'generous',
#   'varied',
#   'cuisine',
#   'Everything',
#   'done',
#   'time',
#   'hurry',
#   'You',
#   'order',
#   'advance',
#   'The',
#   'room',
#   'large',
#   'correct',
#   'Little',
#   'water',
#   'pressure',
#   'shower',
#   'Possibility',
#   'park',
#   'car',
#   'next',
#   'room',
#   'Access',
#   'however',
#   'complicated',
#   'The',
#   'road',
#   'difficult',
#   'pas',
#   'Make',
#   'sure',
#   'suitable',
#   'vehicle',
#   'It',
#   'rather',
#   'isolated',
#   'place',
#   'like',
#   'dwelling',
#   'offered',
#   'around',
#   'lake',
#   'You',
#   'know',
#   'set',
#   'small',
#   'village',
#   'living',
#   'You',
#   'pay',
#   '10Ghs',
#   'per',
#   'person',
#   'access',
#   'valley'],
#  ['PROS',
#   'I',
#   'spent',
#   'night',
#   'In',
#   'fact',
#   'service',
#   'top',
#   'notch',
#   'The',
#   'room',
#   'neat',
#   'AC',
#   'functioned',
#   'well',
#   'environment',
#   'neat',
#   'except',
#   'lake',
#   'side',
#   'recently',
#   'used',
#   'people',
#   'got',
#   'The',
#   'food',
#   'superb',
#   'I',
#   'opportunity',
#   'take',
#   'variety',
#   'meal',
#   'Breakfast',
#   'Milo',
#   'pancake',
#   'bread',
#   'fried',
#   'egg',
#   'Lunch',
#   'Fufu',
#   'Aponkye',
#   'Light',
#   'soup',
#   'Supper',
#   'Banku',
#   'Tilapia',
#   'plus',
#   'Special',
#   'local',
#   'potato',
#   'chicken',
#   'ordered',
#   'special',
#   'pop',
#   'corn',
#   'khebab',
#   'fried',
#   'plantain',
#   'Their',
#   'food',
#   'far',
#   'best',
#   'ive',
#   'tasted',
#   'resort',
#   'The',
#   'owner',
#   'Maa',
#   'Patricia',
#   'friendly',
#   'met',
#   'two',
#   'people',
#   'Solomon',
#   'Seiba',
#   'woooooooooow',
#   'customer',
#   'service',
#   'assistance',
#   'overwhelming',
#   'I',
#   'hesitate',
#   'visit',
#   'place',
#   'second',
#   'time',
#   'Cons',
#   'Despite',
#   'nice',
#   'environment',
#   'negative',
#   'The',
#   'road',
#   'leading',
#   'place',
#   'bad',
#   'far',
#   'There',
#   'wall',
#   'around',
#   'resort',
#   'security',
#   'concern',
#   'really',
#   'see',
#   'security',
#   'guard',
#   'around',
#   'They',
#   'security',
#   'cam',
#   'far',
#   'car',
#   'park',
#   'But',
#   'I',
#   'really',
#   'enjoyed',
#   'stay'],
#  ['The',
#   'food',
#   'environment',
#   'staff',
#   'especially',
#   'Madam',
#   'Patricia',
#   'CEO',
#   'loving',
#   'humble',
#   'She',
#   'time',
#   'everyone'],
#  ['I',
#   'enjoyed',
#   'ecofriendly',
#   'system',
#   'wildwin',
#   'food',
#   'best',
#   'jollof',
#   'rice',
#   'banku',
#   'tilapia',
#   'muah',
#   'owner',
#   'madam',
#   'Patricia',
#   'humble',
#   'friendly',
#   'person',
#   'Planning',
#   'another',
#   'visit'],
#  ['Asked',
#   'Guiness',
#   '15',
#   'cedi',
#   'Was',
#   'warm',
#   'When',
#   'I',
#   'left',
#   'said',
#   'actually',
#   '20',
#   'cedi',
#   'If',
#   'sell',
#   '5',
#   '6',
#   'drink',
#   'know',
#   'price'],
#  ['Great',
#   'place',
#   'toilet',
#   'shower',
#   'bad',
#   'electricity',
#   'fail',
#   'many',
#   'time',
#   'The',
#   'restaurant',
#   'good',
#   'take',
#   'tour',
#   'boat',
#   'fun'],
#  ['It',
#   'beautiful',
#   'resort',
#   'right',
#   'Lake',
#   'Bosumtwi',
#   'You',
#   'love',
#   'food',
#   'good',
#   'atmosphere',
#   'relaxing',
#   'You',
#   'take',
#   'swim',
#   'The',
#   'staff',
#   'nice',
#   'owner',
#   'friendly',
#   'Downside',
#   'warm',
#   'shower',
#   'issue',
#   'want',
#   'Otherwise',
#   'I',
#   'totally',
#   'enjoyed',
#   'stay',
#   'blast'],
#  ['Loved',
#   'environment',
#   'Very',
#   'serene',
#   'great',
#   'food',
#   'beautiful',
#   'environment',
#   'Staff',
#   'friendly',
#   'Ultimate',
#   'escape',
#   'reset',
#   'meditate',
#   'reconnect',
#   'nature',
#   'Counting',
#   'day',
#   'next',
#   'visit'],
#  ['The',
#   'view',
#   'lake',
#   'serenity',
#   'absolutely',
#   'worth',
#   'journey',
#   'sparkle'],
#  ['Bad', 'policy', 'Not', 'good', 'By', 'force', 'ordering', 'food'],
#  ['Cozy', 'environment', 'food', 'keep', 'long'],
#  ['one', 'best', 'resort', 'get', 'leisure', 'Don', 'miss'],
#  ['They',
#   'best',
#   'road',
#   'though',
#   'serene',
#   'natural',
#   'environment',
#   'view',
#   'lake'],
#  ['Was', 'birthday', 'I', 'love', 'environment'],
#  ['The', 'natural', 'environment', 'lake', 'healing', 'fun'],
#  ['Staffs',
#   'friendly',
#   'patient',
#   'respectful',
#   'Rooms',
#   'bathroom',
#   'neat',
#   'food',
#   'delicious',
#   'wildwin',
#   'drink',
#   'make',
#   'die',
#   'last',
#   'least',
#   'place',
#   'surrounded',
#   'different',
#   'fruit',
#   'facing',
#   'lake',
#   'night',
#   'I',
#   'slept',
#   'side',
#   'listening',
#   'sound',
#   'lake',
#   'watching',
#   'star',
#   'moon',
#   'In',
#   'short',
#   'I',
#   'recommend',
#   'place',
#   'anyone',
#   'need',
#   'getaway',
#   'rest',
#   'relax'],
#  ['Great',
#   'weekend',
#   'getaway',
#   'easy',
#   'access',
#   'lake',
#   'nature',
#   'Good',
#   'customer',
#   'service',
#   'around',
#   'Seiba',
#   'Godwin',
#   'helpful',
#   'free',
#   'breakfast',
#   'par'],
#  ['Great', 'experience'],
#  ['Beautiful',
#   'ground',
#   'Willing',
#   'staff',
#   'intuition',
#   'clearly',
#   'trained',
#   'They',
#   'willing',
#   'bit',
#   'trust',
#   'everything',
#   'take',
#   'long',
#   'We',
#   'waited',
#   'half',
#   'hour',
#   'breakfast',
#   'longer',
#   'dinner',
#   'The',
#   'bedroom',
#   'We',
#   'blue',
#   'light',
#   'bathroom',
#   'strange',
#   'one',
#   'towel',
#   'knew',
#   'two',
#   'people',
#   'staying',
#   'room'],
#  ['Beautiful', 'serene', 'place', 'good', 'people', 'delicious', 'meal'],
#  ['Nice',
#   'place',
#   'enough',
#   'space',
#   'family',
#   'outing',
#   'A',
#   'view',
#   'Lake',
#   'Bosomtwe',
#   'But',
#   'road',
#   'location',
#   'encouraging'],
#  ['My',
#   'first',
#   'experience',
#   'June',
#   '2021',
#   'I',
#   'fell',
#   'love',
#   'place',
#   'The',
#   'water',
#   'tree',
#   'bird',
#   'different',
#   'colour',
#   'Oh',
#   'I',
#   'help',
#   'come',
#   'weekend',
#   'birthday',
#   'Oct',
#   '2nd',
#   '4th',
#   'It',
#   'magical',
#   'experience',
#   'I',
#   'swam',
#   'lake',
#   'Bosomtwe',
#   'first',
#   'time',
#   'I',
#   'meditation',
#   'lake',
#   '5am',
#   'bird',
#   'singing',
#   'sun',
#   'rising',
#   'calm',
#   'lake',
#   'The',
#   'owner',
#   'amazing',
#   'person',
#   'I',
#   'came',
#   'June',
#   'nice',
#   'phone',
#   'changed',
#   'It',
#   'feel',
#   'like',
#   'home',
#   'They',
#   'even',
#   'made',
#   'surprise',
#   'birthday',
#   'local',
#   'food',
#   'I',
#   'never',
#   'forget',
#   'weekend',
#   'The',
#   'time',
#   'I',
#   'saw',
#   'happy',
#   'client',
#   'came',
#   'food',
#   'refused',
#   'pay',
#   'anything',
#   'When',
#   'asked',
#   'pay',
#   'nicely',
#   'refused',
#   'finally',
#   'asked',
#   'leave',
#   'They',
#   'rained',
#   'insult',
#   'whole',
#   'place',
#   'I',
#   'never',
#   'seen',
#   'disrespect',
#   'rude',
#   'behaviour',
#   'If',
#   'food',
#   'eat',
#   'home',
#   'You',
#   'bring',
#   'food',
#   'restaurant',
#   'Why',
#   'good',
#   'business',
#   'Wildwin',
#   'amazing',
#   'gateway',
#   'nature',
#   'lover',
#   'owner',
#   'best',
#   'customer',
#   'service',
#   'client',
#   'I',
#   'seen',
#   'Anyways',
#   'I',
#   'already',
#   'booked',
#   'ticket',
#   'December',
#   '2021',
#   'Can',
#   'wait',
#   'see',
#   'blue',
#   'green',
#   'bird',
#   'swim',
#   'lake',
#   'Bosomtwe',
#   'I',
#   'could',
#   'live',
#   'life'],
#  ['Good', 'chef', 'Quiet', 'environment'],
#  ['I',
#   'really',
#   'love',
#   'place',
#   'We',
#   'refresher',
#   'course',
#   'indeed',
#   'refreshing',
#   'Very',
#   'nice',
#   'serene',
#   'environment'],
#  ['I',
#   'enjoyed',
#   'stay',
#   'nice',
#   'calm',
#   'environment',
#   'beautiful',
#   'caring',
#   'staff',
#   'I',
#   'wan',
#   'na',
#   'leave'],
#  ['Nice', 'place', 'village', 'setting'],
#  ['It', 'great', 'time', 'view', 'lake', 'breath', 'taking'],
#  ['I',
#   'loved',
#   'neat',
#   'serene',
#   'place',
#   'It',
#   'good',
#   'place',
#   'visit',
#   'want',
#   'run',
#   'away',
#   'chaos',
#   'city',
#   'And',
#   'customer',
#   'service',
#   'wonderful',
#   'well'],
#  ['Good',
#   'place',
#   'relax',
#   'unplug',
#   'Location',
#   'perfect',
#   'waiting',
#   'service',
#   'better',
#   'Will',
#   'recommend',
#   'place',
#   'looking',
#   'cool',
#   'place',
#   'get',
#   'away'],
#  ['Good', 'customer', 'care'],
#  ['We',
#   'really',
#   'enjoyed',
#   'Blue',
#   'Diamond',
#   'Easy',
#   'booking',
#   'great',
#   'communication',
#   'easy',
#   'find',
#   'really',
#   'bad',
#   'drive',
#   'Accra',
#   'Ordering',
#   'drink',
#   'meal',
#   'easy',
#   'WhatsApp',
#   'message',
#   'We',
#   'ordered',
#   'food',
#   'one',
#   'night',
#   'good',
#   'brought',
#   'bbq',
#   'second',
#   'night',
#   'I',
#   'like',
#   'allow',
#   'bring',
#   'food',
#   'The',
#   'room',
#   'super',
#   'basic',
#   'spent',
#   'time',
#   'beach',
#   'anyway',
#   'The',
#   'beach',
#   'clean',
#   'safe',
#   'swim',
#   'Decent',
#   'wave',
#   'boogie',
#   'boarding',
#   'even',
#   'surfing',
#   'decent',
#   'break',
#   'beach',
#   'bit',
#   'It',
#   'feel',
#   'good',
#   'find',
#   'place',
#   'escape',
#   'Accra',
#   'really',
#   'required',
#   'nothing',
#   'relax'],
#  ['Nice',
#   'clean',
#   'beach',
#   'getaway',
#   'Accra',
#   'Beautiful',
#   'shoreline',
#   'wave',
#   'body',
#   'surfing',
#   'close',
#   'quick',
#   'surfing',
#   'Resort',
#   'food',
#   'yummy',
#   'You',
#   'bring',
#   'charcoal',
#   'grill',
#   'food',
#   'well',
#   'Dmall',
#   'nighltly',
#   'bonfire',
#   'weekend',
#   'Small',
#   'clean',
#   'pool',
#   'Very',
#   'nice',
#   'spot',
#   'family',
#   'Drinks',
#   'thr',
#   'pricier',
#   'side',
#   'order',
#   'via',
#   'WhatsApp',
#   'convenient',
#   'Rooms',
#   'AC',
#   'mini',
#   'fridge',
#   'honestly',
#   'spend',
#   'much',
#   'time',
#   'thr',
#   'room',
#   'awake',
#   'No',
#   'store',
#   'nearby',
#   'bring',
#   'snack',
#   'maybe',
#   'water',
#   'Rooms',
#   'get',
#   'sandy',
#   'floor',
#   'mat',
#   'would',
#   'nice',
#   'inside',
#   'door',
#   'Manager',
#   'person',
#   'owner',
#   'German',
#   'lady',
#   'great',
#   'communication',
#   'skill'],
#  ['Blue',
#   'Diamond',
#   'Beach',
#   'Resort',
#   'life',
#   'upto',
#   'name',
#   'It',
#   'clean',
#   'beach',
#   'view',
#   'picture',
#   'perfect',
#   'Service',
#   'staff',
#   'polite',
#   'professional',
#   'approach',
#   'Long',
#   'walk',
#   '7',
#   '10',
#   'Km',
#   'beach',
#   'normal',
#   'villager',
#   'fishing',
#   'nearby',
#   'add',
#   'experience',
#   'local',
#   'people',
#   'culture',
#   'Ride',
#   'wave',
#   'get',
#   'board',
#   'Swings',
#   'hammock',
#   'coconut',
#   'tree',
#   'give',
#   'true',
#   'feel',
#   'beach',
#   'resort',
#   'Rooms',
#   'functional',
#   'well',
#   'maintained',
#   'Overall',
#   'excellent',
#   'place',
#   'Place',
#   'cosy',
#   'give',
#   'privacy',
#   'bottle',
#   '_',
#   '_',
#   'popping',
#   '_',
#   'corkclinking',
#   '_',
#   'glassesclinking',
#   '_',
#   'beer',
#   '_',
#   'mugstropical',
#   '_',
#   'drinkperson',
#   '_',
#   'surfingpalm',
#   '_',
#   'tree'],
#  ['A',
#   'lovely',
#   'hideout',
#   'hustle',
#   'bustle',
#   'city',
#   'life',
#   'An',
#   'escape',
#   'route',
#   'really',
#   'Serene',
#   'atmosphere',
#   'well',
#   'trimmed',
#   'lawn',
#   'Not',
#   'easy',
#   'location',
#   'though',
#   'get',
#   'love',
#   'A',
#   'neat',
#   'tidy',
#   'beach',
#   'life',
#   'guard',
#   'available',
#   'help',
#   'time',
#   'We',
#   'really',
#   'fun',
#   'host',
#   'amazing'],
#  ['Just',
#   'came',
#   'back',
#   '2',
#   'day',
#   'stay',
#   'getaway',
#   'Blue',
#   'Diamond',
#   'Firstly',
#   'communication',
#   '100',
#   'All',
#   'question',
#   'prior',
#   'booking',
#   'answered',
#   'well',
#   'time',
#   'WhatsApp',
#   'The',
#   'outside',
#   'Arriving',
#   'resort',
#   'easy',
#   'informed',
#   'arrival',
#   'someone',
#   'met',
#   'u',
#   'gate',
#   'As',
#   'drive',
#   'feel',
#   'peace',
#   'serenity',
#   'resort',
#   'It',
#   'clean',
#   'beach',
#   'well',
#   'kept',
#   'lovely',
#   'palm',
#   'tree',
#   'shaded',
#   'seating',
#   'table',
#   'beach',
#   'side',
#   'The',
#   'Rooms',
#   'We',
#   'booked',
#   'conjoining',
#   'family',
#   'room',
#   'I',
#   'must',
#   'say',
#   'room',
#   'big',
#   'disappointment',
#   'The',
#   'room',
#   'extremely',
#   'basic',
#   'especially',
#   'price',
#   'paid',
#   'felt',
#   'inclined',
#   'chill',
#   'beach',
#   'till',
#   'time',
#   'go',
#   'bed',
#   'room',
#   'depressing',
#   'dark',
#   'bare',
#   'furniture',
#   'Food',
#   'Ordering',
#   'food',
#   'easy',
#   'A',
#   'quick',
#   'whatsapp',
#   'get',
#   'quick',
#   'response',
#   'However',
#   'food',
#   '5',
#   '10',
#   'overpriced',
#   'quality',
#   'Ordered',
#   'dinner',
#   'day',
#   'arrived',
#   'decided',
#   'find',
#   'local',
#   'make',
#   'meal',
#   'rest',
#   'trip',
#   'Cocktails',
#   'nice',
#   'The',
#   'blue',
#   'diamond',
#   'hit',
#   'So',
#   'Last',
#   'Prayer',
#   'Overall',
#   'tranquility',
#   'place',
#   'make',
#   'room',
#   'food',
#   'I',
#   'giving',
#   '4'],
#  ['Stephanie',
#   'absolute',
#   'hostess',
#   'efficient',
#   'via',
#   'WhatsApp',
#   'provided',
#   'clear',
#   'communication',
#   'address',
#   'every',
#   'situation',
#   'The',
#   'food',
#   'great',
#   'everything',
#   'menu',
#   'WAS',
#   'available',
#   'loved',
#   'grilled',
#   'lobster',
#   'prawn',
#   'provencal',
#   'sea',
#   'food',
#   'linguine',
#   'beach',
#   'front',
#   'amazing',
#   'absolutely',
#   'loved',
#   'eating',
#   'meal',
#   'right',
#   'beach',
#   'front',
#   'falling',
#   'asleep',
#   'sound',
#   'sea',
#   'beach',
#   'resort',
#   'worth',
#   'visiting',
#   'room',
#   'basic',
#   'beach',
#   'worth',
#   'I',
#   'would'],
#  ['Beautiful', 'place'],
#  ['I', 'enjoy', 'red', '_', 'heart'],
#  ['Great',
#   'place',
#   'nice',
#   'getaway',
#   'Accra',
#   'great',
#   'service',
#   'nice',
#   'food',
#   'nice',
#   'scenery',
#   'beach',
#   'great',
#   'hostess',
#   'PS',
#   'ask',
#   'bonfire'],
#  ['Neat', 'beach', 'good', 'food', 'great', 'customer', 'service'],
#  ['We',
#   'spent',
#   'week',
#   'Xmil',
#   'coast',
#   'The',
#   'splendid',
#   'sea',
#   'well',
#   'served',
#   'equipped',
#   'beach',
#   'The',
#   'excellent',
#   'catering',
#   'fresh',
#   'fish',
#   'excellent',
#   'pizza',
#   'courtesy',
#   'cleaning',
#   'place'],
#  ['Very',
#   'lovely',
#   'place',
#   'Was',
#   '2015',
#   'today',
#   'great',
#   'Will',
#   'always',
#   'recommend'],
#  ['Any',
#   'reason',
#   'pick',
#   'call',
#   'strictly',
#   'reservation',
#   'keep',
#   'phone',
#   'close'],
#  ['Worst',
#   'place',
#   'visit',
#   'Never',
#   'seen',
#   'zero',
#   'hospitality',
#   'life',
#   'You',
#   'even',
#   'enter',
#   'gate',
#   'reservation',
#   'What',
#   'nonsense',
#   'Why',
#   'allow',
#   'walk',
#   'customer',
#   'coming',
#   'way',
#   'Accra',
#   'lunch',
#   'What',
#   'precious',
#   'Inside',
#   'walk',
#   'customer',
#   'turned',
#   'away',
#   'gate',
#   'Ridiculous',
#   'behaviour',
#   'lady',
#   'manager',
#   'spoke',
#   'phone',
#   'Will',
#   'never',
#   'visit',
#   'recommend',
#   'place',
#   'one'],
#  ...]

# %%
bigram_data
# Out:
# [['I wonderful',
#   'wonderful experience',
#   'experience Jonat',
#   'Jonat Hotel',
#   'Hotel Their',
#   'Their room',
#   'room new',
#   'new service',
#   'service top',
#   'top notch',
#   'notch I',
#   'I definitely',
#   'definitely recommend',
#   'recommend anyone',
#   'anyone visiting',
#   'visiting Cape',
#   'Cape Coast',
#   'Coast folded',
#   'folded _',
#   '_ hand',
#   'hand _',
#   '_ dark',
#   'dark _',
#   '_ skin',
#   'skin _',
#   '_ tone'],
#  ['I enjoyed',
#   'enjoyed stay',
#   'stay For',
#   'For serene',
#   'serene environment',
#   'environment choose',
#   'choose Jonat',
#   'Jonat Hotel'],
#  ['The couple',
#   'couple time',
#   'time I',
#   'I peaceful',
#   'peaceful time',
#   'time I',
#   'I really',
#   'really enjoyed',
#   'enjoyed serenity',
#   'serenity calm',
#   'calm ambiance',
#   'ambiance place',
#   'place Really',
#   'Really nice',
#   'nice room',
#   'room affordable',
#   'affordable well'],
#  ['Everything nice',
#   'nice super',
#   'super clean',
#   'clean thumb',
#   'thumb _',
#   '_ upthumbs',
#   'upthumbs _',
#   '_ upthumbs',
#   'upthumbs _'],
#  ['I splendid',
#   'splendid stay',
#   'stay Jonat',
#   'Jonat Hotel',
#   'Hotel It',
#   'It might',
#   'might new',
#   'new service',
#   'service great',
#   'great food',
#   'food delish'],
#  ['Staff provide',
#   'provide warm',
#   'warm reception',
#   'reception neat',
#   'neat room',
#   'room room',
#   'room service',
#   'service available'],
#  ['It nice',
#   'nice place',
#   'place stay',
#   'stay Pretty',
#   'Pretty clean',
#   'clean price',
#   'price room',
#   'room great',
#   'great They',
#   'They also',
#   'also serve',
#   'serve everyone',
#   'everyone breakfast',
#   'breakfast plus'],
#  ['The Drowaa',
#   'Drowaa Plus',
#   'Plus Hotel',
#   'Hotel go',
#   'go place',
#   'place stop',
#   'stop night',
#   'night sleep',
#   'sleep Great',
#   'Great design',
#   'design room',
#   'room great',
#   'great ventilation',
#   'ventilation AC',
#   'AC Fan',
#   'Fan room',
#   'room etc',
#   'etc I',
#   'I recommend',
#   'recommend place',
#   'place organizing',
#   'organizing event',
#   'event looking',
#   'looking great',
#   'great place',
#   'place lodge'],
#  ['Very quite', 'quite location', 'location Cape', 'Cape Coast'],
#  ['In town', 'town around', 'around IBB'],
#  ['The room',
#   'room beautiful',
#   'beautiful Elegant',
#   'Elegant design',
#   'design But',
#   'But washroom',
#   'washroom poor',
#   'poor condition',
#   'condition And',
#   'And poor',
#   'poor customer',
#   'customer service'],
#  ['drink pub',
#   'pub place',
#   'place hold',
#   'hold sentimental',
#   'sentimental value',
#   'value well',
#   'well old',
#   'old junior',
#   'junior high',
#   'high half',
#   'half kilometre',
#   'kilometre away',
#   'away friendly',
#   'friendly accommodating',
#   'accommodating staff'],
#  ['Close beach'],
#  ['Not good',
#   'good condition',
#   'condition moment',
#   'moment It',
#   'It left',
#   'left without',
#   'without form',
#   'form maintenance'],
#  ['Its nice', 'nice place'],
#  ['This great',
#   'great establishment',
#   'establishment striving',
#   'striving part',
#   'part community',
#   'community This',
#   'This place',
#   'place alll',
#   'alll type',
#   'type loving',
#   'loving event',
#   'event Thanks',
#   'Thanks everyone',
#   'everyone community'],
#  ['We spent', 'spent saturday', 'saturday place', 'place magic'],
#  ['Unique conjunction',
#   'conjunction pristine',
#   'pristine beach',
#   'beach good',
#   'good food'],
#  ['Wonderfull nothing', 'nothing else'],
#  ['Situated paradise',
#   'paradise place',
#   'place Very',
#   'Very quiet',
#   'quiet beautiful',
#   'beautiful landscape',
#   'landscape Access',
#   'Access easy',
#   'easy good',
#   'good never',
#   'never easy'],
#  ['Excellent place',
#   'place thumb',
#   'thumb _',
#   '_ upbeaming',
#   'upbeaming _',
#   '_ face',
#   'face _',
#   '_ _',
#   '_ smiling',
#   'smiling _',
#   '_ eye'],
#  ['Magnificent place',
#   'place comfortable',
#   'comfortable accommodation',
#   'accommodation taste',
#   'taste refined',
#   'refined kitchen',
#   'kitchen careful',
#   'careful welcome'],
#  ['Fantas Folly',
#   'Folly favourite',
#   'favourite place',
#   'place spend',
#   'spend relaxing',
#   'relaxing time',
#   'time Philip',
#   'Philip Fanta',
#   'Fanta wonderful',
#   'wonderful host',
#   'host always',
#   'always spend',
#   'spend time',
#   'time make',
#   'make feel',
#   'feel welcome',
#   'welcome The',
#   'The food',
#   'food great',
#   'great good',
#   'good value',
#   'value money',
#   'money The',
#   'The room',
#   'room comfortable',
#   'comfortable well',
#   'well thought',
#   'thought The',
#   'The location',
#   'location piece',
#   'piece Paradise',
#   'Paradise Earth',
#   'Earth We',
#   'We lot',
#   'lot wonderful',
#   'wonderful memory',
#   'memory time',
#   'time spent',
#   'spent Fantas',
#   'Fantas Highly',
#   'Highly recommended'],
#  ['No wish',
#   'wish remains',
#   'remains unfulfilled',
#   'unfulfilled A',
#   'A little',
#   'little paradise',
#   'paradise earth'],
#  ['Very poor',
#   'poor service',
#   'service I',
#   'I received',
#   'received fantas',
#   'fantas folly',
#   'folly Food',
#   'Food took',
#   'took 2',
#   '2 hour',
#   'hour waiter',
#   'waiter smart',
#   'smart They',
#   'They could',
#   'could even',
#   'even recommend',
#   'recommend listed',
#   'listed food',
#   'food menu',
#   'menu best',
#   'best one',
#   'one waitress',
#   'waitress mentioned',
#   'mentioned recommend',
#   'recommend allowed',
#   'allowed Their',
#   'Their appearance',
#   'appearance also',
#   'also Imagine',
#   'Imagine going',
#   'going long',
#   'long journey',
#   'journey given',
#   'given poor',
#   'poor service',
#   'service heart',
#   'heart breaking'],
#  ['This worse',
#   'worse place',
#   'place I',
#   'I ever',
#   'ever They',
#   'They rude',
#   'rude service',
#   'service bad',
#   'bad The',
#   'The owner',
#   'owner wife',
#   'wife wanted',
#   'wanted fight',
#   'fight costumer',
#   'costumer never',
#   'never go',
#   'go want',
#   'want good',
#   'good time'],
#  ['An idyllic',
#   'idyllic place',
#   'place European',
#   'European cuisine',
#   'cuisine unfortunately',
#   'unfortunately difficult',
#   'difficult achieve',
#   'achieve Use',
#   'Use road',
#   'road car',
#   'car possible'],
#  ['Nice place',
#   'place quiet',
#   'quiet peaceful',
#   'peaceful amazing',
#   'amazing view',
#   'view The',
#   'The minus',
#   'minus water',
#   'water shower',
#   'shower tap',
#   'tap clean',
#   'clean used',
#   'used big',
#   'big minus'],
#  ['This best',
#   'best get',
#   'get away',
#   'away hectic',
#   'hectic traffic',
#   'traffic busyness',
#   'busyness dirty',
#   'dirty beach',
#   'beach Accra',
#   'Accra Though',
#   'Though said',
#   'said road',
#   'road lead',
#   'lead heaven',
#   'heaven narrow',
#   'narrow get',
#   'get ready',
#   'ready narrow',
#   'narrow drive',
#   'drive haha',
#   'haha worth',
#   'worth end',
#   'end Clean',
#   'Clean environment',
#   'environment good',
#   'good group',
#   'group good',
#   'good couple',
#   'couple spend',
#   'spend quality',
#   'quality time',
#   'time together',
#   'together Good',
#   'Good family',
#   'family vacation',
#   'vacation good',
#   'good kid',
#   'kid good',
#   'good long',
#   'long walk',
#   'walk beach',
#   'beach I',
#   'I strongly',
#   'strongly recommend'],
#  ['Very nice', 'nice beach'],
#  ['Amazing stay', 'stay mouth', 'mouth watering', 'watering food'],
#  ['Great food',
#   'food beach',
#   'beach relaxing',
#   'relaxing Awesome',
#   'Awesome place',
#   'place getaway',
#   'getaway road',
#   'road bumpy',
#   'bumpy prepared',
#   'prepared going',
#   'going definitely',
#   'definitely gem',
#   'gem smiling',
#   'smiling _',
#   '_ face',
#   'face _',
#   '_ _',
#   '_ hearteyes',
#   'hearteyes OK',
#   'OK _',
#   '_ hand',
#   'hand dark',
#   'dark _',
#   '_ skin',
#   'skin _',
#   '_ tone'],
#  ['The worst',
#   'worst ever',
#   'ever customer',
#   'customer service',
#   'service I',
#   'I ever',
#   'ever experienced',
#   'experienced I',
#   'I checked',
#   'checked ordered',
#   'ordered two',
#   'two meal',
#   'meal wife',
#   'wife surprised',
#   'surprised bottle',
#   'bottle wine',
#   'wine I',
#   'I requested',
#   'requested glass',
#   'glass brought',
#   'brought manager',
#   'manager owner',
#   'owner came',
#   'came request',
#   'request 29ghs',
#   '29ghs bringing',
#   'bringing wine',
#   'wine guest',
#   'guest accommodated',
#   'accommodated I',
#   'I objected',
#   'objected poured',
#   'poured wine',
#   'wine glass',
#   'glass away',
#   'away took',
#   'took glass',
#   'glass And',
#   'And told',
#   'told check',
#   'check leave',
#   'leave I',
#   'I want',
#   'want I'],
#  ['Best beach',
#   'beach resort',
#   'resort takoradi',
#   'takoradi clean',
#   'clean beach',
#   'beach helpful',
#   'helpful personal'],
#  ['A peaceful',
#   'peaceful surrounded',
#   'surrounded overloaded',
#   'overloaded package',
#   'package nature',
#   'nature tree',
#   'tree bird',
#   'bird sky',
#   'sky sun',
#   'sun moon',
#   'moon star',
#   'star course',
#   'course ocean',
#   'ocean Amazing',
#   'Amazing Thank',
#   'Thank Fanta',
#   'Fanta Philippe',
#   'Philippe Janet',
#   'Janet Chef',
#   'Chef Deborah',
#   'Deborah Ebo',
#   'Ebo whole',
#   'whole team',
#   'team You',
#   'You make',
#   'make Fantas',
#   'Fantas Folly',
#   'Folly living',
#   'living I',
#   'I coming',
#   'coming back'],
#  ['Great meal', 'meal peaceful', 'peaceful atmosphere'],
#  ['Paradise earth', 'earth road', 'road difficult'],
#  ['Warm reception',
#   'reception Philip',
#   'Philip team',
#   'team Always',
#   'Always ready',
#   'ready listen',
#   'listen serve',
#   'serve guest',
#   'guest well',
#   'well For',
#   'For meal',
#   'meal love'],
#  ['One Cleanest',
#   'Cleanest Beaches',
#   'Beaches beach',
#   'beach _',
#   '_ _',
#   '_ umbrella',
#   'umbrella Great',
#   'Great food',
#   'food fresh',
#   'fresh sea',
#   'sea water',
#   'water _',
#   '_ wave',
#   'wave Ambiance',
#   'Ambiance TOP',
#   'TOP _',
#   '_ arrow',
#   'arrow notch',
#   'notch Moderate',
#   'Moderate pricing'],
#  ['Really nice',
#   'nice Proprio',
#   'Proprio Franc',
#   'Franc Comtois',
#   'Comtois Heavenly',
#   'Heavenly beach'],
#  ['An amazing', 'amazing place', 'place weekend', 'weekend getaway'],
#  ['An fantastic',
#   'fantastic place',
#   'place serene',
#   'serene atmosphere',
#   'atmosphere located',
#   'located right',
#   'right Butre',
#   'Butre beach',
#   'beach It',
#   'It perfect',
#   'perfect place',
#   'place calm',
#   'calm enjoy',
#   'enjoy The',
#   'The resort',
#   'resort built',
#   'built great',
#   'great sense',
#   'sense design',
#   'design atmosphere',
#   'atmosphere nice',
#   'nice couple',
#   'couple taking',
#   'taking good',
#   'good care',
#   'care I',
#   'I really',
#   'really loved',
#   'loved place',
#   'place The',
#   'The bad',
#   'bad thing',
#   'thing internet',
#   'internet connection',
#   'connection weak',
#   'weak depending',
#   'depending internet',
#   'internet perfect',
#   'perfect place'],
#  ['Nestled among',
#   'among tropical',
#   'tropical vegetation',
#   'vegetation sound',
#   'sound Atlantic',
#   'Atlantic Ocean',
#   'Ocean rolling',
#   'rolling shore',
#   'shore feel',
#   'feel far',
#   'far away',
#   'away hustle',
#   'hustle bustle',
#   'bustle yet',
#   'yet le',
#   'le hour',
#   'hour drive',
#   'drive city',
#   'city Takoradi',
#   'Takoradi Caution',
#   'Caution Road',
#   'Road rough',
#   'rough Consider',
#   'Consider Pick',
#   'Pick van',
#   'van Beautiful',
#   'Beautiful sea',
#   'sea beach',
#   'beach photogenic',
#   'photogenic view',
#   'view Clean',
#   'Clean area',
#   'area water',
#   'water The',
#   'The beauty',
#   'beauty place',
#   'place small',
#   'small rocky',
#   'rocky mountain',
#   'mountain mountain',
#   'mountain walk',
#   'walk 3',
#   '3 4',
#   '4 minute',
#   'minute click',
#   'click picture',
#   'picture video',
#   'video Adding',
#   'Adding picture',
#   'picture water',
#   'water green',
#   'green grey',
#   'grey yellow',
#   'yellow lol',
#   'lol mix',
#   'mix colour',
#   'colour Make',
#   'Make sure',
#   'sure order',
#   'order food',
#   'food advance',
#   'advance take',
#   'take 2',
#   '2 hour',
#   'hour saying',
#   'saying 5',
#   '5 minute',
#   'minute I',
#   'I omelette',
#   'omelette bread',
#   'bread waited',
#   'waited 1',
#   '1 one',
#   'one hour'],
#  ['An excellent',
#   'excellent hideaway',
#   'hideaway vacation',
#   'vacation spot',
#   'spot couple',
#   'couple want',
#   'want get',
#   'get away',
#   'away busy',
#   'busy city',
#   'city atmosphere',
#   'atmosphere A',
#   'A serene',
#   'serene area',
#   'area beautiful',
#   'beautiful beach',
#   'beach The',
#   'The food',
#   'food great',
#   'great take',
#   'take long',
#   'long time',
#   'time prepare',
#   'prepare I',
#   'I recommend',
#   'recommend ordering',
#   'ordering early',
#   'early enough',
#   'enough disappointed',
#   'disappointed One',
#   'One need',
#   'need note',
#   'note however',
#   'however resort',
#   'resort far',
#   'far away',
#   'away main',
#   'main road',
#   'road The',
#   'The road',
#   'road generally',
#   'generally smooth',
#   'smooth though',
#   'though We',
#   'We could',
#   'could find',
#   'find sign',
#   'sign main',
#   'main junction',
#   'junction missed',
#   'missed turn',
#   'turn got',
#   'got lost',
#   'lost Be',
#   'Be sure',
#   'sure ask',
#   'ask direction',
#   'direction You',
#   'You spend',
#   'spend 20',
#   '20 30',
#   '30 min',
#   'min drive',
#   'drive main',
#   'main road',
#   'road dirt',
#   'dirt road',
#   'road get',
#   'get resort',
#   'resort After',
#   'After main',
#   'main junction',
#   'junction sign',
#   'sign junction',
#   'junction find',
#   'find way',
#   'way I',
#   'I recommend',
#   'recommend resort',
#   'resort couple',
#   'couple want',
#   'want quiet',
#   'quiet low',
#   'low key',
#   'key affordable',
#   'affordable vacation',
#   'vacation Just',
#   'Just make',
#   'make sure',
#   'sure 4x4',
#   '4x4 face',
#   'face _',
#   '_ _',
#   '_ tear',
#   'tear _',
#   '_ _',
#   '_ joy'],
#  ['Wonderful experience', 'experience middle', 'middle nowhere'],
#  ['Always one',
#   'one fav',
#   'fav place',
#   'place visit',
#   'visit Food',
#   'Food great',
#   'great beach',
#   'beach always',
#   'always clean',
#   'clean Rooms',
#   'Rooms affordable',
#   'affordable clean'],
#  ['Serene atmosphere',
#   'atmosphere perfect',
#   'perfect OK',
#   'OK _',
#   '_ hand',
#   'hand _',
#   '_ mediumdark',
#   'mediumdark _',
#   '_ skin',
#   'skin _',
#   '_ tone',
#   'tone get',
#   'get away',
#   'away trip',
#   'trip wonderful',
#   'wonderful people',
#   'people hotel',
#   'hotel Love',
#   'Love place',
#   'place Would',
#   'Would always',
#   'always choose',
#   'choose place'],
#  ['It serene', 'serene Atmosphere'],
#  ['Amazing getaway',
#   'getaway everyone',
#   'everyone Beautiful',
#   'Beautiful sunset',
#   'sunset serene',
#   'serene atmosphere'],
#  ['Sure wonderful', 'wonderful place', 'place enjoy', 'enjoy breeze'],
#  ['To honest',
#   'honest visited',
#   'visited place',
#   'place find',
#   'find time',
#   'time go',
#   'go relax'],
#  ['Perfect value',
#   'value money',
#   'money Clean',
#   'Clean room',
#   'room AC',
#   'AC nice',
#   'nice guy',
#   'guy reception'],
#  ['Has beautiful',
#   'beautiful view',
#   'view estuary',
#   'estuary service',
#   'service facility',
#   'facility commendable'],
#  ['Good atmosphere',
#   'atmosphere great',
#   'great environment',
#   'environment right',
#   'right place',
#   'place Ankobra',
#   'Ankobra river',
#   'river join',
#   'join sea',
#   'sea good',
#   'good service',
#   'service There',
#   'There room',
#   'room improvement',
#   'improvement however'],
#  ['A wonderful',
#   'wonderful experience',
#   'experience Neat',
#   'Neat environment',
#   'environment courteous',
#   'courteous worker',
#   'worker food',
#   'food A'],
#  ['Nice serene', 'serene environment', 'environment relaxing'],
#  ['Loved serene',
#   'serene atmosphere',
#   'atmosphere Loved',
#   'Loved waking',
#   'waking sound',
#   'sound rumbling',
#   'rumbling wave',
#   'wave Relaxing',
#   'Relaxing max',
#   'max Don',
#   'Don miss',
#   'miss sunset',
#   'sunset sunrise',
#   'sunrise The',
#   'The food',
#   'food breakfast',
#   'breakfast dinner',
#   'dinner superb',
#   'superb I',
#   'I definitely'],
#  ['The Beach',
#   'Beach Ankobra',
#   'Ankobra view',
#   'view best',
#   'best room',
#   'room stay',
#   'stay privacy',
#   'privacy leisure'],
#  ['Ankobra Bridge',
#   'Bridge Hotel',
#   'Hotel amazing',
#   'amazing place',
#   'place Nice',
#   'Nice facility',
#   'facility room',
#   'room serene',
#   'serene environment',
#   'environment The',
#   'The food',
#   'food great',
#   'great Rooms',
#   'Rooms range',
#   'range Ghc200',
#   'Ghc200 400',
#   '400 Great',
#   'Great place',
#   'place get',
#   'get city',
#   'city relax',
#   'relax It',
#   'It great'],
#  ['Home away', 'away home'],
#  ['heart _',
#   '_ exclamation',
#   'exclamation heart',
#   'heart _',
#   '_ exclamation',
#   'exclamation heart',
#   'heart _',
#   '_ exclamation',
#   'exclamation heart',
#   'heart _',
#   '_ exclamation',
#   'exclamation heart',
#   'heart _',
#   '_ exclamation',
#   'exclamation food',
#   'food Room',
#   'Room mouth',
#   'mouth mouth',
#   'mouth mouth',
#   'mouth mouth',
#   'mouth mouth',
#   'mouth mouth'],
#  ['Very nice', 'nice place', 'place relaxation'],
#  ['One best',
#   'best place',
#   'place relax',
#   'relax western',
#   'western part',
#   'part Ghana'],
#  ['Great experience'],
#  ['Excellent amenity',
#   'amenity room',
#   'room smell',
#   'smell good',
#   'good breakfast',
#   'breakfast top',
#   'top notch',
#   'notch Will',
#   'Will recommend',
#   'recommend hotel'],
#  ['Its close',
#   'close ankobra',
#   'ankobra River',
#   'River calm',
#   'calm refreshing',
#   'refreshing staff',
#   'staff welcoming',
#   'welcoming friendly',
#   'friendly food',
#   'food great'],
#  ['Passed briefly',
#   'briefly Excellent',
#   'Excellent service',
#   'service Good',
#   'Good location'],
#  ['Comfortable friendly', 'friendly staff'],
#  ['The place', 'place amazing', 'amazing guy', 'guy got', 'got ta', 'ta go'],
#  ['Nice place', 'place good', 'good customer', 'customer service'],
#  [],
#  ['Nice ambiance'],
#  ['Nice neat', 'neat new'],
#  ['Green Zion',
#   'Zion Garden',
#   'Garden host',
#   'host Ellis',
#   'Ellis left',
#   'left imprint',
#   'imprint heart',
#   'heart I',
#   'I never',
#   'never forget',
#   'forget Thank'],
#  ['Green Zion',
#   'Zion Garden',
#   'Garden actual',
#   'actual paradise',
#   'paradise The',
#   'The various',
#   'various little',
#   'little large',
#   'large room',
#   'room like',
#   'like natural',
#   'natural hobbit',
#   'hobbit house',
#   'house No',
#   'No Aircon',
#   'Aircon sure',
#   'sure fan',
#   'fan grand',
#   'grand There',
#   'There tree',
#   'tree house',
#   'house The',
#   'The garden',
#   'garden immaculate',
#   'immaculate green',
#   'green indeed',
#   'indeed Beautiful',
#   'Beautiful flower',
#   'flower plant',
#   'plant tree',
#   'tree There',
#   'There bird',
#   'bird dragonfly',
#   'dragonfly friendly',
#   'friendly goat',
#   'goat couple',
#   'couple friendly',
#   'friendly dog',
#   'dog It',
#   'It right',
#   'right beach',
#   'beach Ellis',
#   'Ellis beautifully',
#   'beautifully decorated',
#   'decorated wooden',
#   'wooden bar',
#   'bar He',
#   'He feed',
#   'feed delicious',
#   'delicious veggie',
#   'veggie food',
#   'food serve',
#   'serve tasty',
#   'tasty drink',
#   'drink He',
#   'He got',
#   'got best',
#   'best smile',
#   'smile growing',
#   'growing _',
#   '_ heartThere',
#   'heartThere seat',
#   'seat shaded',
#   'shaded bed',
#   'bed ocean',
#   'ocean The',
#   'The beach',
#   'beach clean',
#   'clean rubbish',
#   'rubbish The',
#   'The cleanest',
#   'cleanest I',
#   'I seen',
#   'seen Ghana',
#   'Ghana I',
#   'I stayed',
#   'stayed longer',
#   'longer I',
#   'I go',
#   'go back',
#   'back one',
#   'one day',
#   'day The',
#   'The village',
#   'village Butre',
#   'Butre across',
#   'across rickety',
#   'rickety Indiana',
#   'Indiana Jones',
#   'Jones style',
#   'style bridge',
#   'bridge bustling',
#   'bustling lively',
#   'lively fishy',
#   'fishy place',
#   'place The',
#   'The child',
#   'child ran',
#   'ran fistbumps',
#   'fistbumps hi',
#   'hi five',
#   'five Goats',
#   'Goats chicken',
#   'chicken dog',
#   'dog everywhere',
#   'everywhere We',
#   'We got',
#   'got motorbike',
#   'motorbike Asa',
#   'Asa Baako',
#   'Baako Festival',
#   'Festival Busua',
#   'Busua walked',
#   'walked back',
#   'back full',
#   'full moon',
#   'moon illuminating',
#   'illuminating way',
#   'way across',
#   'across beach',
#   'beach headtorches',
#   'headtorches helping',
#   'helping path',
#   'path bush',
#   'bush hilly',
#   'hilly headland',
#   'headland bird',
#   'bird frog',
#   'frog insect',
#   'insect providing',
#   'providing soundtrack',
#   'soundtrack A',
#   'A magical',
#   'magical special',
#   'special place',
#   'place seems',
#   'seems growing',
#   'growing even',
#   'even better',
#   'better new',
#   'new build',
#   'build idea',
#   'idea Loved',
#   'Loved smiling',
#   'smiling _',
#   '_ face',
#   'face _',
#   '_ _',
#   '_ smiling',
#   'smiling _',
#   '_ eye'],
#  ['I crossed',
#   'crossed rendomly',
#   'rendomly Green',
#   'Green garden',
#   'garden eco',
#   'eco lodge',
#   'lodge I',
#   'I trekking',
#   'trekking coast',
#   'coast I',
#   'I met',
#   'met Ellis',
#   'Ellis positive',
#   'positive funny',
#   'funny man',
#   'man We',
#   'We ate',
#   'ate together',
#   'together good',
#   'good fun',
#   'fun He',
#   'He show',
#   'show lodge',
#   'lodge clean',
#   'clean nice',
#   'nice place',
#   'place The',
#   'The garden',
#   'garden crazy',
#   'crazy good',
#   'good moment',
#   'moment vibe'],
#  ['Very green',
#   'green space',
#   'space cool',
#   'cool environment',
#   'environment Great',
#   'Great gardening',
#   'gardening eco',
#   'eco lodge',
#   'lodge experience'],
#  ['They OM',
#   'OM sign',
#   'sign outside',
#   'outside board',
#   'board You',
#   'You see',
#   'see cat',
#   'cat around',
#   'around 10',
#   '10 minute',
#   'minute drive',
#   'drive fantas',
#   'fantas folly',
#   'folly He',
#   'He know',
#   'know cook',
#   'cook indian',
#   'indian food',
#   'food The',
#   'The man',
#   'man offer',
#   'offer everything',
#   'everything want',
#   'want Posting',
#   'Posting picture',
#   'picture review',
#   'review Offering',
#   'Offering free',
#   'free private',
#   'private parking',
#   'parking onsite',
#   'onsite Green',
#   'Green Zion',
#   'Zion Garden',
#   'Garden offer',
#   'offer pet',
#   'pet friendly',
#   'friendly accommodation',
#   'accommodation Butre',
#   'Butre The',
#   'The bed',
#   'bed breakfast',
#   'breakfast lawn',
#   'lawn hammock',
#   'hammock guest',
#   'guest located',
#   'located garden',
#   'garden Guests',
#   'Guests enjoy',
#   'enjoy meal',
#   'meal outside',
#   'outside garden',
#   'garden restaurant',
#   'restaurant serf',
#   'serf local',
#   'local Indian',
#   'Indian International',
#   'International cuisine',
#   'cuisine The',
#   'The property',
#   'property onsite',
#   'onsite bar',
#   'bar garden',
#   'garden also',
#   'also coffee',
#   'coffee shop',
#   'shop You',
#   'You find',
#   'find shared',
#   'shared lounge',
#   'lounge property',
#   'property Thai',
#   'Thai yoga',
#   'yoga massage',
#   'massage treatment',
#   'treatment available'],
#  ['Paradise Ghana'],
#  ['Wooow special', 'special place', 'place incredible'],
#  ['I almost',
#   'almost want',
#   'want recommend',
#   'recommend green',
#   'green zion',
#   'zion garden',
#   'garden Hidden',
#   'Hidden gem',
#   'gem Moreover',
#   'Moreover Ellis',
#   'Ellis host',
#   'host honestly',
#   'honestly best',
#   'best Guy',
#   'Guy met',
#   'met Ghana',
#   'Ghana If',
#   'If want',
#   'want best',
#   'best round',
#   'round experience',
#   'experience Ghana',
#   'Ghana visit',
#   'visit Ellis',
#   'Ellis place',
#   'place welcome',
#   'welcome Zion',
#   'Zion garden'],
#  ['Affable owner',
#   'owner good',
#   'good food',
#   'food great',
#   'great relax',
#   'relax All',
#   'All sited',
#   'sited beautiful',
#   'beautiful skilfully',
#   'skilfully elaborated',
#   'elaborated garden',
#   'garden Will',
#   'Will come'],
#  ['A place',
#   'place amazing',
#   'amazing garden',
#   'garden Ellis',
#   'Ellis great',
#   'great job',
#   'job care',
#   'care guest',
#   'guest good',
#   'good food',
#   'food clean',
#   'clean room'],
#  ['Amazing place', 'place butre'],
#  ['Super lovely',
#   'lovely place',
#   'place Set',
#   'Set serene',
#   'serene beautiful',
#   'beautiful ambiance',
#   'ambiance one',
#   'one Ghana',
#   'Ghana beautiful',
#   'beautiful coastline',
#   'coastline Green',
#   'Green Zion',
#   'Zion Garden',
#   'Garden perfect',
#   'perfect location',
#   'location good',
#   'good relaxation',
#   'relaxation good',
#   'good peaceful',
#   'peaceful unwinding',
#   'unwinding My',
#   'My host',
#   'host Ellis',
#   'Ellis super',
#   'super amazing',
#   'amazing A',
#   'A super',
#   'super friendly',
#   'friendly hardworking',
#   'hardworking open',
#   'open minded',
#   'minded gentle',
#   'gentle rasta',
#   'rasta man',
#   'man His',
#   'His vegetarian',
#   'vegetarian cooking',
#   'cooking top',
#   'top notch',
#   'notch His',
#   'His knowledge',
#   'knowledge sharing',
#   'sharing experience',
#   'experience great',
#   'great He',
#   'He prepared',
#   'prepared bonfire',
#   'bonfire kind',
#   'kind good',
#   'good drummer',
#   'drummer pretty',
#   'pretty please',
#   'please let',
#   'let sing',
#   'sing The',
#   'The various',
#   'various lodge',
#   'lodge dormitory',
#   'dormitory upper',
#   'upper deck',
#   'deck tree',
#   'tree house',
#   'house neat',
#   'neat lovely',
#   'lovely awash',
#   'awash beautiful',
#   'beautiful color',
#   'color traditional',
#   'traditional fabric',
#   'fabric Bonus',
#   'Bonus request',
#   'request coconut',
#   'coconut get',
#   'get fresh',
#   'fresh one',
#   'one cut',
#   'cut tree',
#   'tree right',
#   'right face',
#   'face I',
#   'I sure'],
#  ['We passed',
#   'passed dinner',
#   'dinner 06',
#   '06 2018',
#   '2018 atmosphere',
#   'atmosphere restaurant',
#   'restaurant lounge',
#   'lounge indescribable',
#   'indescribable After',
#   'After fantastic',
#   'fantastic food',
#   'food grabbed',
#   'grabbed Djembe',
#   'Djembe guitar',
#   'guitar sang',
#   'sang together',
#   'together host',
#   'host moonlight',
#   'moonlight garden',
#   'garden late',
#   'late night',
#   'night Nice',
#   'Nice place',
#   'place An',
#   'An unforgettable',
#   'unforgettable evening'],
#  ['Green zion',
#   'zion garden',
#   'garden offer',
#   'offer nice',
#   'nice stay',
#   'stay great',
#   'great garden',
#   'garden djungle',
#   'djungle feeling',
#   'feeling friendly',
#   'friendly host',
#   'host gladly',
#   'gladly show',
#   'show around',
#   'around area',
#   'area Pancakes',
#   'Pancakes recommended'],
#  ['A friend',
#   'friend wedding',
#   'wedding refreshment',
#   'refreshment held',
#   'held venue',
#   'venue Warm',
#   'Warm reception',
#   'reception given',
#   'given u'],
#  ['Very fun',
#   'fun see',
#   'see distance',
#   'distance Agartha',
#   'Agartha Overlords',
#   'Overlords Da',
#   'Da God',
#   'God Squad'],
#  ['The customer',
#   'customer service',
#   'service excellent',
#   'excellent worker',
#   'worker friendly',
#   'friendly give',
#   'give wonderful',
#   'wonderful reception',
#   'reception room',
#   'room clean',
#   'clean I',
#   'I lodge'],
#  ['It best', 'best Spend', 'Spend night', 'night love', 'love It', 'It great'],
#  ['A great', 'great place'],
#  ['Good environment'],
#  ['The pool',
#   'pool side',
#   'side spacious',
#   'spacious parking',
#   'parking space',
#   'space say',
#   'say reception',
#   'reception security',
#   'security give',
#   'give entry',
#   'entry premise',
#   'premise say'],
#  ['Nice hotel', 'hotel An', 'An ok', 'ok rest', 'rest place'],
#  ['The hotel',
#   'hotel nice',
#   'nice beautiful',
#   'beautiful I',
#   'I always',
#   'always recommend',
#   'recommend anyone'],
#  ['Is nice', 'nice plce', 'plce bushy', 'bushy area'],
#  ['Very cool', 'cool environment'],
#  ['Simply home', 'home away', 'away home'],
#  ['Love hotel'],
#  ['Very hospitable',
#   'hospitable staff',
#   'staff helpful',
#   'helpful improve',
#   'improve restaurant',
#   'restaurant service'],
#  ['Most quiet',
#   'quiet perfect',
#   'perfect place',
#   'place stay',
#   'stay away',
#   'away busy',
#   'busy street',
#   'street tadi'],
#  ['Nice place', 'place rest'],
#  ['Good service'],
#  ['Nice cheap', 'cheap place', 'place kindly', 'kindly team'],
#  ['It cool',
#   'cool place',
#   'place great',
#   'great view',
#   'view Very',
#   'Very serene'],
#  ['Very nice', 'nice affordable', 'affordable place', 'place visit'],
#  ['Great place'],
#  ['The amenity',
#   'amenity room',
#   'room poolside',
#   'poolside restaurant',
#   'restaurant etc',
#   'etc world',
#   'world class',
#   'class Their',
#   'Their meal',
#   'meal equally',
#   'equally tasty',
#   'tasty cost',
#   'cost Ghc100',
#   'Ghc100 9',
#   '9 10',
#   '10 They',
#   'They amiable',
#   'amiable staff'],
#  ['The experience',
#   'experience Alliance',
#   'Alliance super',
#   'super good',
#   'good OK',
#   'OK _',
#   '_ hand',
#   'hand beautiful',
#   'beautiful environment',
#   'environment service',
#   'service importantly',
#   'importantly staff',
#   'staff To',
#   'To mention',
#   'mention Hnel',
#   'Hnel 5',
#   '5 star',
#   'star manager',
#   'manager sense',
#   'sense humour',
#   'humour HUMILITY',
#   'HUMILITY Samuel',
#   'Samuel ever',
#   'ever smiling',
#   'smiling dude',
#   'dude service',
#   'service etc',
#   'etc Kafui',
#   'Kafui Front',
#   'Front Desk',
#   'Desk personnel',
#   'personnel swag',
#   'swag Jacqueline',
#   'Jacqueline calm',
#   'calm wonderful',
#   'wonderful person',
#   'person ensuring',
#   'ensuring everything',
#   'everything OK',
#   'OK Thanks',
#   'Thanks smiling',
#   'smiling _',
#   '_ face'],
#  ['It quiet',
#   'quiet hotel',
#   'hotel room',
#   'room need',
#   'need cleaning',
#   'cleaning The',
#   'The furniture',
#   'furniture bathroom',
#   'bathroom outdated'],
#  ['Absolutely exquisite',
#   'exquisite nestled',
#   'nestled beach',
#   'beach road',
#   'road area',
#   'area Takoradi',
#   'Takoradi Alliance',
#   'Alliance home',
#   'home away',
#   'away home',
#   'home For',
#   'For business',
#   'business traveller',
#   'traveller well',
#   'well seeking',
#   'seeking pleasure'],
#  ['Not beautiful',
#   'beautiful picture',
#   'picture review',
#   'review I',
#   'I saw',
#   'saw looked',
#   'looked quite',
#   'quite tight',
#   'tight spacious',
#   'spacious enough',
#   'enough But',
#   'But good',
#   'good side',
#   'side stay',
#   'stay long',
#   'long enough',
#   'enough find',
#   'find though'],
#  ['Worthy experience'],
#  ['Clean serene',
#   'serene location',
#   'location friendly',
#   'friendly staff',
#   'staff The',
#   'The room',
#   'room small',
#   'small well',
#   'well maintained'],
#  ['Don know',
#   'know whether',
#   'whether season',
#   'season thus',
#   'thus staff',
#   'staff overwhelmed',
#   'overwhelmed service',
#   'service left',
#   'left soo',
#   'soo much',
#   'much desired'],
#  ['Their food', 'food exquisite'],
#  ['Cozy place',
#   'place great',
#   'great service',
#   'service value',
#   'value money'],
#  ['This one',
#   'one nice',
#   'nice big',
#   'big hotel',
#   'hotel Takoradi',
#   'Takoradi I',
#   'I hoping',
#   'hoping better',
#   'better experience',
#   'experience I',
#   'I especially',
#   'especially knowing',
#   'knowing owned',
#   'owned Eagles',
#   'Eagles Their',
#   'Their staff',
#   'staff generally',
#   'generally nice',
#   'nice service',
#   'service poor',
#   'poor The',
#   'The breakfast',
#   'breakfast buffet',
#   'buffet limited',
#   'limited We',
#   'We option',
#   'option food',
#   'food 3',
#   '3 night',
#   'night stay',
#   'stay breakfast',
#   'breakfast I',
#   'I add',
#   'add favourite',
#   'favourite place',
#   'place Takoradi',
#   'Takoradi Hopefully',
#   'Hopefully improve',
#   'improve soon'],
#  ['Nice place'],
#  ['If best',
#   'best among',
#   'among best',
#   'best hotel',
#   'hotel Takoradi',
#   'Takoradi Ghana',
#   'Ghana whole',
#   'whole hundred',
#   'hundred _',
#   '_ point',
#   'point red',
#   'red _',
#   '_ heart'],
#  ['I sound', 'sound mind', 'mind learning'],
#  ['We stayed',
#   'stayed hotel',
#   'hotel family',
#   'family vacation',
#   'vacation amazing',
#   'amazing time',
#   'time The',
#   'The staff',
#   'staff friendly',
#   'friendly went',
#   'went beyond',
#   'beyond make',
#   'make stay',
#   'stay enjoyable'],
#  ['My staying',
#   'staying Alliance',
#   'Alliance peaceful',
#   'peaceful perfect',
#   'perfect The',
#   'The access',
#   'access road',
#   'road hotel',
#   'hotel must',
#   'must looked'],
#  ['Bad experience',
#   'experience Had',
#   'Had change',
#   'change room',
#   'room Stained',
#   'Stained mattress',
#   'mattress broken',
#   'broken window',
#   'window broken',
#   'broken toilet',
#   'toilet seat',
#   'seat many',
#   'many issue'],
#  ['Unpaved road',
#   'road leading',
#   'leading hotel',
#   'hotel roomservice',
#   'roomservice taking',
#   'taking almost',
#   'almost 1',
#   '1 5hours',
#   '5hours deliver',
#   'deliver simple',
#   'simple meal',
#   'meal diarrhea',
#   'diarrhea food',
#   'food water',
#   'water shower',
#   'shower spraying',
#   'spraying water',
#   'water ceiling',
#   'ceiling floor',
#   'floor guest',
#   'guest playing',
#   'playing loud',
#   'loud music',
#   'music pool',
#   'pool male',
#   'male guest',
#   'guest staring',
#   'staring inappropriately',
#   'inappropriately gym',
#   'gym reception',
#   'reception taking',
#   'taking immediate',
#   'immediate action',
#   'action afterwards',
#   'afterwards recommend',
#   'recommend hotel',
#   'hotel anyone',
#   'anyone especially',
#   'especially female',
#   'female foreigner'],
#  ['It amazingly',
#   'amazingly serene',
#   'serene luxurious',
#   'luxurious place',
#   'place spend',
#   'spend night',
#   'night forget',
#   'forget world'],
#  ['Very nice', 'nice lodge'],
#  ['Nice place'],
#  ['I stayed',
#   'stayed hotel',
#   'hotel work',
#   'work related',
#   'related retreat',
#   'retreat liked',
#   'liked experience',
#   'experience The',
#   'The room',
#   'room clean',
#   'clean facility',
#   'facility standard',
#   'standard Their',
#   'Their front',
#   'front desk',
#   'desk staff',
#   'staff friendly',
#   'friendly welcoming',
#   'welcoming two',
#   'two staff',
#   'staff depict',
#   'depict trait',
#   'trait Their',
#   'Their conference',
#   'conference room',
#   'room ok',
#   'ok even',
#   'even though',
#   'though I',
#   'I think',
#   'think arrangement',
#   'arrangement furniture',
#   'furniture fit',
#   'fit purpose',
#   'purpose given',
#   'given nature',
#   'nature engagement',
#   'engagement I',
#   'I get',
#   'get use',
#   'use facility',
#   'facility gym',
#   'gym I',
#   'I attest',
#   'attest availability',
#   'availability state',
#   'state Overall',
#   'Overall lovely',
#   'lovely place',
#   'place especially',
#   'especially weekend',
#   'weekend getaway'],
#  ['There lovely',
#   'lovely ambience',
#   'ambience I',
#   'I really',
#   'really enjoyed',
#   'enjoyed buffet',
#   'buffet dinner'],
#  ['Serene environment'],
#  ['The best', 'best come', 'come West'],
#  ['Hotel normal',
#   'normal I',
#   'I wrote',
#   'wrote pool',
#   'pool I',
#   'I kicked',
#   'kicked I',
#   'I would',
#   'would like',
#   'like write',
#   'write pool',
#   'pool high',
#   'high Fix',
#   'Fix bug',
#   'bug pancreas',
#   'pancreas norm',
#   'norm P',
#   'P S',
#   'S I',
#   'I left',
#   'left goose',
#   'goose room',
#   'room throw',
#   'throw Tinkoff',
#   'Tinkoff Bitoch'],
#  ['smiling _',
#   '_ face',
#   'face _',
#   '_ _',
#   '_ hearteyes',
#   'hearteyes smiling',
#   'smiling _',
#   '_ face',
#   'face _',
#   '_ _',
#   '_ hearteyes',
#   'hearteyes smiling',
#   'smiling _',
#   '_ face',
#   'face _',
#   '_ _',
#   '_ hearteyes',
#   'hearteyes smiling',
#   'smiling _',
#   '_ face',
#   'face _',
#   '_ _',
#   '_ hearteyes',
#   'hearteyes I',
#   'I loved',
#   'loved stay',
#   'stay hotel',
#   'hotel The',
#   'The room',
#   'room fabulous',
#   'fabulous Furniture',
#   'Furniture adorable',
#   'adorable The',
#   'The bedstead',
#   'bedstead classy',
#   'classy display',
#   'display transparent',
#   'transparent material',
#   'material super',
#   'super comfortable',
#   'comfortable mattress',
#   'mattress bedding',
#   'bedding The',
#   'The view',
#   'view window',
#   'window beautiful',
#   'beautiful Showing',
#   'Showing pool',
#   'pool vast',
#   'vast green',
#   'green field',
#   'field around',
#   'around hotel',
#   'hotel Washroom',
#   'Washroom housekeeping',
#   'housekeeping breakfast',
#   'breakfast point',
#   'point Rooms',
#   'Rooms Rates',
#   'Rates little',
#   'little high',
#   'high side',
#   'side In',
#   'In evening',
#   'evening holiday',
#   'holiday live',
#   'live band',
#   'band music',
#   'music must',
#   'must Anytime',
#   'Anytime I',
#   'I back',
#   'back Takoradi',
#   'Takoradi I',
#   'I surely',
#   'surely visit'],
#  ['Management look',
#   'look thing',
#   'thing thing',
#   'thing way',
#   'way expensive',
#   'expensive 4pcs',
#   '4pcs spring',
#   'spring roll',
#   'roll 100gh',
#   '100gh n',
#   'n opinion',
#   'opinion u',
#   'u guy',
#   'guy losing',
#   'losing customer',
#   'customer co',
#   'co alot',
#   'alot pple',
#   'pple complaining',
#   'complaining price',
#   'price thanks'],
#  ['Great hotel', 'hotel Takoradi', 'Takoradi nice', 'nice view', 'view ocean'],
#  ['indeed play',
#   'play play',
#   'play Eiiii',
#   'Eiiii takodi',
#   'takodi We',
#   'We something',
#   'something red',
#   'red _',
#   '_ heart',
#   'heart globe',
#   'globe _',
#   '_ showing',
#   'showing _',
#   '_ EuropeAfrica',
#   'EuropeAfrica ry',
#   'ry folded',
#   'folded _',
#   '_ hand',
#   'hand Takoradi',
#   'Takoradi World',
#   'World wind',
#   'wind _',
#   '_ face'],
#  ['Walk inn',
#   'inn shower',
#   'shower Moderate',
#   'Moderate neat',
#   'neat comfortable',
#   'comfortable room',
#   'room There',
#   'There 3',
#   '3 swimming',
#   'swimming pool',
#   'pool kid',
#   'kid normal',
#   'normal Olympic',
#   'Olympic size',
#   'size Well',
#   'Well maintained',
#   'maintained Dining',
#   'Dining either',
#   'either pool',
#   'pool side',
#   'side dinning',
#   'dinning area',
#   'area whatever',
#   'whatever comfortable',
#   'comfortable relaxing',
#   'relaxing lover',
#   'lover family',
#   'family business',
#   'business meeting',
#   'meeting indoors',
#   'indoors outdoors',
#   'outdoors I',
#   'I view',
#   'view go',
#   'go beach',
#   'beach golf',
#   'golf course',
#   'course football',
#   'football pitch',
#   'pitch swimming',
#   'swimming pool',
#   'pool comfort',
#   'comfort room',
#   'room This',
#   'This OK',
#   'OK _',
#   '_ hand',
#   'hand Guess',
#   'Guess The',
#   'The meal',
#   'meal expensive',
#   'expensive I',
#   'I imagined',
#   'imagined Wifi',
#   'Wifi unreliable'],
#  ['Calm space',
#   'space accessible',
#   'accessible Takoradi',
#   'Takoradi city',
#   'city It',
#   'It beach',
#   'beach road'],
#  ['Clean room',
#   'room warm',
#   'warm staff',
#   'staff reception',
#   'reception good',
#   'good variety',
#   'variety option',
#   'option buffet',
#   'buffet breakfast',
#   'breakfast menu',
#   'menu Lovely',
#   'Lovely view',
#   'view ocean',
#   'ocean lovely',
#   'lovely landscape',
#   'landscape hotel',
#   'hotel room'],
#  ['Great view', 'view Serene', 'Serene environment'],
#  ['Pizza nice',
#   'nice Friendly',
#   'Friendly lovely',
#   'lovely environment',
#   'environment scenic',
#   'scenic view'],
#  ['Awesome relaxing',
#   'relaxing hotel',
#   'hotel good',
#   'good business',
#   'business family'],
#  ['The Ghana',
#   'Ghana Institution',
#   'Institution Engineering',
#   'Engineering held',
#   'held annual',
#   'annual banquet',
#   'banquet dinner',
#   'dinner food',
#   'food tasty',
#   'tasty Set',
#   'Set AGM',
#   'AGM also',
#   'also great',
#   'great Nice',
#   'Nice place'],
#  ['Still great', 'great place', 'place Takoradi'],
#  ['Nice wonderful', 'wonderful place', 'place relax', 'relax work'],
#  ['5 star',
#   'star This',
#   'This said',
#   'said Everything',
#   'Everything super',
#   'super food',
#   'food rest',
#   'rest amenity',
#   'amenity etc'],
#  ['Thank management',
#   'management Staff',
#   'Staff Excellent',
#   'Excellent service'],
#  [],
#  ['The hotel',
#   'hotel nice',
#   'nice however',
#   'however price',
#   'price resort',
#   'resort cheap',
#   'cheap 4',
#   '4 star',
#   'star hotel',
#   'hotel I',
#   'I expecting',
#   'expecting higher',
#   'higher standard',
#   'standard We',
#   'We booked',
#   'booked seaview',
#   'seaview chalet',
#   'chalet could',
#   'could see',
#   'see sea',
#   'sea due',
#   'due back',
#   'back gate',
#   'gate tree',
#   'tree The',
#   'The building',
#   'building need',
#   'need renovated',
#   'renovated The',
#   'The shower',
#   'shower draining',
#   'draining properly',
#   'properly swimming',
#   'swimming pool',
#   'pool lounge',
#   'lounge chair',
#   'chair good',
#   'good condition',
#   'condition pool',
#   'pool bed',
#   'bed dirty',
#   'dirty We',
#   'We hot',
#   'hot water',
#   'water first',
#   'first day',
#   'day night',
#   'night rectified',
#   'rectified first',
#   'first shower',
#   'shower cold',
#   'cold We',
#   'We power',
#   'power cut',
#   'cut lasted',
#   'lasted hour',
#   'hour The',
#   'The hotel',
#   'hotel operational',
#   'operational generator',
#   'generator The',
#   'The positive',
#   'positive thing',
#   'thing breakfast',
#   'breakfast buffet',
#   'buffet continental',
#   'continental freshly',
#   'freshly cooked',
#   'cooked food',
#   'food including',
#   'including local',
#   'local food',
#   'food tasty'],
#  ['Air conditioning',
#   'conditioning poor',
#   'poor I',
#   'I hardly',
#   'hardly slept',
#   'slept night',
#   'night Pillows',
#   'Pillows like',
#   'like big',
#   'big gummy',
#   'gummy bear',
#   'bear extremely',
#   'extremely firm',
#   'firm round',
#   'round Had',
#   'Had food',
#   'food outside',
#   'outside back',
#   'back ok'],
#  ['Very good',
#   'good hotel',
#   'hotel clean',
#   'clean room',
#   'room comfortable',
#   'comfortable delicious',
#   'delicious food',
#   'food best',
#   'best hotel',
#   'hotel stay',
#   'stay Takoradi',
#   'Takoradi opinion'],
#  ['Great resort'],
#  ['It absolutely',
#   'absolutely beautiful',
#   'beautiful Staff',
#   'Staff friendly',
#   'friendly caring',
#   'caring An',
#   'An excellent',
#   'excellent selection',
#   'selection food',
#   'food menu',
#   'menu Perhaps',
#   'Perhaps larger',
#   'larger selection',
#   'selection onsite',
#   'onsite entertainment',
#   'entertainment would',
#   'would make',
#   'make perfect',
#   'perfect getaway',
#   'getaway stay'],
#  ['I absolutely',
#   'absolutely loved',
#   'loved stay',
#   'stay Red',
#   'Red Mango',
#   'Mango I',
#   'I honeymoon',
#   'honeymoon lovely',
#   'lovely Their',
#   'Their room',
#   'room really',
#   'really neat',
#   'neat modern',
#   'modern staff',
#   'staff welcoming',
#   'welcoming friendly',
#   'friendly professional',
#   'professional pool',
#   'pool food',
#   'food environment',
#   'environment access',
#   'access town',
#   'town etc',
#   'etc It',
#   'It perfect',
#   'perfect hideout',
#   'hideout u'],
#  ['Service location',
#   'location top',
#   'top notch',
#   'notch smiling',
#   'smiling _',
#   '_ face',
#   'face _',
#   '_ _',
#   '_ smiling',
#   'smiling _',
#   '_ eyesOK',
#   'eyesOK _',
#   '_ hand'],
#  ['I recommend', 'recommend everyone', 'everyone best', 'best place'],
#  ['Well arranged',
#   'arranged apartment',
#   'apartment good',
#   'good comfort',
#   'comfort couple',
#   'couple family',
#   'family Well',
#   'Well located',
#   'located heart',
#   'heart Takoradi'],
#  ['I great',
#   'great time',
#   'time Red',
#   'Red mango',
#   'mango hotel',
#   'hotel The',
#   'The service',
#   'service excellent',
#   'excellent food',
#   'food room',
#   'room nice'],
#  ['This located',
#   'located serene',
#   'serene area',
#   'area Takoradi',
#   'Takoradi Very',
#   'Very close',
#   'close road',
#   'road easily',
#   'easily accessible',
#   'accessible The',
#   'The room',
#   'room cool',
#   'cool quite',
#   'quite average',
#   'average Their',
#   'Their service',
#   'service nice',
#   'nice The',
#   'The one',
#   'one attended',
#   'attended smart',
#   'smart professional'],
#  ['The environment',
#   'environment serene',
#   'serene Great',
#   'Great view',
#   'view night',
#   'night Good',
#   'Good dinner',
#   'dinner couple',
#   'couple night'],
#  ['The room',
#   'room nice',
#   'nice comfy',
#   'comfy Beautiful',
#   'Beautiful experience'],
#  ['I amazing',
#   'amazing experience',
#   'experience would',
#   'would definitely',
#   'definitely recommend',
#   'recommend anyone',
#   'anyone looking',
#   'looking visit',
#   'visit Takoradi',
#   'Takoradi soon'],
#  ['Couldn asked',
#   'asked better',
#   'better Services',
#   'Services top',
#   'top notch'],
#  ['Red Mango',
#   'Mango awesome',
#   'awesome interior',
#   'interior design',
#   'design And',
#   'And room',
#   'room really',
#   'really neat',
#   'neat I',
#   'I personally',
#   'personally loved',
#   'loved washroom',
#   'washroom Top',
#   'Top class'],
#  ['It lovely',
#   'lovely Clean',
#   'Clean room',
#   'room Staff',
#   'Staff polite',
#   'polite professional',
#   'professional I',
#   'I enjoyed',
#   'enjoyed stay',
#   'stay smiling',
#   'smiling _',
#   '_ face',
#   'face _',
#   '_ _',
#   '_ heart'],
#  ['I enjoyed', 'enjoyed stay'],
#  ['Very comfortable',
#   'comfortable serene',
#   'serene environment',
#   'environment I',
#   'I go'],
#  ['The facility',
#   'facility exceeded',
#   'exceeded expectation',
#   'expectation The',
#   'The bed',
#   'bed comfortable',
#   'comfortable living',
#   'living room',
#   'room spacious',
#   'spacious kitchenette',
#   'kitchenette useful',
#   'useful breastfeeding',
#   'breastfeeding mum',
#   'mum I',
#   'I love',
#   'love fridge',
#   'fridge sizeable',
#   'sizeable freezer',
#   'freezer unit',
#   'unit However',
#   'However smell',
#   'smell room',
#   'room quite',
#   'quite strong',
#   'strong Smelt',
#   'Smelt like',
#   'like sewage',
#   'sewage something',
#   'something dump',
#   'dump dry',
#   'dry properly',
#   'properly especially',
#   'especially area',
#   'area around',
#   'around vent',
#   'vent kitchen',
#   'kitchen Regardless',
#   'Regardless I',
#   'I impressed',
#   'impressed enjoyed',
#   'enjoyed stay'],
#  ['It really',
#   'really lovely',
#   'lovely place',
#   'place Apartments',
#   'Apartments neat',
#   'neat feel',
#   'feel like',
#   'like home',
#   'home Their',
#   'Their pool',
#   'pool tidy',
#   'tidy customer',
#   'customer service',
#   'service excellent'],
#  ['Excellent OK', 'OK _', '_ hand'],
#  ['Love pool'],
#  ['Best New',
#   'New hide',
#   'hide takoradi',
#   'takoradi Lovely',
#   'Lovely room',
#   'room Very',
#   'Very friendly',
#   'friendly staff',
#   'staff Will',
#   'Will go',
#   'go get',
#   'get request',
#   'request met',
#   'met Only',
#   'Only problem',
#   'problem pool',
#   'pool unattended',
#   'unattended And',
#   'And I',
#   'I saw',
#   'saw crow',
#   'crow bathing',
#   'bathing Not',
#   'Not healthy',
#   'healthy Hopefully',
#   'Hopefully addressed'],
#  ['The best',
#   'best hotel',
#   'hotel business',
#   'business vacation',
#   'vacation nutritious',
#   'nutritious assorted',
#   'assorted food',
#   'food every',
#   'every occasion'],
#  ['Nice place'],
#  ['Lovely apartment',
#   'apartment high',
#   'high quality',
#   'quality finishing',
#   'finishing kitchenette',
#   'kitchenette facility',
#   'facility provides',
#   'provides catering',
#   'catering service',
#   'service well',
#   'well There',
#   'There daily',
#   'daily room',
#   'room cleaning',
#   'cleaning staff',
#   'staff top',
#   'top notch',
#   'notch professional',
#   'professional friendly',
#   'friendly There',
#   'There infinity',
#   'infinity pool',
#   'pool set',
#   'set peaceful',
#   'peaceful garden',
#   'garden Great',
#   'Great place',
#   'place work',
#   'work travel',
#   'travel get',
#   'get away'],
#  ['A cozy', 'cozy relaxing', 'relaxing place', 'place whole', 'whole family'],
#  ['Lovely serene',
#   'serene place',
#   'place The',
#   'The waitress',
#   'waitress happy',
#   'happy serve',
#   'serve u',
#   'u It',
#   'It good',
#   'good accommodation',
#   'accommodation pick',
#   'pick In',
#   'In Takoradi',
#   'Takoradi day'],
#  ['Nice place', 'place bar', 'bar area'],
#  ['What place',
#   'place siren',
#   'siren environment',
#   'environment perfect',
#   'perfect come',
#   'come service',
#   'service render',
#   'render guest'],
#  ['Best Place', 'Place ever', 'ever visit'],
#  ['Gives comfortable', 'comfortable home', 'home away', 'away home'],
#  [],
#  [],
#  ['Indeed nice', 'nice place'],
#  ['Beautiful Compound'],
#  ['Cozy room', 'room Serene', 'Serene environment'],
#  ['Nice environment'],
#  [],
#  ['Sedelam Lodge',
#   'Lodge home',
#   'home away',
#   'away home',
#   'home U',
#   'U never',
#   'never regret',
#   'regret cherish',
#   'cherish comfort',
#   'comfort Cousy',
#   'Cousy serene',
#   'serene Will',
#   'Will recommend',
#   'recommend Sedelam',
#   'Sedelam day',
#   'day 100',
#   '100 OK',
#   'OK _',
#   '_ hand'],
#  ['A Good', 'Good hotel', 'hotel Aboadzi', 'Aboadzi enclave'],
#  ['Nice place', 'place thumb', 'thumb _'],
#  ['A Cool',
#   'Cool Nice',
#   'Nice place',
#   'place lodge',
#   'lodge Excellent',
#   'Excellent client',
#   'client service',
#   'service I',
#   'I highly',
#   'highly recommend',
#   'recommend Sedelam',
#   'Sedelam Lodge',
#   'Lodge anyone',
#   'anyone looking',
#   'looking cool',
#   'cool place',
#   'place lodge',
#   'lodge Takoradi',
#   'Takoradi red',
#   'red _',
#   '_ heart'],
#  ['Friendly staff',
#   'staff well',
#   'well managed',
#   'managed Serene',
#   'Serene environment',
#   'environment It',
#   'It must',
#   'must looking',
#   'looking change',
#   'change usual',
#   'usual buzz',
#   'buzz city',
#   'city relax',
#   'relax fun'],
#  ['A nice',
#   'nice place',
#   'place countryside',
#   'countryside vacation',
#   'vacation Beautiful',
#   'Beautiful environment',
#   'environment great',
#   'great reception',
#   'reception I',
#   'I recommend',
#   'recommend place'],
#  ['Beautiful environment',
#   'environment excellent',
#   'excellent service',
#   'service I',
#   'I really',
#   'really enjoyed',
#   'enjoyed stay',
#   'stay great',
#   'great customer',
#   'customer service',
#   'service provided',
#   'provided I',
#   'I recommend',
#   'recommend visit',
#   'visit More',
#   'More home'],
#  ['My Honeymoon',
#   'Honeymoon stay',
#   'stay Sedelam',
#   'Sedelam Lodge',
#   'Lodge best',
#   'best It',
#   'It serene',
#   'serene beautiful',
#   'beautiful edifice',
# ...
#   'beautiful environment',
#   'environment Staff',
#   'Staff friendly',
#   'friendly Ultimate',
#   'Ultimate escape',
#   'escape reset',
#   'reset meditate',
#   'meditate reconnect',
#   'reconnect nature',
#   'nature Counting',
#   'Counting day',
#   'day next',
#   'next visit'],
#  ['The view',
#   'view lake',
#   'lake serenity',
#   'serenity absolutely',
#   'absolutely worth',
#   'worth journey',
#   'journey sparkle'],
#  ['Bad policy',
#   'policy Not',
#   'Not good',
#   'good By',
#   'By force',
#   'force ordering',
#   'ordering food'],
#  ['Cozy environment', 'environment food', 'food keep', 'keep long'],
#  ['one best',
#   'best resort',
#   'resort get',
#   'get leisure',
#   'leisure Don',
#   'Don miss'],
#  ['They best',
#   'best road',
#   'road though',
#   'though serene',
#   'serene natural',
#   'natural environment',
#   'environment view',
#   'view lake'],
#  ['Was birthday', 'birthday I', 'I love', 'love environment'],
#  ['The natural',
#   'natural environment',
#   'environment lake',
#   'lake healing',
#   'healing fun'],
#  ['Staffs friendly',
#   'friendly patient',
#   'patient respectful',
#   'respectful Rooms',
#   'Rooms bathroom',
#   'bathroom neat',
#   'neat food',
#   'food delicious',
#   'delicious wildwin',
#   'wildwin drink',
#   'drink make',
#   'make die',
#   'die last',
#   'last least',
#   'least place',
#   'place surrounded',
#   'surrounded different',
#   'different fruit',
#   'fruit facing',
#   'facing lake',
#   'lake night',
#   'night I',
#   'I slept',
#   'slept side',
#   'side listening',
#   'listening sound',
#   'sound lake',
#   'lake watching',
#   'watching star',
#   'star moon',
#   'moon In',
#   'In short',
#   'short I',
#   'I recommend',
#   'recommend place',
#   'place anyone',
#   'anyone need',
#   'need getaway',
#   'getaway rest',
#   'rest relax'],
#  ['Great weekend',
#   'weekend getaway',
#   'getaway easy',
#   'easy access',
#   'access lake',
#   'lake nature',
#   'nature Good',
#   'Good customer',
#   'customer service',
#   'service around',
#   'around Seiba',
#   'Seiba Godwin',
#   'Godwin helpful',
#   'helpful free',
#   'free breakfast',
#   'breakfast par'],
#  ['Great experience'],
#  ['Beautiful ground',
#   'ground Willing',
#   'Willing staff',
#   'staff intuition',
#   'intuition clearly',
#   'clearly trained',
#   'trained They',
#   'They willing',
#   'willing bit',
#   'bit trust',
#   'trust everything',
#   'everything take',
#   'take long',
#   'long We',
#   'We waited',
#   'waited half',
#   'half hour',
#   'hour breakfast',
#   'breakfast longer',
#   'longer dinner',
#   'dinner The',
#   'The bedroom',
#   'bedroom We',
#   'We blue',
#   'blue light',
#   'light bathroom',
#   'bathroom strange',
#   'strange one',
#   'one towel',
#   'towel knew',
#   'knew two',
#   'two people',
#   'people staying',
#   'staying room'],
#  ['Beautiful serene',
#   'serene place',
#   'place good',
#   'good people',
#   'people delicious',
#   'delicious meal'],
#  ['Nice place',
#   'place enough',
#   'enough space',
#   'space family',
#   'family outing',
#   'outing A',
#   'A view',
#   'view Lake',
#   'Lake Bosomtwe',
#   'Bosomtwe But',
#   'But road',
#   'road location',
#   'location encouraging'],
#  ['My first',
#   'first experience',
#   'experience June',
#   'June 2021',
#   '2021 I',
#   'I fell',
#   'fell love',
#   'love place',
#   'place The',
#   'The water',
#   'water tree',
#   'tree bird',
#   'bird different',
#   'different colour',
#   'colour Oh',
#   'Oh I',
#   'I help',
#   'help come',
#   'come weekend',
#   'weekend birthday',
#   'birthday Oct',
#   'Oct 2nd',
#   '2nd 4th',
#   '4th It',
#   'It magical',
#   'magical experience',
#   'experience I',
#   'I swam',
#   'swam lake',
#   'lake Bosomtwe',
#   'Bosomtwe first',
#   'first time',
#   'time I',
#   'I meditation',
#   'meditation lake',
#   'lake 5am',
#   '5am bird',
#   'bird singing',
#   'singing sun',
#   'sun rising',
#   'rising calm',
#   'calm lake',
#   'lake The',
#   'The owner',
#   'owner amazing',
#   'amazing person',
#   'person I',
#   'I came',
#   'came June',
#   'June nice',
#   'nice phone',
#   'phone changed',
#   'changed It',
#   'It feel',
#   'feel like',
#   'like home',
#   'home They',
#   'They even',
#   'even made',
#   'made surprise',
#   'surprise birthday',
#   'birthday local',
#   'local food',
#   'food I',
#   'I never',
#   'never forget',
#   'forget weekend',
#   'weekend The',
#   'The time',
#   'time I',
#   'I saw',
#   'saw happy',
#   'happy client',
#   'client came',
#   'came food',
#   'food refused',
#   'refused pay',
#   'pay anything',
#   'anything When',
#   'When asked',
#   'asked pay',
#   'pay nicely',
#   'nicely refused',
#   'refused finally',
#   'finally asked',
#   'asked leave',
#   'leave They',
#   'They rained',
#   'rained insult',
#   'insult whole',
#   'whole place',
#   'place I',
#   'I never',
#   'never seen',
#   'seen disrespect',
#   'disrespect rude',
#   'rude behaviour',
#   'behaviour If',
#   'If food',
#   'food eat',
#   'eat home',
#   'home You',
#   'You bring',
#   'bring food',
#   'food restaurant',
#   'restaurant Why',
#   'Why good',
#   'good business',
#   'business Wildwin',
#   'Wildwin amazing',
#   'amazing gateway',
#   'gateway nature',
#   'nature lover',
#   'lover owner',
#   'owner best',
#   'best customer',
#   'customer service',
#   'service client',
#   'client I',
#   'I seen',
#   'seen Anyways',
#   'Anyways I',
#   'I already',
#   'already booked',
#   'booked ticket',
#   'ticket December',
#   'December 2021',
#   '2021 Can',
#   'Can wait',
#   'wait see',
#   'see blue',
#   'blue green',
#   'green bird',
#   'bird swim',
#   'swim lake',
#   'lake Bosomtwe',
#   'Bosomtwe I',
#   'I could',
#   'could live',
#   'live life'],
#  ['Good chef', 'chef Quiet', 'Quiet environment'],
#  ['I really',
#   'really love',
#   'love place',
#   'place We',
#   'We refresher',
#   'refresher course',
#   'course indeed',
#   'indeed refreshing',
#   'refreshing Very',
#   'Very nice',
#   'nice serene',
#   'serene environment'],
#  ['I enjoyed',
#   'enjoyed stay',
#   'stay nice',
#   'nice calm',
#   'calm environment',
#   'environment beautiful',
#   'beautiful caring',
#   'caring staff',
#   'staff I',
#   'I wan',
#   'wan na',
#   'na leave'],
#  ['Nice place', 'place village', 'village setting'],
#  ['It great',
#   'great time',
#   'time view',
#   'view lake',
#   'lake breath',
#   'breath taking'],
#  ['I loved',
#   'loved neat',
#   'neat serene',
#   'serene place',
#   'place It',
#   'It good',
#   'good place',
#   'place visit',
#   'visit want',
#   'want run',
#   'run away',
#   'away chaos',
#   'chaos city',
#   'city And',
#   'And customer',
#   'customer service',
#   'service wonderful',
#   'wonderful well'],
#  ['Good place',
#   'place relax',
#   'relax unplug',
#   'unplug Location',
#   'Location perfect',
#   'perfect waiting',
#   'waiting service',
#   'service better',
#   'better Will',
#   'Will recommend',
#   'recommend place',
#   'place looking',
#   'looking cool',
#   'cool place',
#   'place get',
#   'get away'],
#  ['Good customer', 'customer care'],
#  ['We really',
#   'really enjoyed',
#   'enjoyed Blue',
#   'Blue Diamond',
#   'Diamond Easy',
#   'Easy booking',
#   'booking great',
#   'great communication',
#   'communication easy',
#   'easy find',
#   'find really',
#   'really bad',
#   'bad drive',
#   'drive Accra',
#   'Accra Ordering',
#   'Ordering drink',
#   'drink meal',
#   'meal easy',
#   'easy WhatsApp',
#   'WhatsApp message',
#   'message We',
#   'We ordered',
#   'ordered food',
#   'food one',
#   'one night',
#   'night good',
#   'good brought',
#   'brought bbq',
#   'bbq second',
#   'second night',
#   'night I',
#   'I like',
#   'like allow',
#   'allow bring',
#   'bring food',
#   'food The',
#   'The room',
#   'room super',
#   'super basic',
#   'basic spent',
#   'spent time',
#   'time beach',
#   'beach anyway',
#   'anyway The',
#   'The beach',
#   'beach clean',
#   'clean safe',
#   'safe swim',
#   'swim Decent',
#   'Decent wave',
#   'wave boogie',
#   'boogie boarding',
#   'boarding even',
#   'even surfing',
#   'surfing decent',
#   'decent break',
#   'break beach',
#   'beach bit',
#   'bit It',
#   'It feel',
#   'feel good',
#   'good find',
#   'find place',
#   'place escape',
#   'escape Accra',
#   'Accra really',
#   'really required',
#   'required nothing',
#   'nothing relax'],
#  ['Nice clean',
#   'clean beach',
#   'beach getaway',
#   'getaway Accra',
#   'Accra Beautiful',
#   'Beautiful shoreline',
#   'shoreline wave',
#   'wave body',
#   'body surfing',
#   'surfing close',
#   'close quick',
#   'quick surfing',
#   'surfing Resort',
#   'Resort food',
#   'food yummy',
#   'yummy You',
#   'You bring',
#   'bring charcoal',
#   'charcoal grill',
#   'grill food',
#   'food well',
#   'well Dmall',
#   'Dmall nighltly',
#   'nighltly bonfire',
#   'bonfire weekend',
#   'weekend Small',
#   'Small clean',
#   'clean pool',
#   'pool Very',
#   'Very nice',
#   'nice spot',
#   'spot family',
#   'family Drinks',
#   'Drinks thr',
#   'thr pricier',
#   'pricier side',
#   'side order',
#   'order via',
#   'via WhatsApp',
#   'WhatsApp convenient',
#   'convenient Rooms',
#   'Rooms AC',
#   'AC mini',
#   'mini fridge',
#   'fridge honestly',
#   'honestly spend',
#   'spend much',
#   'much time',
#   'time thr',
#   'thr room',
#   'room awake',
#   'awake No',
#   'No store',
#   'store nearby',
#   'nearby bring',
#   'bring snack',
#   'snack maybe',
#   'maybe water',
#   'water Rooms',
#   'Rooms get',
#   'get sandy',
#   'sandy floor',
#   'floor mat',
#   'mat would',
#   'would nice',
#   'nice inside',
#   'inside door',
#   'door Manager',
#   'Manager person',
#   'person owner',
#   'owner German',
#   'German lady',
#   'lady great',
#   'great communication',
#   'communication skill'],
#  ['Blue Diamond',
#   'Diamond Beach',
#   'Beach Resort',
#   'Resort life',
#   'life upto',
#   'upto name',
#   'name It',
#   'It clean',
#   'clean beach',
#   'beach view',
#   'view picture',
#   'picture perfect',
#   'perfect Service',
#   'Service staff',
#   'staff polite',
#   'polite professional',
#   'professional approach',
#   'approach Long',
#   'Long walk',
#   'walk 7',
#   '7 10',
#   '10 Km',
#   'Km beach',
#   'beach normal',
#   'normal villager',
#   'villager fishing',
#   'fishing nearby',
#   'nearby add',
#   'add experience',
#   'experience local',
#   'local people',
#   'people culture',
#   'culture Ride',
#   'Ride wave',
#   'wave get',
#   'get board',
#   'board Swings',
#   'Swings hammock',
#   'hammock coconut',
#   'coconut tree',
#   'tree give',
#   'give true',
#   'true feel',
#   'feel beach',
#   'beach resort',
#   'resort Rooms',
#   'Rooms functional',
#   'functional well',
#   'well maintained',
#   'maintained Overall',
#   'Overall excellent',
#   'excellent place',
#   'place Place',
#   'Place cosy',
#   'cosy give',
#   'give privacy',
#   'privacy bottle',
#   'bottle _',
#   '_ _',
#   '_ popping',
#   'popping _',
#   '_ corkclinking',
#   'corkclinking _',
#   '_ glassesclinking',
#   'glassesclinking _',
#   '_ beer',
#   'beer _',
#   '_ mugstropical',
#   'mugstropical _',
#   '_ drinkperson',
#   'drinkperson _',
#   '_ surfingpalm',
#   'surfingpalm _',
#   '_ tree'],
#  ['A lovely',
#   'lovely hideout',
#   'hideout hustle',
#   'hustle bustle',
#   'bustle city',
#   'city life',
#   'life An',
#   'An escape',
#   'escape route',
#   'route really',
#   'really Serene',
#   'Serene atmosphere',
#   'atmosphere well',
#   'well trimmed',
#   'trimmed lawn',
#   'lawn Not',
#   'Not easy',
#   'easy location',
#   'location though',
#   'though get',
#   'get love',
#   'love A',
#   'A neat',
#   'neat tidy',
#   'tidy beach',
#   'beach life',
#   'life guard',
#   'guard available',
#   'available help',
#   'help time',
#   'time We',
#   'We really',
#   'really fun',
#   'fun host',
#   'host amazing'],
#  ['Just came',
#   'came back',
#   'back 2',
#   '2 day',
#   'day stay',
#   'stay getaway',
#   'getaway Blue',
#   'Blue Diamond',
#   'Diamond Firstly',
#   'Firstly communication',
#   'communication 100',
#   '100 All',
#   'All question',
#   'question prior',
#   'prior booking',
#   'booking answered',
#   'answered well',
#   'well time',
#   'time WhatsApp',
#   'WhatsApp The',
#   'The outside',
#   'outside Arriving',
#   'Arriving resort',
#   'resort easy',
#   'easy informed',
#   'informed arrival',
#   'arrival someone',
#   'someone met',
#   'met u',
#   'u gate',
#   'gate As',
#   'As drive',
#   'drive feel',
#   'feel peace',
#   'peace serenity',
#   'serenity resort',
#   'resort It',
#   'It clean',
#   'clean beach',
#   'beach well',
#   'well kept',
#   'kept lovely',
#   'lovely palm',
#   'palm tree',
#   'tree shaded',
#   'shaded seating',
#   'seating table',
#   'table beach',
#   'beach side',
#   'side The',
#   'The Rooms',
#   'Rooms We',
#   'We booked',
#   'booked conjoining',
#   'conjoining family',
#   'family room',
#   'room I',
#   'I must',
#   'must say',
#   'say room',
#   'room big',
#   'big disappointment',
#   'disappointment The',
#   'The room',
#   'room extremely',
#   'extremely basic',
#   'basic especially',
#   'especially price',
#   'price paid',
#   'paid felt',
#   'felt inclined',
#   'inclined chill',
#   'chill beach',
#   'beach till',
#   'till time',
#   'time go',
#   'go bed',
#   'bed room',
#   'room depressing',
#   'depressing dark',
#   'dark bare',
#   'bare furniture',
#   'furniture Food',
#   'Food Ordering',
#   'Ordering food',
#   'food easy',
#   'easy A',
#   'A quick',
#   'quick whatsapp',
#   'whatsapp get',
#   'get quick',
#   'quick response',
#   'response However',
#   'However food',
#   'food 5',
#   '5 10',
#   '10 overpriced',
#   'overpriced quality',
#   'quality Ordered',
#   'Ordered dinner',
#   'dinner day',
#   'day arrived',
#   'arrived decided',
#   'decided find',
#   'find local',
#   'local make',
#   'make meal',
#   'meal rest',
#   'rest trip',
#   'trip Cocktails',
#   'Cocktails nice',
#   'nice The',
#   'The blue',
#   'blue diamond',
#   'diamond hit',
#   'hit So',
#   'So Last',
#   'Last Prayer',
#   'Prayer Overall',
#   'Overall tranquility',
#   'tranquility place',
#   'place make',
#   'make room',
#   'room food',
#   'food I',
#   'I giving',
#   'giving 4'],
#  ['Stephanie absolute',
#   'absolute hostess',
#   'hostess efficient',
#   'efficient via',
#   'via WhatsApp',
#   'WhatsApp provided',
#   'provided clear',
#   'clear communication',
#   'communication address',
#   'address every',
#   'every situation',
#   'situation The',
#   'The food',
#   'food great',
#   'great everything',
#   'everything menu',
#   'menu WAS',
#   'WAS available',
#   'available loved',
#   'loved grilled',
#   'grilled lobster',
#   'lobster prawn',
#   'prawn provencal',
#   'provencal sea',
#   'sea food',
#   'food linguine',
#   'linguine beach',
#   'beach front',
#   'front amazing',
#   'amazing absolutely',
#   'absolutely loved',
#   'loved eating',
#   'eating meal',
#   'meal right',
#   'right beach',
#   'beach front',
#   'front falling',
#   'falling asleep',
#   'asleep sound',
#   'sound sea',
#   'sea beach',
#   'beach resort',
#   'resort worth',
#   'worth visiting',
#   'visiting room',
#   'room basic',
#   'basic beach',
#   'beach worth',
#   'worth I',
#   'I would'],
#  ['Beautiful place'],
#  ['I enjoy', 'enjoy red', 'red _', '_ heart'],
#  ['Great place',
#   'place nice',
#   'nice getaway',
#   'getaway Accra',
#   'Accra great',
#   'great service',
#   'service nice',
#   'nice food',
#   'food nice',
#   'nice scenery',
#   'scenery beach',
#   'beach great',
#   'great hostess',
#   'hostess PS',
#   'PS ask',
#   'ask bonfire'],
#  ['Neat beach',
#   'beach good',
#   'good food',
#   'food great',
#   'great customer',
#   'customer service'],
#  ['We spent',
#   'spent week',
#   'week Xmil',
#   'Xmil coast',
#   'coast The',
#   'The splendid',
#   'splendid sea',
#   'sea well',
#   'well served',
#   'served equipped',
#   'equipped beach',
#   'beach The',
#   'The excellent',
#   'excellent catering',
#   'catering fresh',
#   'fresh fish',
#   'fish excellent',
#   'excellent pizza',
#   'pizza courtesy',
#   'courtesy cleaning',
#   'cleaning place'],
#  ['Very lovely',
#   'lovely place',
#   'place Was',
#   'Was 2015',
#   '2015 today',
#   'today great',
#   'great Will',
#   'Will always',
#   'always recommend'],
#  ['Any reason',
#   'reason pick',
#   'pick call',
#   'call strictly',
#   'strictly reservation',
#   'reservation keep',
#   'keep phone',
#   'phone close'],
#  ['Worst place',
#   'place visit',
#   'visit Never',
#   'Never seen',
#   'seen zero',
#   'zero hospitality',
#   'hospitality life',
#   'life You',
#   'You even',
#   'even enter',
#   'enter gate',
#   'gate reservation',
#   'reservation What',
#   'What nonsense',
#   'nonsense Why',
#   'Why allow',
#   'allow walk',
#   'walk customer',
#   'customer coming',
#   'coming way',
#   'way Accra',
#   'Accra lunch',
#   'lunch What',
#   'What precious',
#   'precious Inside',
#   'Inside walk',
#   'walk customer',
#   'customer turned',
#   'turned away',
#   'away gate',
#   'gate Ridiculous',
#   'Ridiculous behaviour',
#   'behaviour lady',
#   'lady manager',
#   'manager spoke',
#   'spoke phone',
#   'phone Will',
#   'Will never',
#   'never visit',
#   'visit recommend',
#   'recommend place',
#   'place one'],
#  ...]

# %%
train = unigram_data + bigram_data

# %%
train[:5]
# Out:
# [['I',
#   'wonderful',
#   'experience',
#   'Jonat',
#   'Hotel',
#   'Their',
#   'room',
#   'new',
#   'service',
#   'top',
#   'notch',
#   'I',
#   'definitely',
#   'recommend',
#   'anyone',
#   'visiting',
#   'Cape',
#   'Coast',
#   'folded',
#   '_',
#   'hand',
#   '_',
#   'dark',
#   '_',
#   'skin',
#   '_',
#   'tone'],
#  ['I',
#   'enjoyed',
#   'stay',
#   'For',
#   'serene',
#   'environment',
#   'choose',
#   'Jonat',
#   'Hotel'],
#  ['The',
#   'couple',
#   'time',
#   'I',
#   'peaceful',
#   'time',
#   'I',
#   'really',
#   'enjoyed',
#   'serenity',
#   'calm',
#   'ambiance',
#   'place',
#   'Really',
#   'nice',
#   'room',
#   'affordable',
#   'well'],
#  ['Everything',
#   'nice',
#   'super',
#   'clean',
#   'thumb',
#   '_',
#   'upthumbs',
#   '_',
#   'upthumbs',
#   '_'],
#  ['I',
#   'splendid',
#   'stay',
#   'Jonat',
#   'Hotel',
#   'It',
#   'might',
#   'new',
#   'service',
#   'great',
#   'food',
#   'delish']]

# %%
# Out:
# [['I',
#   'wonderful',
#   'experience',
#   'Jonat',
#   'Hotel',
#   'Their',
#   'room',
#   'new',
#   'service',
#   'top',
#   'notch',
#   'I',
#   'definitely',
#   'recommend',
#   'anyone',
#   'visiting',
#   'Cape',
#   'Coast',
#   'folded',
#   '_',
#   'hand',
#   '_',
#   'dark',
#   '_',
#   'skin',
#   '_',
#   'tone'],
#  ['I',
#   'enjoyed',
#   'stay',
#   'For',
#   'serene',
#   'environment',
#   'choose',
#   'Jonat',
#   'Hotel'],
#  ['The',
#   'couple',
#   'time',
#   'I',
#   'peaceful',
#   'time',
#   'I',
#   'really',
#   'enjoyed',
#   'serenity',
#   'calm',
#   'ambiance',
#   'place',
#   'Really',
#   'nice',
#   'room',
#   'affordable',
#   'well'],
#  ['Everything',
#   'nice',
#   'super',
#   'clean',
#   'thumb',
#   '_',
#   'upthumbs',
#   '_',
#   'upthumbs',
#   '_'],
#  ['I',
#   'splendid',
#   'stay',
#   'Jonat',
#   'Hotel',
#   'It',
#   'might',
#   'new',
#   'service',
#   'great',
#   'food',
#   'delish'],
#  ['Staff',
#   'provide',
#   'warm',
#   'reception',
#   'neat',
#   'room',
#   'room',
#   'service',
#   'available'],
#  ['It',
#   'nice',
#   'place',
#   'stay',
#   'Pretty',
#   'clean',
#   'price',
#   'room',
#   'great',
#   'They',
#   'also',
#   'serve',
#   'everyone',
#   'breakfast',
#   'plus'],
#  ['The',
#   'Drowaa',
#   'Plus',
#   'Hotel',
#   'go',
#   'place',
#   'stop',
#   'night',
#   'sleep',
#   'Great',
#   'design',
#   'room',
#   'great',
#   'ventilation',
#   'AC',
#   'Fan',
#   'room',
#   'etc',
#   'I',
#   'recommend',
#   'place',
#   'organizing',
#   'event',
#   'looking',
#   'great',
#   'place',
#   'lodge'],
#  ['Very', 'quite', 'location', 'Cape', 'Coast'],
#  ['In', 'town', 'around', 'IBB'],
#  ['The',
#   'room',
#   'beautiful',
#   'Elegant',
#   'design',
#   'But',
#   'washroom',
#   'poor',
#   'condition',
#   'And',
#   'poor',
#   'customer',
#   'service'],
#  ['drink',
#   'pub',
#   'place',
#   'hold',
#   'sentimental',
#   'value',
#   'well',
#   'old',
#   'junior',
#   'high',
#   'half',
#   'kilometre',
#   'away',
#   'friendly',
#   'accommodating',
#   'staff'],
#  ['Close', 'beach'],
#  ['Not',
#   'good',
#   'condition',
#   'moment',
#   'It',
#   'left',
#   'without',
#   'form',
#   'maintenance'],
#  ['Its', 'nice', 'place'],
#  ['This',
#   'great',
#   'establishment',
#   'striving',
#   'part',
#   'community',
#   'This',
#   'place',
#   'alll',
#   'type',
#   'loving',
#   'event',
#   'Thanks',
#   'everyone',
#   'community'],
#  ['We', 'spent', 'saturday', 'place', 'magic'],
#  ['Unique', 'conjunction', 'pristine', 'beach', 'good', 'food'],
#  ['Wonderfull', 'nothing', 'else'],
#  ['Situated',
#   'paradise',
#   'place',
#   'Very',
#   'quiet',
#   'beautiful',
#   'landscape',
#   'Access',
#   'easy',
#   'good',
#   'never',
#   'easy'],
#  ['Excellent',
#   'place',
#   'thumb',
#   '_',
#   'upbeaming',
#   '_',
#   'face',
#   '_',
#   '_',
#   'smiling',
#   '_',
#   'eye'],
#  ['Magnificent',
#   'place',
#   'comfortable',
#   'accommodation',
#   'taste',
#   'refined',
#   'kitchen',
#   'careful',
#   'welcome'],
#  ['Fantas',
#   'Folly',
#   'favourite',
#   'place',
#   'spend',
#   'relaxing',
#   'time',
#   'Philip',
#   'Fanta',
#   'wonderful',
#   'host',
#   'always',
#   'spend',
#   'time',
#   'make',
#   'feel',
#   'welcome',
#   'The',
#   'food',
#   'great',
#   'good',
#   'value',
#   'money',
#   'The',
#   'room',
#   'comfortable',
#   'well',
#   'thought',
#   'The',
#   'location',
#   'piece',
#   'Paradise',
#   'Earth',
#   'We',
#   'lot',
#   'wonderful',
#   'memory',
#   'time',
#   'spent',
#   'Fantas',
#   'Highly',
#   'recommended'],
#  ['No', 'wish', 'remains', 'unfulfilled', 'A', 'little', 'paradise', 'earth'],
#  ['Very',
#   'poor',
#   'service',
#   'I',
#   'received',
#   'fantas',
#   'folly',
#   'Food',
#   'took',
#   '2',
#   'hour',
#   'waiter',
#   'smart',
#   'They',
#   'could',
#   'even',
#   'recommend',
#   'listed',
#   'food',
#   'menu',
#   'best',
#   'one',
#   'waitress',
#   'mentioned',
#   'recommend',
#   'allowed',
#   'Their',
#   'appearance',
#   'also',
#   'Imagine',
#   'going',
#   'long',
#   'journey',
#   'given',
#   'poor',
#   'service',
#   'heart',
#   'breaking'],
#  ['This',
#   'worse',
#   'place',
#   'I',
#   'ever',
#   'They',
#   'rude',
#   'service',
#   'bad',
#   'The',
#   'owner',
#   'wife',
#   'wanted',
#   'fight',
#   'costumer',
#   'never',
#   'go',
#   'want',
#   'good',
#   'time'],
#  ['An',
#   'idyllic',
#   'place',
#   'European',
#   'cuisine',
#   'unfortunately',
#   'difficult',
#   'achieve',
#   'Use',
#   'road',
#   'car',
#   'possible'],
#  ['Nice',
#   'place',
#   'quiet',
#   'peaceful',
#   'amazing',
#   'view',
#   'The',
#   'minus',
#   'water',
#   'shower',
#   'tap',
#   'clean',
#   'used',
#   'big',
#   'minus'],
#  ['This',
#   'best',
#   'get',
#   'away',
#   'hectic',
#   'traffic',
#   'busyness',
#   'dirty',
#   'beach',
#   'Accra',
#   'Though',
#   'said',
#   'road',
#   'lead',
#   'heaven',
#   'narrow',
#   'get',
#   'ready',
#   'narrow',
#   'drive',
#   'haha',
#   'worth',
#   'end',
#   'Clean',
#   'environment',
#   'good',
#   'group',
#   'good',
#   'couple',
#   'spend',
#   'quality',
#   'time',
#   'together',
#   'Good',
#   'family',
#   'vacation',
#   'good',
#   'kid',
#   'good',
#   'long',
#   'walk',
#   'beach',
#   'I',
#   'strongly',
#   'recommend'],
#  ['Very', 'nice', 'beach'],
#  ['Amazing', 'stay', 'mouth', 'watering', 'food'],
#  ['Great',
#   'food',
#   'beach',
#   'relaxing',
#   'Awesome',
#   'place',
#   'getaway',
#   'road',
#   'bumpy',
#   'prepared',
#   'going',
#   'definitely',
#   'gem',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   '_',
#   'hearteyes',
#   'OK',
#   '_',
#   'hand',
#   'dark',
#   '_',
#   'skin',
#   '_',
#   'tone'],
#  ['The',
#   'worst',
#   'ever',
#   'customer',
#   'service',
#   'I',
#   'ever',
#   'experienced',
#   'I',
#   'checked',
#   'ordered',
#   'two',
#   'meal',
#   'wife',
#   'surprised',
#   'bottle',
#   'wine',
#   'I',
#   'requested',
#   'glass',
#   'brought',
#   'manager',
#   'owner',
#   'came',
#   'request',
#   '29ghs',
#   'bringing',
#   'wine',
#   'guest',
#   'accommodated',
#   'I',
#   'objected',
#   'poured',
#   'wine',
#   'glass',
#   'away',
#   'took',
#   'glass',
#   'And',
#   'told',
#   'check',
#   'leave',
#   'I',
#   'want',
#   'I'],
#  ['Best',
#   'beach',
#   'resort',
#   'takoradi',
#   'clean',
#   'beach',
#   'helpful',
#   'personal'],
#  ['A',
#   'peaceful',
#   'surrounded',
#   'overloaded',
#   'package',
#   'nature',
#   'tree',
#   'bird',
#   'sky',
#   'sun',
#   'moon',
#   'star',
#   'course',
#   'ocean',
#   'Amazing',
#   'Thank',
#   'Fanta',
#   'Philippe',
#   'Janet',
#   'Chef',
#   'Deborah',
#   'Ebo',
#   'whole',
#   'team',
#   'You',
#   'make',
#   'Fantas',
#   'Folly',
#   'living',
#   'I',
#   'coming',
#   'back'],
#  ['Great', 'meal', 'peaceful', 'atmosphere'],
#  ['Paradise', 'earth', 'road', 'difficult'],
#  ['Warm',
#   'reception',
#   'Philip',
#   'team',
#   'Always',
#   'ready',
#   'listen',
#   'serve',
#   'guest',
#   'well',
#   'For',
#   'meal',
#   'love'],
#  ['One',
#   'Cleanest',
#   'Beaches',
#   'beach',
#   '_',
#   '_',
#   'umbrella',
#   'Great',
#   'food',
#   'fresh',
#   'sea',
#   'water',
#   '_',
#   'wave',
#   'Ambiance',
#   'TOP',
#   '_',
#   'arrow',
#   'notch',
#   'Moderate',
#   'pricing'],
#  ['Really', 'nice', 'Proprio', 'Franc', 'Comtois', 'Heavenly', 'beach'],
#  ['An', 'amazing', 'place', 'weekend', 'getaway'],
#  ['An',
#   'fantastic',
#   'place',
#   'serene',
#   'atmosphere',
#   'located',
#   'right',
#   'Butre',
#   'beach',
#   'It',
#   'perfect',
#   'place',
#   'calm',
#   'enjoy',
#   'The',
#   'resort',
#   'built',
#   'great',
#   'sense',
#   'design',
#   'atmosphere',
#   'nice',
#   'couple',
#   'taking',
#   'good',
#   'care',
#   'I',
#   'really',
#   'loved',
#   'place',
#   'The',
#   'bad',
#   'thing',
#   'internet',
#   'connection',
#   'weak',
#   'depending',
#   'internet',
#   'perfect',
#   'place'],
#  ['Nestled',
#   'among',
#   'tropical',
#   'vegetation',
#   'sound',
#   'Atlantic',
#   'Ocean',
#   'rolling',
#   'shore',
#   'feel',
#   'far',
#   'away',
#   'hustle',
#   'bustle',
#   'yet',
#   'le',
#   'hour',
#   'drive',
#   'city',
#   'Takoradi',
#   'Caution',
#   'Road',
#   'rough',
#   'Consider',
#   'Pick',
#   'van',
#   'Beautiful',
#   'sea',
#   'beach',
#   'photogenic',
#   'view',
#   'Clean',
#   'area',
#   'water',
#   'The',
#   'beauty',
#   'place',
#   'small',
#   'rocky',
#   'mountain',
#   'mountain',
#   'walk',
#   '3',
#   '4',
#   'minute',
#   'click',
#   'picture',
#   'video',
#   'Adding',
#   'picture',
#   'water',
#   'green',
#   'grey',
#   'yellow',
#   'lol',
#   'mix',
#   'colour',
#   'Make',
#   'sure',
#   'order',
#   'food',
#   'advance',
#   'take',
#   '2',
#   'hour',
#   'saying',
#   '5',
#   'minute',
#   'I',
#   'omelette',
#   'bread',
#   'waited',
#   '1',
#   'one',
#   'hour'],
#  ['An',
#   'excellent',
#   'hideaway',
#   'vacation',
#   'spot',
#   'couple',
#   'want',
#   'get',
#   'away',
#   'busy',
#   'city',
#   'atmosphere',
#   'A',
#   'serene',
#   'area',
#   'beautiful',
#   'beach',
#   'The',
#   'food',
#   'great',
#   'take',
#   'long',
#   'time',
#   'prepare',
#   'I',
#   'recommend',
#   'ordering',
#   'early',
#   'enough',
#   'disappointed',
#   'One',
#   'need',
#   'note',
#   'however',
#   'resort',
#   'far',
#   'away',
#   'main',
#   'road',
#   'The',
#   'road',
#   'generally',
#   'smooth',
#   'though',
#   'We',
#   'could',
#   'find',
#   'sign',
#   'main',
#   'junction',
#   'missed',
#   'turn',
#   'got',
#   'lost',
#   'Be',
#   'sure',
#   'ask',
#   'direction',
#   'You',
#   'spend',
#   '20',
#   '30',
#   'min',
#   'drive',
#   'main',
#   'road',
#   'dirt',
#   'road',
#   'get',
#   'resort',
#   'After',
#   'main',
#   'junction',
#   'sign',
#   'junction',
#   'find',
#   'way',
#   'I',
#   'recommend',
#   'resort',
#   'couple',
#   'want',
#   'quiet',
#   'low',
#   'key',
#   'affordable',
#   'vacation',
#   'Just',
#   'make',
#   'sure',
#   '4x4',
#   'face',
#   '_',
#   '_',
#   'tear',
#   '_',
#   '_',
#   'joy'],
#  ['Wonderful', 'experience', 'middle', 'nowhere'],
#  ['Always',
#   'one',
#   'fav',
#   'place',
#   'visit',
#   'Food',
#   'great',
#   'beach',
#   'always',
#   'clean',
#   'Rooms',
#   'affordable',
#   'clean'],
#  ['Serene',
#   'atmosphere',
#   'perfect',
#   'OK',
#   '_',
#   'hand',
#   '_',
#   'mediumdark',
#   '_',
#   'skin',
#   '_',
#   'tone',
#   'get',
#   'away',
#   'trip',
#   'wonderful',
#   'people',
#   'hotel',
#   'Love',
#   'place',
#   'Would',
#   'always',
#   'choose',
#   'place'],
#  ['It', 'serene', 'Atmosphere'],
#  ['Amazing',
#   'getaway',
#   'everyone',
#   'Beautiful',
#   'sunset',
#   'serene',
#   'atmosphere'],
#  ['Sure', 'wonderful', 'place', 'enjoy', 'breeze'],
#  ['To', 'honest', 'visited', 'place', 'find', 'time', 'go', 'relax'],
#  ['Perfect',
#   'value',
#   'money',
#   'Clean',
#   'room',
#   'AC',
#   'nice',
#   'guy',
#   'reception'],
#  ['Has', 'beautiful', 'view', 'estuary', 'service', 'facility', 'commendable'],
#  ['Good',
#   'atmosphere',
#   'great',
#   'environment',
#   'right',
#   'place',
#   'Ankobra',
#   'river',
#   'join',
#   'sea',
#   'good',
#   'service',
#   'There',
#   'room',
#   'improvement',
#   'however'],
#  ['A',
#   'wonderful',
#   'experience',
#   'Neat',
#   'environment',
#   'courteous',
#   'worker',
#   'food',
#   'A'],
#  ['Nice', 'serene', 'environment', 'relaxing'],
#  ['Loved',
#   'serene',
#   'atmosphere',
#   'Loved',
#   'waking',
#   'sound',
#   'rumbling',
#   'wave',
#   'Relaxing',
#   'max',
#   'Don',
#   'miss',
#   'sunset',
#   'sunrise',
#   'The',
#   'food',
#   'breakfast',
#   'dinner',
#   'superb',
#   'I',
#   'definitely'],
#  ['The',
#   'Beach',
#   'Ankobra',
#   'view',
#   'best',
#   'room',
#   'stay',
#   'privacy',
#   'leisure'],
#  ['Ankobra',
#   'Bridge',
#   'Hotel',
#   'amazing',
#   'place',
#   'Nice',
#   'facility',
#   'room',
#   'serene',
#   'environment',
#   'The',
#   'food',
#   'great',
#   'Rooms',
#   'range',
#   'Ghc200',
#   '400',
#   'Great',
#   'place',
#   'get',
#   'city',
#   'relax',
#   'It',
#   'great'],
#  ['Home', 'away', 'home'],
#  ['heart',
#   '_',
#   'exclamation',
#   'heart',
#   '_',
#   'exclamation',
#   'heart',
#   '_',
#   'exclamation',
#   'heart',
#   '_',
#   'exclamation',
#   'heart',
#   '_',
#   'exclamation',
#   'food',
#   'Room',
#   'mouth',
#   'mouth',
#   'mouth',
#   'mouth',
#   'mouth',
#   'mouth'],
#  ['Very', 'nice', 'place', 'relaxation'],
#  ['One', 'best', 'place', 'relax', 'western', 'part', 'Ghana'],
#  ['Great', 'experience'],
#  ['Excellent',
#   'amenity',
#   'room',
#   'smell',
#   'good',
#   'breakfast',
#   'top',
#   'notch',
#   'Will',
#   'recommend',
#   'hotel'],
#  ['Its',
#   'close',
#   'ankobra',
#   'River',
#   'calm',
#   'refreshing',
#   'staff',
#   'welcoming',
#   'friendly',
#   'food',
#   'great'],
#  ['Passed', 'briefly', 'Excellent', 'service', 'Good', 'location'],
#  ['Comfortable', 'friendly', 'staff'],
#  ['The', 'place', 'amazing', 'guy', 'got', 'ta', 'go'],
#  ['Nice', 'place', 'good', 'customer', 'service'],
#  ['Fantastic'],
#  ['Nice', 'ambiance'],
#  ['Nice', 'neat', 'new'],
#  ['Green',
#   'Zion',
#   'Garden',
#   'host',
#   'Ellis',
#   'left',
#   'imprint',
#   'heart',
#   'I',
#   'never',
#   'forget',
#   'Thank'],
#  ['Green',
#   'Zion',
#   'Garden',
#   'actual',
#   'paradise',
#   'The',
#   'various',
#   'little',
#   'large',
#   'room',
#   'like',
#   'natural',
#   'hobbit',
#   'house',
#   'No',
#   'Aircon',
#   'sure',
#   'fan',
#   'grand',
#   'There',
#   'tree',
#   'house',
#   'The',
#   'garden',
#   'immaculate',
#   'green',
#   'indeed',
#   'Beautiful',
#   'flower',
#   'plant',
#   'tree',
#   'There',
#   'bird',
#   'dragonfly',
#   'friendly',
#   'goat',
#   'couple',
#   'friendly',
#   'dog',
#   'It',
#   'right',
#   'beach',
#   'Ellis',
#   'beautifully',
#   'decorated',
#   'wooden',
#   'bar',
#   'He',
#   'feed',
#   'delicious',
#   'veggie',
#   'food',
#   'serve',
#   'tasty',
#   'drink',
#   'He',
#   'got',
#   'best',
#   'smile',
#   'growing',
#   '_',
#   'heartThere',
#   'seat',
#   'shaded',
#   'bed',
#   'ocean',
#   'The',
#   'beach',
#   'clean',
#   'rubbish',
#   'The',
#   'cleanest',
#   'I',
#   'seen',
#   'Ghana',
#   'I',
#   'stayed',
#   'longer',
#   'I',
#   'go',
#   'back',
#   'one',
#   'day',
#   'The',
#   'village',
#   'Butre',
#   'across',
#   'rickety',
#   'Indiana',
#   'Jones',
#   'style',
#   'bridge',
#   'bustling',
#   'lively',
#   'fishy',
#   'place',
#   'The',
#   'child',
#   'ran',
#   'fistbumps',
#   'hi',
#   'five',
#   'Goats',
#   'chicken',
#   'dog',
#   'everywhere',
#   'We',
#   'got',
#   'motorbike',
#   'Asa',
#   'Baako',
#   'Festival',
#   'Busua',
#   'walked',
#   'back',
#   'full',
#   'moon',
#   'illuminating',
#   'way',
#   'across',
#   'beach',
#   'headtorches',
#   'helping',
#   'path',
#   'bush',
#   'hilly',
#   'headland',
#   'bird',
#   'frog',
#   'insect',
#   'providing',
#   'soundtrack',
#   'A',
#   'magical',
#   'special',
#   'place',
#   'seems',
#   'growing',
#   'even',
#   'better',
#   'new',
#   'build',
#   'idea',
#   'Loved',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   '_',
#   'smiling',
#   '_',
#   'eye'],
#  ['I',
#   'crossed',
#   'rendomly',
#   'Green',
#   'garden',
#   'eco',
#   'lodge',
#   'I',
#   'trekking',
#   'coast',
#   'I',
#   'met',
#   'Ellis',
#   'positive',
#   'funny',
#   'man',
#   'We',
#   'ate',
#   'together',
#   'good',
#   'fun',
#   'He',
#   'show',
#   'lodge',
#   'clean',
#   'nice',
#   'place',
#   'The',
#   'garden',
#   'crazy',
#   'good',
#   'moment',
#   'vibe'],
#  ['Very',
#   'green',
#   'space',
#   'cool',
#   'environment',
#   'Great',
#   'gardening',
#   'eco',
#   'lodge',
#   'experience'],
#  ['They',
#   'OM',
#   'sign',
#   'outside',
#   'board',
#   'You',
#   'see',
#   'cat',
#   'around',
#   '10',
#   'minute',
#   'drive',
#   'fantas',
#   'folly',
#   'He',
#   'know',
#   'cook',
#   'indian',
#   'food',
#   'The',
#   'man',
#   'offer',
#   'everything',
#   'want',
#   'Posting',
#   'picture',
#   'review',
#   'Offering',
#   'free',
#   'private',
#   'parking',
#   'onsite',
#   'Green',
#   'Zion',
#   'Garden',
#   'offer',
#   'pet',
#   'friendly',
#   'accommodation',
#   'Butre',
#   'The',
#   'bed',
#   'breakfast',
#   'lawn',
#   'hammock',
#   'guest',
#   'located',
#   'garden',
#   'Guests',
#   'enjoy',
#   'meal',
#   'outside',
#   'garden',
#   'restaurant',
#   'serf',
#   'local',
#   'Indian',
#   'International',
#   'cuisine',
#   'The',
#   'property',
#   'onsite',
#   'bar',
#   'garden',
#   'also',
#   'coffee',
#   'shop',
#   'You',
#   'find',
#   'shared',
#   'lounge',
#   'property',
#   'Thai',
#   'yoga',
#   'massage',
#   'treatment',
#   'available'],
#  ['Paradise', 'Ghana'],
#  ['Wooow', 'special', 'place', 'incredible'],
#  ['I',
#   'almost',
#   'want',
#   'recommend',
#   'green',
#   'zion',
#   'garden',
#   'Hidden',
#   'gem',
#   'Moreover',
#   'Ellis',
#   'host',
#   'honestly',
#   'best',
#   'Guy',
#   'met',
#   'Ghana',
#   'If',
#   'want',
#   'best',
#   'round',
#   'experience',
#   'Ghana',
#   'visit',
#   'Ellis',
#   'place',
#   'welcome',
#   'Zion',
#   'garden'],
#  ['Affable',
#   'owner',
#   'good',
#   'food',
#   'great',
#   'relax',
#   'All',
#   'sited',
#   'beautiful',
#   'skilfully',
#   'elaborated',
#   'garden',
#   'Will',
#   'come'],
#  ['A',
#   'place',
#   'amazing',
#   'garden',
#   'Ellis',
#   'great',
#   'job',
#   'care',
#   'guest',
#   'good',
#   'food',
#   'clean',
#   'room'],
#  ['Amazing', 'place', 'butre'],
#  ['Super',
#   'lovely',
#   'place',
#   'Set',
#   'serene',
#   'beautiful',
#   'ambiance',
#   'one',
#   'Ghana',
#   'beautiful',
#   'coastline',
#   'Green',
#   'Zion',
#   'Garden',
#   'perfect',
#   'location',
#   'good',
#   'relaxation',
#   'good',
#   'peaceful',
#   'unwinding',
#   'My',
#   'host',
#   'Ellis',
#   'super',
#   'amazing',
#   'A',
#   'super',
#   'friendly',
#   'hardworking',
#   'open',
#   'minded',
#   'gentle',
#   'rasta',
#   'man',
#   'His',
#   'vegetarian',
#   'cooking',
#   'top',
#   'notch',
#   'His',
#   'knowledge',
#   'sharing',
#   'experience',
#   'great',
#   'He',
#   'prepared',
#   'bonfire',
#   'kind',
#   'good',
#   'drummer',
#   'pretty',
#   'please',
#   'let',
#   'sing',
#   'The',
#   'various',
#   'lodge',
#   'dormitory',
#   'upper',
#   'deck',
#   'tree',
#   'house',
#   'neat',
#   'lovely',
#   'awash',
#   'beautiful',
#   'color',
#   'traditional',
#   'fabric',
#   'Bonus',
#   'request',
#   'coconut',
#   'get',
#   'fresh',
#   'one',
#   'cut',
#   'tree',
#   'right',
#   'face',
#   'I',
#   'sure'],
#  ['We',
#   'passed',
#   'dinner',
#   '06',
#   '2018',
#   'atmosphere',
#   'restaurant',
#   'lounge',
#   'indescribable',
#   'After',
#   'fantastic',
#   'food',
#   'grabbed',
#   'Djembe',
#   'guitar',
#   'sang',
#   'together',
#   'host',
#   'moonlight',
#   'garden',
#   'late',
#   'night',
#   'Nice',
#   'place',
#   'An',
#   'unforgettable',
#   'evening'],
#  ['Green',
#   'zion',
#   'garden',
#   'offer',
#   'nice',
#   'stay',
#   'great',
#   'garden',
#   'djungle',
#   'feeling',
#   'friendly',
#   'host',
#   'gladly',
#   'show',
#   'around',
#   'area',
#   'Pancakes',
#   'recommended'],
#  ['A',
#   'friend',
#   'wedding',
#   'refreshment',
#   'held',
#   'venue',
#   'Warm',
#   'reception',
#   'given',
#   'u'],
#  ['Very',
#   'fun',
#   'see',
#   'distance',
#   'Agartha',
#   'Overlords',
#   'Da',
#   'God',
#   'Squad'],
#  ['The',
#   'customer',
#   'service',
#   'excellent',
#   'worker',
#   'friendly',
#   'give',
#   'wonderful',
#   'reception',
#   'room',
#   'clean',
#   'I',
#   'lodge'],
#  ['It', 'best', 'Spend', 'night', 'love', 'It', 'great'],
#  ['A', 'great', 'place'],
#  ['Good', 'environment'],
#  ['The',
#   'pool',
#   'side',
#   'spacious',
#   'parking',
#   'space',
#   'say',
#   'reception',
#   'security',
#   'give',
#   'entry',
#   'premise',
#   'say'],
#  ['Nice', 'hotel', 'An', 'ok', 'rest', 'place'],
#  ['The', 'hotel', 'nice', 'beautiful', 'I', 'always', 'recommend', 'anyone'],
#  ['Is', 'nice', 'plce', 'bushy', 'area'],
#  ['Very', 'cool', 'environment'],
#  ['Simply', 'home', 'away', 'home'],
#  ['Love', 'hotel'],
#  ['Very',
#   'hospitable',
#   'staff',
#   'helpful',
#   'improve',
#   'restaurant',
#   'service'],
#  ['Most',
#   'quiet',
#   'perfect',
#   'place',
#   'stay',
#   'away',
#   'busy',
#   'street',
#   'tadi'],
#  ['Nice', 'place', 'rest'],
#  ['Good', 'service'],
#  ['Nice', 'cheap', 'place', 'kindly', 'team'],
#  ['It', 'cool', 'place', 'great', 'view', 'Very', 'serene'],
#  ['Very', 'nice', 'affordable', 'place', 'visit'],
#  ['Great', 'place'],
#  ['The',
#   'amenity',
#   'room',
#   'poolside',
#   'restaurant',
#   'etc',
#   'world',
#   'class',
#   'Their',
#   'meal',
#   'equally',
#   'tasty',
#   'cost',
#   'Ghc100',
#   '9',
#   '10',
#   'They',
#   'amiable',
#   'staff'],
#  ['The',
#   'experience',
#   'Alliance',
#   'super',
#   'good',
#   'OK',
#   '_',
#   'hand',
#   'beautiful',
#   'environment',
#   'service',
#   'importantly',
#   'staff',
#   'To',
#   'mention',
#   'Hnel',
#   '5',
#   'star',
#   'manager',
#   'sense',
#   'humour',
#   'HUMILITY',
#   'Samuel',
#   'ever',
#   'smiling',
#   'dude',
#   'service',
#   'etc',
#   'Kafui',
#   'Front',
#   'Desk',
#   'personnel',
#   'swag',
#   'Jacqueline',
#   'calm',
#   'wonderful',
#   'person',
#   'ensuring',
#   'everything',
#   'OK',
#   'Thanks',
#   'smiling',
#   '_',
#   'face'],
#  ['It',
#   'quiet',
#   'hotel',
#   'room',
#   'need',
#   'cleaning',
#   'The',
#   'furniture',
#   'bathroom',
#   'outdated'],
#  ['Absolutely',
#   'exquisite',
#   'nestled',
#   'beach',
#   'road',
#   'area',
#   'Takoradi',
#   'Alliance',
#   'home',
#   'away',
#   'home',
#   'For',
#   'business',
#   'traveller',
#   'well',
#   'seeking',
#   'pleasure'],
#  ['Not',
#   'beautiful',
#   'picture',
#   'review',
#   'I',
#   'saw',
#   'looked',
#   'quite',
#   'tight',
#   'spacious',
#   'enough',
#   'But',
#   'good',
#   'side',
#   'stay',
#   'long',
#   'enough',
#   'find',
#   'though'],
#  ['Worthy', 'experience'],
#  ['Clean',
#   'serene',
#   'location',
#   'friendly',
#   'staff',
#   'The',
#   'room',
#   'small',
#   'well',
#   'maintained'],
#  ['Don',
#   'know',
#   'whether',
#   'season',
#   'thus',
#   'staff',
#   'overwhelmed',
#   'service',
#   'left',
#   'soo',
#   'much',
#   'desired'],
#  ['Their', 'food', 'exquisite'],
#  ['Cozy', 'place', 'great', 'service', 'value', 'money'],
#  ['This',
#   'one',
#   'nice',
#   'big',
#   'hotel',
#   'Takoradi',
#   'I',
#   'hoping',
#   'better',
#   'experience',
#   'I',
#   'especially',
#   'knowing',
#   'owned',
#   'Eagles',
#   'Their',
#   'staff',
#   'generally',
#   'nice',
#   'service',
#   'poor',
#   'The',
#   'breakfast',
#   'buffet',
#   'limited',
#   'We',
#   'option',
#   'food',
#   '3',
#   'night',
#   'stay',
#   'breakfast',
#   'I',
#   'add',
#   'favourite',
#   'place',
#   'Takoradi',
#   'Hopefully',
#   'improve',
#   'soon'],
#  ['Nice', 'place'],
#  ['If',
#   'best',
#   'among',
#   'best',
#   'hotel',
#   'Takoradi',
#   'Ghana',
#   'whole',
#   'hundred',
#   '_',
#   'point',
#   'red',
#   '_',
#   'heart'],
#  ['I', 'sound', 'mind', 'learning'],
#  ['We',
#   'stayed',
#   'hotel',
#   'family',
#   'vacation',
#   'amazing',
#   'time',
#   'The',
#   'staff',
#   'friendly',
#   'went',
#   'beyond',
#   'make',
#   'stay',
#   'enjoyable'],
#  ['My',
#   'staying',
#   'Alliance',
#   'peaceful',
#   'perfect',
#   'The',
#   'access',
#   'road',
#   'hotel',
#   'must',
#   'looked'],
#  ['Bad',
#   'experience',
#   'Had',
#   'change',
#   'room',
#   'Stained',
#   'mattress',
#   'broken',
#   'window',
#   'broken',
#   'toilet',
#   'seat',
#   'many',
#   'issue'],
#  ['Unpaved',
#   'road',
#   'leading',
#   'hotel',
#   'roomservice',
#   'taking',
#   'almost',
#   '1',
#   '5hours',
#   'deliver',
#   'simple',
#   'meal',
#   'diarrhea',
#   'food',
#   'water',
#   'shower',
#   'spraying',
#   'water',
#   'ceiling',
#   'floor',
#   'guest',
#   'playing',
#   'loud',
#   'music',
#   'pool',
#   'male',
#   'guest',
#   'staring',
#   'inappropriately',
#   'gym',
#   'reception',
#   'taking',
#   'immediate',
#   'action',
#   'afterwards',
#   'recommend',
#   'hotel',
#   'anyone',
#   'especially',
#   'female',
#   'foreigner'],
#  ['It',
#   'amazingly',
#   'serene',
#   'luxurious',
#   'place',
#   'spend',
#   'night',
#   'forget',
#   'world'],
#  ['Very', 'nice', 'lodge'],
#  ['Nice', 'place'],
#  ['I',
#   'stayed',
#   'hotel',
#   'work',
#   'related',
#   'retreat',
#   'liked',
#   'experience',
#   'The',
#   'room',
#   'clean',
#   'facility',
#   'standard',
#   'Their',
#   'front',
#   'desk',
#   'staff',
#   'friendly',
#   'welcoming',
#   'two',
#   'staff',
#   'depict',
#   'trait',
#   'Their',
#   'conference',
#   'room',
#   'ok',
#   'even',
#   'though',
#   'I',
#   'think',
#   'arrangement',
#   'furniture',
#   'fit',
#   'purpose',
#   'given',
#   'nature',
#   'engagement',
#   'I',
#   'get',
#   'use',
#   'facility',
#   'gym',
#   'I',
#   'attest',
#   'availability',
#   'state',
#   'Overall',
#   'lovely',
#   'place',
#   'especially',
#   'weekend',
#   'getaway'],
#  ['There', 'lovely', 'ambience', 'I', 'really', 'enjoyed', 'buffet', 'dinner'],
#  ['Serene', 'environment'],
#  ['The', 'best', 'come', 'West'],
#  ['Hotel',
#   'normal',
#   'I',
#   'wrote',
#   'pool',
#   'I',
#   'kicked',
#   'I',
#   'would',
#   'like',
#   'write',
#   'pool',
#   'high',
#   'Fix',
#   'bug',
#   'pancreas',
#   'norm',
#   'P',
#   'S',
#   'I',
#   'left',
#   'goose',
#   'room',
#   'throw',
#   'Tinkoff',
#   'Bitoch'],
#  ['smiling',
#   '_',
#   'face',
#   '_',
#   '_',
#   'hearteyes',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   '_',
#   'hearteyes',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   '_',
#   'hearteyes',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   '_',
#   'hearteyes',
#   'I',
#   'loved',
#   'stay',
#   'hotel',
#   'The',
#   'room',
#   'fabulous',
#   'Furniture',
#   'adorable',
#   'The',
#   'bedstead',
#   'classy',
#   'display',
#   'transparent',
#   'material',
#   'super',
#   'comfortable',
#   'mattress',
#   'bedding',
#   'The',
#   'view',
#   'window',
#   'beautiful',
#   'Showing',
#   'pool',
#   'vast',
#   'green',
#   'field',
#   'around',
#   'hotel',
#   'Washroom',
#   'housekeeping',
#   'breakfast',
#   'point',
#   'Rooms',
#   'Rates',
#   'little',
#   'high',
#   'side',
#   'In',
#   'evening',
#   'holiday',
#   'live',
#   'band',
#   'music',
#   'must',
#   'Anytime',
#   'I',
#   'back',
#   'Takoradi',
#   'I',
#   'surely',
#   'visit'],
#  ['Management',
#   'look',
#   'thing',
#   'thing',
#   'way',
#   'expensive',
#   '4pcs',
#   'spring',
#   'roll',
#   '100gh',
#   'n',
#   'opinion',
#   'u',
#   'guy',
#   'losing',
#   'customer',
#   'co',
#   'alot',
#   'pple',
#   'complaining',
#   'price',
#   'thanks'],
#  ['Great', 'hotel', 'Takoradi', 'nice', 'view', 'ocean'],
#  ['indeed',
#   'play',
#   'play',
#   'Eiiii',
#   'takodi',
#   'We',
#   'something',
#   'red',
#   '_',
#   'heart',
#   'globe',
#   '_',
#   'showing',
#   '_',
#   'EuropeAfrica',
#   'ry',
#   'folded',
#   '_',
#   'hand',
#   'Takoradi',
#   'World',
#   'wind',
#   '_',
#   'face'],
#  ['Walk',
#   'inn',
#   'shower',
#   'Moderate',
#   'neat',
#   'comfortable',
#   'room',
#   'There',
#   '3',
#   'swimming',
#   'pool',
#   'kid',
#   'normal',
#   'Olympic',
#   'size',
#   'Well',
#   'maintained',
#   'Dining',
#   'either',
#   'pool',
#   'side',
#   'dinning',
#   'area',
#   'whatever',
#   'comfortable',
#   'relaxing',
#   'lover',
#   'family',
#   'business',
#   'meeting',
#   'indoors',
#   'outdoors',
#   'I',
#   'view',
#   'go',
#   'beach',
#   'golf',
#   'course',
#   'football',
#   'pitch',
#   'swimming',
#   'pool',
#   'comfort',
#   'room',
#   'This',
#   'OK',
#   '_',
#   'hand',
#   'Guess',
#   'The',
#   'meal',
#   'expensive',
#   'I',
#   'imagined',
#   'Wifi',
#   'unreliable'],
#  ['Calm', 'space', 'accessible', 'Takoradi', 'city', 'It', 'beach', 'road'],
#  ['Clean',
#   'room',
#   'warm',
#   'staff',
#   'reception',
#   'good',
#   'variety',
#   'option',
#   'buffet',
#   'breakfast',
#   'menu',
#   'Lovely',
#   'view',
#   'ocean',
#   'lovely',
#   'landscape',
#   'hotel',
#   'room'],
#  ['Great', 'view', 'Serene', 'environment'],
#  ['Pizza', 'nice', 'Friendly', 'lovely', 'environment', 'scenic', 'view'],
#  ['Awesome', 'relaxing', 'hotel', 'good', 'business', 'family'],
#  ['The',
#   'Ghana',
#   'Institution',
#   'Engineering',
#   'held',
#   'annual',
#   'banquet',
#   'dinner',
#   'food',
#   'tasty',
#   'Set',
#   'AGM',
#   'also',
#   'great',
#   'Nice',
#   'place'],
#  ['Still', 'great', 'place', 'Takoradi'],
#  ['Nice', 'wonderful', 'place', 'relax', 'work'],
#  ['5',
#   'star',
#   'This',
#   'said',
#   'Everything',
#   'super',
#   'food',
#   'rest',
#   'amenity',
#   'etc'],
#  ['Thank', 'management', 'Staff', 'Excellent', 'service'],
#  ['Fantastic'],
#  ['The',
#   'hotel',
#   'nice',
#   'however',
#   'price',
#   'resort',
#   'cheap',
#   '4',
#   'star',
#   'hotel',
#   'I',
#   'expecting',
#   'higher',
#   'standard',
#   'We',
#   'booked',
#   'seaview',
#   'chalet',
#   'could',
#   'see',
#   'sea',
#   'due',
#   'back',
#   'gate',
#   'tree',
#   'The',
#   'building',
#   'need',
#   'renovated',
#   'The',
#   'shower',
#   'draining',
#   'properly',
#   'swimming',
#   'pool',
#   'lounge',
#   'chair',
#   'good',
#   'condition',
#   'pool',
#   'bed',
#   'dirty',
#   'We',
#   'hot',
#   'water',
#   'first',
#   'day',
#   'night',
#   'rectified',
#   'first',
#   'shower',
#   'cold',
#   'We',
#   'power',
#   'cut',
#   'lasted',
#   'hour',
#   'The',
#   'hotel',
#   'operational',
#   'generator',
#   'The',
#   'positive',
#   'thing',
#   'breakfast',
#   'buffet',
#   'continental',
#   'freshly',
#   'cooked',
#   'food',
#   'including',
#   'local',
#   'food',
#   'tasty'],
#  ['Air',
#   'conditioning',
#   'poor',
#   'I',
#   'hardly',
#   'slept',
#   'night',
#   'Pillows',
#   'like',
#   'big',
#   'gummy',
#   'bear',
#   'extremely',
#   'firm',
#   'round',
#   'Had',
#   'food',
#   'outside',
#   'back',
#   'ok'],
#  ['Very',
#   'good',
#   'hotel',
#   'clean',
#   'room',
#   'comfortable',
#   'delicious',
#   'food',
#   'best',
#   'hotel',
#   'stay',
#   'Takoradi',
#   'opinion'],
#  ['Great', 'resort'],
#  ['It',
#   'absolutely',
#   'beautiful',
#   'Staff',
#   'friendly',
#   'caring',
#   'An',
#   'excellent',
#   'selection',
#   'food',
#   'menu',
#   'Perhaps',
#   'larger',
#   'selection',
#   'onsite',
#   'entertainment',
#   'would',
#   'make',
#   'perfect',
#   'getaway',
#   'stay'],
#  ['I',
#   'absolutely',
#   'loved',
#   'stay',
#   'Red',
#   'Mango',
#   'I',
#   'honeymoon',
#   'lovely',
#   'Their',
#   'room',
#   'really',
#   'neat',
#   'modern',
#   'staff',
#   'welcoming',
#   'friendly',
#   'professional',
#   'pool',
#   'food',
#   'environment',
#   'access',
#   'town',
#   'etc',
#   'It',
#   'perfect',
#   'hideout',
#   'u'],
#  ['Service',
#   'location',
#   'top',
#   'notch',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   '_',
#   'smiling',
#   '_',
#   'eyesOK',
#   '_',
#   'hand'],
#  ['I', 'recommend', 'everyone', 'best', 'place'],
#  ['Well',
#   'arranged',
#   'apartment',
#   'good',
#   'comfort',
#   'couple',
#   'family',
#   'Well',
#   'located',
#   'heart',
#   'Takoradi'],
#  ['I',
#   'great',
#   'time',
#   'Red',
#   'mango',
#   'hotel',
#   'The',
#   'service',
#   'excellent',
#   'food',
#   'room',
#   'nice'],
#  ['This',
#   'located',
#   'serene',
#   'area',
#   'Takoradi',
#   'Very',
#   'close',
#   'road',
#   'easily',
#   'accessible',
#   'The',
#   'room',
#   'cool',
#   'quite',
#   'average',
#   'Their',
#   'service',
#   'nice',
#   'The',
#   'one',
#   'attended',
#   'smart',
#   'professional'],
#  ['The',
#   'environment',
#   'serene',
#   'Great',
#   'view',
#   'night',
#   'Good',
#   'dinner',
#   'couple',
#   'night'],
#  ['The', 'room', 'nice', 'comfy', 'Beautiful', 'experience'],
#  ['I',
#   'amazing',
#   'experience',
#   'would',
#   'definitely',
#   'recommend',
#   'anyone',
#   'looking',
#   'visit',
#   'Takoradi',
#   'soon'],
#  ['Couldn', 'asked', 'better', 'Services', 'top', 'notch'],
#  ['Red',
#   'Mango',
#   'awesome',
#   'interior',
#   'design',
#   'And',
#   'room',
#   'really',
#   'neat',
#   'I',
#   'personally',
#   'loved',
#   'washroom',
#   'Top',
#   'class'],
#  ['It',
#   'lovely',
#   'Clean',
#   'room',
#   'Staff',
#   'polite',
#   'professional',
#   'I',
#   'enjoyed',
#   'stay',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   '_',
#   'heart'],
#  ['I', 'enjoyed', 'stay'],
#  ['Very', 'comfortable', 'serene', 'environment', 'I', 'go'],
#  ['The',
#   'facility',
#   'exceeded',
#   'expectation',
#   'The',
#   'bed',
#   'comfortable',
#   'living',
#   'room',
#   'spacious',
#   'kitchenette',
#   'useful',
#   'breastfeeding',
#   'mum',
#   'I',
#   'love',
#   'fridge',
#   'sizeable',
#   'freezer',
#   'unit',
#   'However',
#   'smell',
#   'room',
#   'quite',
#   'strong',
#   'Smelt',
#   'like',
#   'sewage',
#   'something',
#   'dump',
#   'dry',
#   'properly',
#   'especially',
#   'area',
#   'around',
#   'vent',
#   'kitchen',
#   'Regardless',
#   'I',
#   'impressed',
#   'enjoyed',
#   'stay'],
#  ['It',
#   'really',
#   'lovely',
#   'place',
#   'Apartments',
#   'neat',
#   'feel',
#   'like',
#   'home',
#   'Their',
#   'pool',
#   'tidy',
#   'customer',
#   'service',
#   'excellent'],
#  ['Excellent', 'OK', '_', 'hand'],
#  ['Love', 'pool'],
#  ['Best',
#   'New',
#   'hide',
#   'takoradi',
#   'Lovely',
#   'room',
#   'Very',
#   'friendly',
#   'staff',
#   'Will',
#   'go',
#   'get',
#   'request',
#   'met',
#   'Only',
#   'problem',
#   'pool',
#   'unattended',
#   'And',
#   'I',
#   'saw',
#   'crow',
#   'bathing',
#   'Not',
#   'healthy',
#   'Hopefully',
#   'addressed'],
#  ['The',
#   'best',
#   'hotel',
#   'business',
#   'vacation',
#   'nutritious',
#   'assorted',
#   'food',
#   'every',
#   'occasion'],
#  ['Nice', 'place'],
#  ['Lovely',
#   'apartment',
#   'high',
#   'quality',
#   'finishing',
#   'kitchenette',
#   'facility',
#   'provides',
#   'catering',
#   'service',
#   'well',
#   'There',
#   'daily',
#   'room',
#   'cleaning',
#   'staff',
#   'top',
#   'notch',
#   'professional',
#   'friendly',
#   'There',
#   'infinity',
#   'pool',
#   'set',
#   'peaceful',
#   'garden',
#   'Great',
#   'place',
#   'work',
#   'travel',
#   'get',
#   'away'],
#  ['A', 'cozy', 'relaxing', 'place', 'whole', 'family'],
#  ['Lovely',
#   'serene',
#   'place',
#   'The',
#   'waitress',
#   'happy',
#   'serve',
#   'u',
#   'It',
#   'good',
#   'accommodation',
#   'pick',
#   'In',
#   'Takoradi',
#   'day'],
#  ['Nice', 'place', 'bar', 'area'],
#  ['What',
#   'place',
#   'siren',
#   'environment',
#   'perfect',
#   'come',
#   'service',
#   'render',
#   'guest'],
#  ['Best', 'Place', 'ever', 'visit'],
#  ['Gives', 'comfortable', 'home', 'away', 'home'],
#  ['W'],
#  ['Great'],
#  ['Indeed', 'nice', 'place'],
#  ['Beautiful', 'Compound'],
#  ['Cozy', 'room', 'Serene', 'environment'],
#  ['Nice', 'environment'],
#  ['Nice'],
#  ['Sedelam',
#   'Lodge',
#   'home',
#   'away',
#   'home',
#   'U',
#   'never',
#   'regret',
#   'cherish',
#   'comfort',
#   'Cousy',
#   'serene',
#   'Will',
#   'recommend',
#   'Sedelam',
#   'day',
#   '100',
#   'OK',
#   '_',
#   'hand'],
#  ['A', 'Good', 'hotel', 'Aboadzi', 'enclave'],
#  ['Nice', 'place', 'thumb', '_'],
#  ['A',
#   'Cool',
#   'Nice',
#   'place',
#   'lodge',
#   'Excellent',
#   'client',
#   'service',
#   'I',
#   'highly',
#   'recommend',
#   'Sedelam',
#   'Lodge',
#   'anyone',
#   'looking',
#   'cool',
#   'place',
#   'lodge',
#   'Takoradi',
#   'red',
#   '_',
#   'heart'],
#  ['Friendly',
#   'staff',
#   'well',
#   'managed',
#   'Serene',
#   'environment',
#   'It',
#   'must',
#   'looking',
#   'change',
#   'usual',
#   'buzz',
#   'city',
#   'relax',
#   'fun'],
#  ['A',
#   'nice',
#   'place',
#   'countryside',
#   'vacation',
#   'Beautiful',
#   'environment',
#   'great',
#   'reception',
#   'I',
#   'recommend',
#   'place'],
#  ['Beautiful',
#   'environment',
#   'excellent',
#   'service',
#   'I',
#   'really',
#   'enjoyed',
#   'stay',
#   'great',
#   'customer',
#   'service',
#   'provided',
#   'I',
#   'recommend',
#   'visit',
#   'More',
#   'home'],
#  ['My',
#   'Honeymoon',
#   'stay',
#   'Sedelam',
#   'Lodge',
#   'best',
#   'It',
#   'serene',
#   'beautiful',
#   'edifice',
#   'comfortable',
#   'king',
#   'Queen',
#   'size',
#   'bed',
#   'sedelam',
#   'red',
#   '_',
#   'heart',
#   'red',
#   '_',
#   'heart'],
#  ['Great',
#   'environment',
#   'Nice',
#   'comfortable',
#   'room',
#   'My',
#   'family',
#   'I',
#   'totally',
#   'enjoyed',
#   'stay'],
#  ['VERY', 'COMFORTABLE', 'LODGE', 'TO', 'BE', 'BEST', 'EXPERIENCE'],
#  ['Great',
#   'place',
#   'serene',
#   'area',
#   'If',
#   'need',
#   'place',
#   'away',
#   'hustle',
#   'bustle',
#   'city',
#   'get',
#   'business',
#   'Sedelam',
#   'place'],
#  ['Excellent',
#   'Hotel',
#   'Service',
#   'Serene',
#   'Environment',
#   'Nice',
#   'room',
#   'I',
#   'loved',
#   'stay'],
#  ['Serene'],
#  ['Nice'],
#  ['Nice', 'serene', 'view'],
#  ['A',
#   'well',
#   'managed',
#   'lodge',
#   'decent',
#   'facility',
#   'I',
#   'rate',
#   '3',
#   'star',
#   'minor',
#   'factor'],
#  ['Boarding', 'facility', 'provided', 'College'],
#  ['The', 'place', 'cool', 'refreshing'],
#  ['Guest',
#   'House',
#   'located',
#   'top',
#   'volley',
#   'irregular',
#   'staircase',
#   'steeped',
#   'inconvenient',
#   'access',
#   'Superb',
#   'view',
#   'city',
#   'sea',
#   'Vast',
#   'clean',
#   'without',
#   'insured',
#   'running',
#   'water',
#   'Staff',
#   'empathy',
#   'Ni',
#   'wifi',
#   'contrary',
#   'mentioned',
#   'This',
#   'little',
#   'complicated',
#   'center',
#   'manage',
#   'past',
#   '18',
#   'hour',
#   'end',
#   'service',
#   'Taxi',
#   'Taxis'],
#  ['Not', 'bad', 'careful', 'address', 'provided'],
#  ['I',
#   'enjoyed',
#   'stay',
#   'Very',
#   'big',
#   'room',
#   'good',
#   'location',
#   'great',
#   'sea',
#   'view',
#   'even',
#   'community',
#   'view',
#   'I',
#   'wake',
#   'every',
#   'morning',
#   'standing',
#   'corridor',
#   'viewing',
#   'sea',
#   'also',
#   'see',
#   'people',
#   'passing',
#   'It',
#   'life',
#   'worth',
#   'Just',
#   'little',
#   'challenge',
#   'booking',
#   'com',
#   'breakfast',
#   'started',
#   'understood',
#   'mistake',
#   'booking',
#   'page',
#   'Apart',
#   'good'],
#  ['Nice',
#   'place',
#   'affordable',
#   'I',
#   'wished',
#   'constant',
#   'water',
#   'flow',
#   'Wifi',
#   'Aside',
#   'everything',
#   'else',
#   'average'],
#  ['Was', 'fantastic'],
#  ['Nice', 'place'],
#  ['Cool', 'place'],
#  ['It', 'cool', 'I', 'love'],
#  ['Room', 'quite', 'spacious', 'No', 'running', 'water'],
#  ['It', 'ok'],
#  ['Was', 'really', 'happy', 'long', 'time', 'residing', 'wonderful', 'year'],
#  ['Cool'],
#  ['oh', 'like', 'see', 'township', 'room', 'spacious', 'bar', 'spa'],
#  ['Free', 'WiFi', 'Internet', 'access'],
#  ['Affordable', 'beautiful'],
#  ['They',
#   'use',
#   'breakfast',
#   'Access',
#   'complex',
#   'several',
#   'step',
#   'It',
#   'moderately',
#   'decent',
#   'price',
#   'ask',
#   'The',
#   'view',
#   'pretty'],
#  ['Yaa'],
#  ['This',
#   'guest',
#   'house',
#   'treat',
#   'visitor',
#   'nice',
#   'place',
#   'indeed',
#   'meant',
#   'relaxation'],
#  ['Perfect',
#   'sense',
#   'peaceful',
#   'place',
#   'well',
#   'situated',
#   'lovely',
#   'staff',
#   'always',
#   'help',
#   'It',
#   'pleasure',
#   'I',
#   'highly',
#   'recommend'],
#  ['Comfortable', 'peaceful'],
#  ['Good'],
#  ['The', 'place', 'well', 'equipped', 'specially', 'room', 'good', 'offer'],
#  ['Vacation', 'went', 'swim'],
#  ['Bad', 'network', 'serene', 'environment'],
#  ['Incredibly',
#   'nice',
#   'helpful',
#   'staff',
#   'willing',
#   'always',
#   'advise',
#   'help',
#   'We',
#   'enjoyed',
#   'lot'],
#  ['Nice',
#   'pool',
#   'good',
#   'place',
#   'socialise',
#   'especially',
#   'weekend',
#   'holiday'],
#  ['Nice',
#   'hotel',
#   'affordable',
#   'hotel',
#   'Got',
#   'pool',
#   'gym',
#   'restaurant',
#   'friendly',
#   'effective',
#   'staff'],
#  ['FRIENDLY',
#   'STAFF',
#   'AND',
#   'GREAT',
#   'ENVIRONMENT',
#   'AS',
#   'WELL',
#   'I',
#   'RECOMMEND',
#   'TO',
#   'EVERYONE',
#   'VISITING',
#   'CAPE',
#   'COAST',
#   'LODGE',
#   'THERE'],
#  ['It', 'nice', 'place'],
#  ['It', 'nice', 'place'],
#  ['Nice',
#   'place',
#   'Kindly',
#   'fix',
#   'road',
#   'leading',
#   'facility',
#   'The',
#   'network',
#   'terrible',
#   'great',
#   'place'],
#  ['Very', 'good', 'Services'],
#  ['It',
#   'good',
#   'hotel',
#   'serene',
#   'area',
#   'It',
#   'fitness',
#   'center',
#   'bar',
#   'swimming',
#   'pool'],
#  ['I',
#   'enjoyed',
#   'place',
#   'safe',
#   'room',
#   'neat',
#   'service',
#   'nice',
#   'location',
#   'awesome'],
#  ['Nice', 'place', 'cool', 'family', 'event'],
#  ['Infact', 'I', 'design', 'room', 'spacious', 'You', 'comfort'],
#  ['Very', 'serene', 'environment'],
#  ['It', 'nice', 'place', 'amazing', 'envernoment'],
#  ['Excited'],
#  ['Good'],
#  ['Nice', 'atmosphere'],
#  ['Cool', 'place'],
#  ['Its',
#   'nice',
#   'place',
#   'We',
#   'went',
#   'swim',
#   'pool',
#   'student',
#   'We',
#   'enjoyed',
#   'clean',
#   'water',
#   'fun'],
#  ['Fun'],
#  ['Cool', 'place'],
#  ['I',
#   'met',
#   'one',
#   'manager',
#   'Richard',
#   'super',
#   'good',
#   'Excellent',
#   'customer',
#   'service',
#   'They',
#   'clean',
#   'room',
#   'get',
#   'little',
#   'heated',
#   'afternoon'],
#  ['I',
#   'think',
#   'management',
#   'need',
#   'step',
#   'game',
#   'Room',
#   'service',
#   'good',
#   'I',
#   'yet',
#   'know',
#   'guest',
#   'house',
#   'charge',
#   'Gh100',
#   'night',
#   'without',
#   'serving',
#   'Breakfast',
#   'even',
#   'tying',
#   'get',
#   'food',
#   'around',
#   'area',
#   'quite',
#   'challenge'],
#  ['Friendly', 'staff'],
#  ['To',
#   'recommend',
#   'dirty',
#   'hot',
#   'place',
#   'common',
#   'toilet',
#   'locate',
#   'towel',
#   'soap',
#   'shower',
#   'trash',
#   'bedroom',
#   'dust',
#   'hair',
#   'hair',
#   'pillow',
#   'Awakened',
#   '06',
#   '45',
#   'phone',
#   'number',
#   'hour',
#   'later',
#   'number',
#   'work',
#   'In',
#   'short',
#   'flee'],
#  ['Below', 'expectation', 'guest', 'experience', 'good'],
#  ['Love', 'place', 'Cool', 'n', 'serine', 'environment'],
#  ['Rates', 'moderate'],
#  ['It', 'nice', 'place', 'I', 'really', 'enjoy', 'stay'],
#  ['Will'],
#  ['Sirens', 'atmosphere'],
#  ['Facilities',
#   'good',
#   'Human',
#   'relationship',
#   'average',
#   'No',
#   'bar',
#   'service',
#   'restaurant',
#   'provide',
#   'food',
#   'client',
#   'register',
#   'stay',
#   'Guest',
#   'House',
#   'late',
#   'night'],
#  ['Cool', 'place', 'But', 'expect', 'much'],
#  ['They', 'best', 'customer', 'service'],
#  ['Cheap', 'place', 'I', 'go', '2', 'star', 'receptionist', 'nice'],
#  ['Beach', 'side', 'guest', 'house', 'rate', 'cool'],
#  ['It',
#   'moderate',
#   'consideration',
#   'financially',
#   'Very',
#   'serene',
#   'great',
#   'place',
#   'sea',
#   'public',
#   'beach',
#   'much',
#   'people',
#   'relax',
#   'peace',
#   'Good',
#   'staff',
#   'take',
#   'satisfy',
#   'customer',
#   'The',
#   'owner',
#   'great',
#   'human',
#   'skill',
#   'One',
#   'thing',
#   'I',
#   'loved',
#   'mosquito',
#   'strong',
#   'breeze',
#   'always',
#   'around'],
#  ['Good', 'place', 'centre', 'town'],
#  ['Serine', 'environment', 'A', 'cool', 'place', 'relax'],
#  ['nice',
#   'clean',
#   'room',
#   'breakfast',
#   'superb',
#   'night',
#   'manager',
#   'awesome'],
#  ['Cool', 'place'],
#  ['Quite', 'quiet'],
#  ['Great', 'Hospitality', 'generally', 'clean', 'place'],
#  ['Was', 'nice', 'environment', 'I', 'drink'],
#  ['Staf',
#   'Amazing',
#   'especially',
#   'Fredrick',
#   'help',
#   'everything',
#   'Loved',
#   'energy',
#   'environment',
#   'serene'],
#  ['In',
#   'middle',
#   'impressive',
#   'green',
#   'setting',
#   'Ahanta',
#   'Eco',
#   'Lodge',
#   'conceals',
#   'magnificent',
#   'garden',
#   'decor',
#   'stay',
#   'Very',
#   'diverse',
#   'room',
#   'ranging',
#   'suite',
#   'bathroom',
#   'apparently',
#   'without',
#   'Beach',
#   'House',
#   'attached',
#   'surf',
#   'school',
#   'lodge',
#   'note',
#   'latter',
#   'relatively',
#   'distant',
#   'rest',
#   'lodge',
#   'necessaryCount',
#   'least',
#   '5',
#   'minute',
#   'walking',
#   'crossing',
#   'lagoon',
#   'low',
#   'tide',
#   'passing',
#   'village',
#   'In',
#   'general',
#   'road',
#   'leading',
#   'Busua',
#   'therefore',
#   'eco',
#   'lodge',
#   'rather',
#   'chaotic',
#   'damaged',
#   'Count',
#   'good',
#   'driver',
#   'afraid',
#   'bridge',
#   'lagoon',
#   'The',
#   'team',
#   'responsive',
#   'accommodating',
#   'able',
#   'change',
#   'room',
#   'last',
#   'moment',
#   'request',
#   'thank',
#   'Fredrick',
#   'The',
#   'kitchen',
#   'cleanly',
#   'fabulous',
#   'various',
#   'dish',
#   'different',
#   'menu',
#   'every',
#   'day',
#   'local',
#   'product',
#   'The',
#   'chef',
#   'able',
#   'surprise',
#   'authentic',
#   'homemade',
#   'cuisine',
#   'At',
#   'bar',
#   'Francis',
#   'prepare',
#   'whole',
#   'range',
#   'cocktail',
#   'tasty',
#   'Special',
#   'mention',
#   'homemade',
#   'akpetesthie',
#   'good',
#   'humor',
#   'Our',
#   'stay',
#   'pleasant',
#   'hope',
#   'able',
#   'come',
#   'back',
#   'soon'],
#  ['I',
#   'stayed',
#   'Ahanta',
#   'several',
#   'day',
#   'long',
#   'journey',
#   'Ghana',
#   'enjoyed',
#   'calm',
#   'relaxing',
#   'atmosphere',
#   'lot',
#   'The',
#   'location',
#   'beautiful',
#   'I',
#   'loved',
#   'tree',
#   'shower',
#   'I',
#   'felt',
#   'close',
#   'nature',
#   'next',
#   'beach',
#   'side',
#   'The',
#   'staff',
#   'friendly',
#   'even',
#   'though',
#   'information',
#   'would',
#   'helpful',
#   'check',
#   'We',
#   'approach',
#   'staff',
#   'several',
#   'time',
#   'upcoming',
#   'question',
#   'could',
#   'cleared',
#   'beginning',
#   'The',
#   'food',
#   'amazing',
#   'even',
#   'though',
#   'bit',
#   'pricier',
#   'place',
#   'outside',
#   'sitting',
#   'relax',
#   'area',
#   'wonderful',
#   'The',
#   'thing',
#   'really',
#   'disturbed',
#   'u',
#   'rat',
#   'bedroom',
#   'washroom',
#   'We',
#   'tried',
#   'pack',
#   'drink',
#   'snack',
#   'good',
#   'could',
#   'several',
#   'plastic',
#   'bag',
#   'backpack',
#   'still',
#   'entered',
#   'room',
#   'went',
#   'stuff',
#   'I',
#   'personally',
#   'scared',
#   'night',
#   'could',
#   'hear',
#   'saw',
#   'entered',
#   'room',
#   'day',
#   'beach',
#   'I',
#   'called',
#   'reception',
#   'night',
#   'couldnt',
#   'anything',
#   'point',
#   'The',
#   'next',
#   'day',
#   'offered',
#   'clean',
#   'room',
#   'fill',
#   'certain',
#   'hole',
#   'wooden',
#   'roof',
#   'didnt',
#   'help',
#   'They',
#   'asked',
#   'understanding',
#   'ecolodge',
#   'animal',
#   'friendly',
#   'place',
#   'talking',
#   'rat',
#   'I',
#   'accept',
#   'argument',
#   'Especially',
#   'later',
#   'offered',
#   'u',
#   'place',
#   'trap',
#   'room',
#   'animal',
#   'friendly',
#   'Moreover',
#   'next',
#   'night',
#   'I',
#   'used',
#   'washroom',
#   'rat',
#   'bin',
#   'supposed',
#   'emptied',
#   'afternoon',
#   'cleaning',
#   'I',
#   'read',
#   'people',
#   'rat',
#   'problem',
#   'Ahanta',
#   'made',
#   'sleeping',
#   'almost',
#   'impossible',
#   'Still',
#   'really',
#   'amazing',
#   'place',
#   'I',
#   'guess',
#   'one',
#   'beautiful',
#   'stay',
#   'Busua',
#   'rat',
#   'experience',
#   'diminished',
#   'overall',
#   'good',
#   'experience'],
#  ['For',
#   'best',
#   'hotel',
#   'Busua',
#   'Super',
#   'nice',
#   'staff',
#   'flexible',
#   'come',
#   'wish',
#   'guest',
#   'grandiose',
#   'cocktail',
#   'excellent',
#   'food',
#   'The',
#   'bridge',
#   'lodge',
#   'unfortunately',
#   'imposition',
#   'unfortunately',
#   'I',
#   'confirm',
#   'story',
#   'rat',
#   'review',
#   'Therefore',
#   '4',
#   'star'],
#  ['Nice',
#   'accommodation',
#   'end',
#   'beach',
#   'There',
#   'room',
#   'different',
#   'comfort',
#   'We',
#   'Wood',
#   'House',
#   'rather',
#   'comfortable',
#   'However',
#   'photo',
#   'first',
#   'bungalow',
#   'garden',
#   'front',
#   'restaurant',
#   'The',
#   'food',
#   'excellent',
#   'cocktail',
#   'also',
#   'recommended',
#   'Because',
#   'standing',
#   'water',
#   'front',
#   'garden',
#   'mosquito',
#   'spray',
#   'strongly',
#   'recommended',
#   'So',
#   'sit',
#   'outside'],
#  ['Everything', 'great', 'Essen', 'drink', 'accommodation'],
#  ['We',
#   'much',
#   'enjoyed',
#   'stay',
#   'Ahanta',
#   'The',
#   'room',
#   'communal',
#   'area',
#   'nicely',
#   'done',
#   'cosy',
#   'clean',
#   '3',
#   'option',
#   'offered',
#   'dinner',
#   'daily',
#   '40',
#   '70ish',
#   'GHS',
#   'always',
#   'tasty',
#   'one',
#   'big',
#   'table',
#   'provides',
#   'opportunity',
#   'get',
#   'know',
#   'guest',
#   'There',
#   'also',
#   'cocktail',
#   'available',
#   'breakfast',
#   'better',
#   'standard',
#   'hotel',
#   'fare',
#   'Busua',
#   'offer',
#   'lot',
#   'surfing',
#   'offered',
#   'lovely',
#   'instructor',
#   'Ahanta',
#   'come',
#   'prepared',
#   'quiet',
#   'stay',
#   'lot',
#   'reading',
#   'We',
#   'also',
#   'ate',
#   'almost',
#   'exclusively',
#   'lodge',
#   'many',
#   'option',
#   'There',
#   'also',
#   'Ahanta',
#   'surf',
#   'beach',
#   'hut',
#   'beach',
#   'nice',
#   'spot',
#   'hang',
#   'To',
#   'get',
#   'village',
#   'main',
#   'beach',
#   'stretch',
#   'cross',
#   'lagoon',
#   'pleasant',
#   'several',
#   'time',
#   'day',
#   'bit',
#   'dangerous',
#   'high',
#   'fast',
#   'water',
#   'level',
#   'You',
#   'also',
#   'walk',
#   'long',
#   'way',
#   'around',
#   'across',
#   'patchy',
#   'bridge',
#   'small',
#   'touristy',
#   'village',
#   'One',
#   'two',
#   'thing',
#   'le',
#   'ideal',
#   'daily',
#   'wake',
#   'call',
#   'round',
#   '6',
#   '15',
#   'local',
#   'rooster',
#   'general',
#   'enjoyed',
#   'observing',
#   'chicken',
#   'rooster',
#   'goat',
#   'dog',
#   'lodge',
#   'though',
#   'Sometimes',
#   'woken',
#   'animal',
#   'noise',
#   'night',
#   'due',
#   'rainy',
#   'season',
#   'everything',
#   'slightly',
#   'damp',
#   'bed',
#   'sheet',
#   'towel',
#   'clothes',
#   'drying',
#   'difficult',
#   'thing',
#   'started',
#   'smell',
#   'little',
#   'moldy',
#   'outside',
#   'area',
#   'could',
#   'improved',
#   'place',
#   'sit',
#   'especially',
#   'sun',
#   'Other',
#   'lovely',
#   'albeit',
#   'quiet',
#   'time',
#   'staff',
#   'really',
#   'great',
#   'come',
#   'back',
#   'Busua',
#   'return'],
#  ['Great',
#   'little',
#   'eco',
#   'lodge',
#   'cornered',
#   'lagoon',
#   'Stayed',
#   'budget',
#   'room',
#   'name',
#   'suggests',
#   'pretty',
#   'budget',
#   'still',
#   'good',
#   'value',
#   'money',
#   'Showering',
#   'gigantic',
#   'tree',
#   'definitely',
#   'experience',
#   'Relaxing',
#   'atmosphere',
#   'great',
#   'food',
#   'WiFi',
#   'Prob',
#   'one',
#   'best',
#   'place',
#   'stay',
#   'Busua',
#   'hence',
#   'popularity',
#   'Make',
#   'sure',
#   'book',
#   'advance'],
#  ['A',
#   'wonderful',
#   'place',
#   'beautiful',
#   'room',
#   'good',
#   'cuisine',
#   'great',
#   'bar',
#   'Unfortunately',
#   'associated',
#   'surf',
#   'school',
#   'made',
#   'opposite',
#   'impression',
#   'unpunctual',
#   'unmotivated',
#   'guide',
#   'old',
#   'sometimes',
#   'bad',
#   'material'],
#  ['What',
#   'great',
#   'experience',
#   'My',
#   'friend',
#   'I',
#   'arrived',
#   'day',
#   'checking',
#   'space',
#   'The',
#   'beautiful',
#   'environment',
#   'absolutely',
#   'stunning',
#   'The',
#   'tall',
#   'old',
#   'tree',
#   'little',
#   'garden',
#   'use',
#   'every',
#   'living',
#   'thing',
#   'breath',
#   'taking',
#   'You',
#   'option',
#   'use',
#   'big',
#   'metal',
#   'bridge',
#   'get',
#   'place',
#   'use',
#   'small',
#   'river',
#   'collides',
#   'sea',
#   'That',
#   'magical',
#   'My',
#   'first',
#   'two',
#   'night',
#   'got',
#   'beach',
#   'house',
#   'detached',
#   'eco',
#   'lodge',
#   'It',
#   'right',
#   'beach',
#   'surf',
#   'school',
#   'small',
#   'coffee',
#   'shop',
#   'The',
#   'beach',
#   'house',
#   'beautiful',
#   'lively',
#   'vibrant',
#   'color',
#   'There',
#   'two',
#   'pet',
#   'around',
#   'A',
#   'cat',
#   'dog',
#   'friendly',
#   'You',
#   'take',
#   'dog',
#   'walk',
#   'I',
#   'guess',
#   'ask',
#   'permission',
#   'first',
#   'And',
#   'allergic',
#   'like',
#   'around',
#   'ask',
#   'removal',
#   'while',
#   'stay',
#   'The',
#   'inside',
#   'space',
#   'beautiful',
#   'well',
#   'taken',
#   'care',
#   'We',
#   'checked',
#   'eco',
#   'lodge',
#   'space',
#   'next',
#   'day',
#   'beautiful',
#   'natural',
#   'undertone',
#   'interior',
#   'Warm',
#   'shower',
#   'free',
#   'Wi',
#   'Fi',
#   'quite',
#   'siren',
#   'environment',
#   'The',
#   'worker',
#   'friendly',
#   'especially',
#   'Frederick',
#   'Joy',
#   'helpful',
#   'whenever',
#   'question',
#   'issue',
#   'concerning',
#   'stay',
#   'The',
#   'breakfast',
#   'included',
#   'room',
#   'rate',
#   'absolutely',
#   'mouth',
#   'watering',
#   'They',
#   'good',
#   'option',
#   'choose',
#   'They',
#   'offer',
#   'dinner',
#   'option',
#   'day',
#   'took',
#   'dinner',
#   'night',
#   'checked',
#   'regretted',
#   'eat',
#   'whole',
# ...
#   'functional',
#   'Alas',
#   'due',
#   'full',
#   'booking',
#   'place',
#   'I',
#   'stay',
#   'They',
#   'also',
#   'working',
#   'WiFi',
#   'Plus',
#   'cellphone',
#   'reception',
#   'terrible',
#   'The',
#   'Hotel',
#   'rate',
#   'hand',
#   'good'],
#  ['Has',
#   'serene',
#   'environment',
#   'nice',
#   'accessible',
#   'road',
#   'easy',
#   'locate'],
#  ['It', 'changed'],
#  ['This', 'place', 'nice', 'wedding', 'reception', 'engagement'],
#  ['Manageable'],
#  ['Savoy', 'best'],
#  ['Not', 'bad'],
#  ['I', 'live', 'der', 'nd', 'de', 'many', 'change', 'savoy'],
#  ['Neat', 'comfortable', 'place'],
#  ['Not', 'much', 'say', 'place', 'great'],
#  ['It', 'help'],
#  ['It', 'rated', '3', 'star', 'hotel', 'Cape', 'Coast'],
#  ['Classic', 'looking', 'hotel'],
#  ['Still', 'Operating', 'good', 'crash', 'night', 'travel'],
#  ['It', 'average', 'hotel', 'I', 'like', 'environment'],
#  ['Good'],
#  ['Home', 'based'],
#  ['smirking', '_', 'face'],
#  ['Very', 'unique'],
#  ['Average', 'facility'],
#  ['Cool', 'place'],
#  ['Lovely',
#   'place',
#   'Big',
#   'bed',
#   'calm',
#   'environment',
#   'Nice',
#   'service',
#   'Will',
#   'go',
#   'back',
#   'ad'],
#  ['The', 'accommodation', 'nice', 'clean', 'perfect', 'place'],
#  ['Savoy',
#   'Hotel',
#   'use',
#   'iconic',
#   'hotel',
#   'hotel',
#   'good',
#   'condition',
#   'use',
#   'It',
#   'Rehabilitated'],
#  ['No',
#   'wifi',
#   'break',
#   'fast',
#   'water',
#   'heater',
#   'swimming',
#   'pool',
#   'restaurant'],
#  ['It', 'old', 'place', 'spend', 'night'],
#  ['It', 'nice', 'place'],
#  ['An',
#   'amazing',
#   'school',
#   'set',
#   'aim',
#   'providing',
#   'quality',
#   'education'],
#  ['Lovely', 'environment'],
#  ['Good', 'location'],
#  ['This',
#   'place',
#   'indeed',
#   'paradise',
#   'I',
#   'spent',
#   'three',
#   'day',
#   'resort',
#   'service',
#   'environment',
#   'superb',
#   'The',
#   'staff',
#   'friendly',
#   'food',
#   'WOW',
#   'good',
#   'room',
#   'tidy',
#   'spacious',
#   'I',
#   'wait',
#   'go',
#   'back',
#   'future'],
#  ['Impeccable',
#   'service',
#   'The',
#   'staff',
#   'attractive',
#   'kind',
#   'discreet',
#   'The',
#   'location',
#   'pleasant',
#   'large',
#   'garden',
#   'play',
#   'area',
#   'access',
#   'lake',
#   'Nice',
#   'environment',
#   'peaceful',
#   'Perfect',
#   'observation',
#   'bird',
#   'provide',
#   'twin',
#   'long',
#   'lived',
#   'Excellent',
#   'generous',
#   'varied',
#   'cuisine',
#   'Everything',
#   'done',
#   'time',
#   'hurry',
#   'You',
#   'order',
#   'advance',
#   'The',
#   'room',
#   'large',
#   'correct',
#   'Little',
#   'water',
#   'pressure',
#   'shower',
#   'Possibility',
#   'park',
#   'car',
#   'next',
#   'room',
#   'Access',
#   'however',
#   'complicated',
#   'The',
#   'road',
#   'difficult',
#   'pas',
#   'Make',
#   'sure',
#   'suitable',
#   'vehicle',
#   'It',
#   'rather',
#   'isolated',
#   'place',
#   'like',
#   'dwelling',
#   'offered',
#   'around',
#   'lake',
#   'You',
#   'know',
#   'set',
#   'small',
#   'village',
#   'living',
#   'You',
#   'pay',
#   '10Ghs',
#   'per',
#   'person',
#   'access',
#   'valley'],
#  ['PROS',
#   'I',
#   'spent',
#   'night',
#   'In',
#   'fact',
#   'service',
#   'top',
#   'notch',
#   'The',
#   'room',
#   'neat',
#   'AC',
#   'functioned',
#   'well',
#   'environment',
#   'neat',
#   'except',
#   'lake',
#   'side',
#   'recently',
#   'used',
#   'people',
#   'got',
#   'The',
#   'food',
#   'superb',
#   'I',
#   'opportunity',
#   'take',
#   'variety',
#   'meal',
#   'Breakfast',
#   'Milo',
#   'pancake',
#   'bread',
#   'fried',
#   'egg',
#   'Lunch',
#   'Fufu',
#   'Aponkye',
#   'Light',
#   'soup',
#   'Supper',
#   'Banku',
#   'Tilapia',
#   'plus',
#   'Special',
#   'local',
#   'potato',
#   'chicken',
#   'ordered',
#   'special',
#   'pop',
#   'corn',
#   'khebab',
#   'fried',
#   'plantain',
#   'Their',
#   'food',
#   'far',
#   'best',
#   'ive',
#   'tasted',
#   'resort',
#   'The',
#   'owner',
#   'Maa',
#   'Patricia',
#   'friendly',
#   'met',
#   'two',
#   'people',
#   'Solomon',
#   'Seiba',
#   'woooooooooow',
#   'customer',
#   'service',
#   'assistance',
#   'overwhelming',
#   'I',
#   'hesitate',
#   'visit',
#   'place',
#   'second',
#   'time',
#   'Cons',
#   'Despite',
#   'nice',
#   'environment',
#   'negative',
#   'The',
#   'road',
#   'leading',
#   'place',
#   'bad',
#   'far',
#   'There',
#   'wall',
#   'around',
#   'resort',
#   'security',
#   'concern',
#   'really',
#   'see',
#   'security',
#   'guard',
#   'around',
#   'They',
#   'security',
#   'cam',
#   'far',
#   'car',
#   'park',
#   'But',
#   'I',
#   'really',
#   'enjoyed',
#   'stay'],
#  ['The',
#   'food',
#   'environment',
#   'staff',
#   'especially',
#   'Madam',
#   'Patricia',
#   'CEO',
#   'loving',
#   'humble',
#   'She',
#   'time',
#   'everyone'],
#  ['I',
#   'enjoyed',
#   'ecofriendly',
#   'system',
#   'wildwin',
#   'food',
#   'best',
#   'jollof',
#   'rice',
#   'banku',
#   'tilapia',
#   'muah',
#   'owner',
#   'madam',
#   'Patricia',
#   'humble',
#   'friendly',
#   'person',
#   'Planning',
#   'another',
#   'visit'],
#  ['Asked',
#   'Guiness',
#   '15',
#   'cedi',
#   'Was',
#   'warm',
#   'When',
#   'I',
#   'left',
#   'said',
#   'actually',
#   '20',
#   'cedi',
#   'If',
#   'sell',
#   '5',
#   '6',
#   'drink',
#   'know',
#   'price'],
#  ['Great',
#   'place',
#   'toilet',
#   'shower',
#   'bad',
#   'electricity',
#   'fail',
#   'many',
#   'time',
#   'The',
#   'restaurant',
#   'good',
#   'take',
#   'tour',
#   'boat',
#   'fun'],
#  ['It',
#   'beautiful',
#   'resort',
#   'right',
#   'Lake',
#   'Bosumtwi',
#   'You',
#   'love',
#   'food',
#   'good',
#   'atmosphere',
#   'relaxing',
#   'You',
#   'take',
#   'swim',
#   'The',
#   'staff',
#   'nice',
#   'owner',
#   'friendly',
#   'Downside',
#   'warm',
#   'shower',
#   'issue',
#   'want',
#   'Otherwise',
#   'I',
#   'totally',
#   'enjoyed',
#   'stay',
#   'blast'],
#  ['Loved',
#   'environment',
#   'Very',
#   'serene',
#   'great',
#   'food',
#   'beautiful',
#   'environment',
#   'Staff',
#   'friendly',
#   'Ultimate',
#   'escape',
#   'reset',
#   'meditate',
#   'reconnect',
#   'nature',
#   'Counting',
#   'day',
#   'next',
#   'visit'],
#  ['The',
#   'view',
#   'lake',
#   'serenity',
#   'absolutely',
#   'worth',
#   'journey',
#   'sparkle'],
#  ['Bad', 'policy', 'Not', 'good', 'By', 'force', 'ordering', 'food'],
#  ['Cozy', 'environment', 'food', 'keep', 'long'],
#  ['one', 'best', 'resort', 'get', 'leisure', 'Don', 'miss'],
#  ['They',
#   'best',
#   'road',
#   'though',
#   'serene',
#   'natural',
#   'environment',
#   'view',
#   'lake'],
#  ['Was', 'birthday', 'I', 'love', 'environment'],
#  ['The', 'natural', 'environment', 'lake', 'healing', 'fun'],
#  ['Staffs',
#   'friendly',
#   'patient',
#   'respectful',
#   'Rooms',
#   'bathroom',
#   'neat',
#   'food',
#   'delicious',
#   'wildwin',
#   'drink',
#   'make',
#   'die',
#   'last',
#   'least',
#   'place',
#   'surrounded',
#   'different',
#   'fruit',
#   'facing',
#   'lake',
#   'night',
#   'I',
#   'slept',
#   'side',
#   'listening',
#   'sound',
#   'lake',
#   'watching',
#   'star',
#   'moon',
#   'In',
#   'short',
#   'I',
#   'recommend',
#   'place',
#   'anyone',
#   'need',
#   'getaway',
#   'rest',
#   'relax'],
#  ['Great',
#   'weekend',
#   'getaway',
#   'easy',
#   'access',
#   'lake',
#   'nature',
#   'Good',
#   'customer',
#   'service',
#   'around',
#   'Seiba',
#   'Godwin',
#   'helpful',
#   'free',
#   'breakfast',
#   'par'],
#  ['Great', 'experience'],
#  ['Beautiful',
#   'ground',
#   'Willing',
#   'staff',
#   'intuition',
#   'clearly',
#   'trained',
#   'They',
#   'willing',
#   'bit',
#   'trust',
#   'everything',
#   'take',
#   'long',
#   'We',
#   'waited',
#   'half',
#   'hour',
#   'breakfast',
#   'longer',
#   'dinner',
#   'The',
#   'bedroom',
#   'We',
#   'blue',
#   'light',
#   'bathroom',
#   'strange',
#   'one',
#   'towel',
#   'knew',
#   'two',
#   'people',
#   'staying',
#   'room'],
#  ['Beautiful', 'serene', 'place', 'good', 'people', 'delicious', 'meal'],
#  ['Nice',
#   'place',
#   'enough',
#   'space',
#   'family',
#   'outing',
#   'A',
#   'view',
#   'Lake',
#   'Bosomtwe',
#   'But',
#   'road',
#   'location',
#   'encouraging'],
#  ['My',
#   'first',
#   'experience',
#   'June',
#   '2021',
#   'I',
#   'fell',
#   'love',
#   'place',
#   'The',
#   'water',
#   'tree',
#   'bird',
#   'different',
#   'colour',
#   'Oh',
#   'I',
#   'help',
#   'come',
#   'weekend',
#   'birthday',
#   'Oct',
#   '2nd',
#   '4th',
#   'It',
#   'magical',
#   'experience',
#   'I',
#   'swam',
#   'lake',
#   'Bosomtwe',
#   'first',
#   'time',
#   'I',
#   'meditation',
#   'lake',
#   '5am',
#   'bird',
#   'singing',
#   'sun',
#   'rising',
#   'calm',
#   'lake',
#   'The',
#   'owner',
#   'amazing',
#   'person',
#   'I',
#   'came',
#   'June',
#   'nice',
#   'phone',
#   'changed',
#   'It',
#   'feel',
#   'like',
#   'home',
#   'They',
#   'even',
#   'made',
#   'surprise',
#   'birthday',
#   'local',
#   'food',
#   'I',
#   'never',
#   'forget',
#   'weekend',
#   'The',
#   'time',
#   'I',
#   'saw',
#   'happy',
#   'client',
#   'came',
#   'food',
#   'refused',
#   'pay',
#   'anything',
#   'When',
#   'asked',
#   'pay',
#   'nicely',
#   'refused',
#   'finally',
#   'asked',
#   'leave',
#   'They',
#   'rained',
#   'insult',
#   'whole',
#   'place',
#   'I',
#   'never',
#   'seen',
#   'disrespect',
#   'rude',
#   'behaviour',
#   'If',
#   'food',
#   'eat',
#   'home',
#   'You',
#   'bring',
#   'food',
#   'restaurant',
#   'Why',
#   'good',
#   'business',
#   'Wildwin',
#   'amazing',
#   'gateway',
#   'nature',
#   'lover',
#   'owner',
#   'best',
#   'customer',
#   'service',
#   'client',
#   'I',
#   'seen',
#   'Anyways',
#   'I',
#   'already',
#   'booked',
#   'ticket',
#   'December',
#   '2021',
#   'Can',
#   'wait',
#   'see',
#   'blue',
#   'green',
#   'bird',
#   'swim',
#   'lake',
#   'Bosomtwe',
#   'I',
#   'could',
#   'live',
#   'life'],
#  ['Good', 'chef', 'Quiet', 'environment'],
#  ['I',
#   'really',
#   'love',
#   'place',
#   'We',
#   'refresher',
#   'course',
#   'indeed',
#   'refreshing',
#   'Very',
#   'nice',
#   'serene',
#   'environment'],
#  ['I',
#   'enjoyed',
#   'stay',
#   'nice',
#   'calm',
#   'environment',
#   'beautiful',
#   'caring',
#   'staff',
#   'I',
#   'wan',
#   'na',
#   'leave'],
#  ['Nice', 'place', 'village', 'setting'],
#  ['It', 'great', 'time', 'view', 'lake', 'breath', 'taking'],
#  ['I',
#   'loved',
#   'neat',
#   'serene',
#   'place',
#   'It',
#   'good',
#   'place',
#   'visit',
#   'want',
#   'run',
#   'away',
#   'chaos',
#   'city',
#   'And',
#   'customer',
#   'service',
#   'wonderful',
#   'well'],
#  ['Good',
#   'place',
#   'relax',
#   'unplug',
#   'Location',
#   'perfect',
#   'waiting',
#   'service',
#   'better',
#   'Will',
#   'recommend',
#   'place',
#   'looking',
#   'cool',
#   'place',
#   'get',
#   'away'],
#  ['Good', 'customer', 'care'],
#  ['We',
#   'really',
#   'enjoyed',
#   'Blue',
#   'Diamond',
#   'Easy',
#   'booking',
#   'great',
#   'communication',
#   'easy',
#   'find',
#   'really',
#   'bad',
#   'drive',
#   'Accra',
#   'Ordering',
#   'drink',
#   'meal',
#   'easy',
#   'WhatsApp',
#   'message',
#   'We',
#   'ordered',
#   'food',
#   'one',
#   'night',
#   'good',
#   'brought',
#   'bbq',
#   'second',
#   'night',
#   'I',
#   'like',
#   'allow',
#   'bring',
#   'food',
#   'The',
#   'room',
#   'super',
#   'basic',
#   'spent',
#   'time',
#   'beach',
#   'anyway',
#   'The',
#   'beach',
#   'clean',
#   'safe',
#   'swim',
#   'Decent',
#   'wave',
#   'boogie',
#   'boarding',
#   'even',
#   'surfing',
#   'decent',
#   'break',
#   'beach',
#   'bit',
#   'It',
#   'feel',
#   'good',
#   'find',
#   'place',
#   'escape',
#   'Accra',
#   'really',
#   'required',
#   'nothing',
#   'relax'],
#  ['Nice',
#   'clean',
#   'beach',
#   'getaway',
#   'Accra',
#   'Beautiful',
#   'shoreline',
#   'wave',
#   'body',
#   'surfing',
#   'close',
#   'quick',
#   'surfing',
#   'Resort',
#   'food',
#   'yummy',
#   'You',
#   'bring',
#   'charcoal',
#   'grill',
#   'food',
#   'well',
#   'Dmall',
#   'nighltly',
#   'bonfire',
#   'weekend',
#   'Small',
#   'clean',
#   'pool',
#   'Very',
#   'nice',
#   'spot',
#   'family',
#   'Drinks',
#   'thr',
#   'pricier',
#   'side',
#   'order',
#   'via',
#   'WhatsApp',
#   'convenient',
#   'Rooms',
#   'AC',
#   'mini',
#   'fridge',
#   'honestly',
#   'spend',
#   'much',
#   'time',
#   'thr',
#   'room',
#   'awake',
#   'No',
#   'store',
#   'nearby',
#   'bring',
#   'snack',
#   'maybe',
#   'water',
#   'Rooms',
#   'get',
#   'sandy',
#   'floor',
#   'mat',
#   'would',
#   'nice',
#   'inside',
#   'door',
#   'Manager',
#   'person',
#   'owner',
#   'German',
#   'lady',
#   'great',
#   'communication',
#   'skill'],
#  ['Blue',
#   'Diamond',
#   'Beach',
#   'Resort',
#   'life',
#   'upto',
#   'name',
#   'It',
#   'clean',
#   'beach',
#   'view',
#   'picture',
#   'perfect',
#   'Service',
#   'staff',
#   'polite',
#   'professional',
#   'approach',
#   'Long',
#   'walk',
#   '7',
#   '10',
#   'Km',
#   'beach',
#   'normal',
#   'villager',
#   'fishing',
#   'nearby',
#   'add',
#   'experience',
#   'local',
#   'people',
#   'culture',
#   'Ride',
#   'wave',
#   'get',
#   'board',
#   'Swings',
#   'hammock',
#   'coconut',
#   'tree',
#   'give',
#   'true',
#   'feel',
#   'beach',
#   'resort',
#   'Rooms',
#   'functional',
#   'well',
#   'maintained',
#   'Overall',
#   'excellent',
#   'place',
#   'Place',
#   'cosy',
#   'give',
#   'privacy',
#   'bottle',
#   '_',
#   '_',
#   'popping',
#   '_',
#   'corkclinking',
#   '_',
#   'glassesclinking',
#   '_',
#   'beer',
#   '_',
#   'mugstropical',
#   '_',
#   'drinkperson',
#   '_',
#   'surfingpalm',
#   '_',
#   'tree'],
#  ['A',
#   'lovely',
#   'hideout',
#   'hustle',
#   'bustle',
#   'city',
#   'life',
#   'An',
#   'escape',
#   'route',
#   'really',
#   'Serene',
#   'atmosphere',
#   'well',
#   'trimmed',
#   'lawn',
#   'Not',
#   'easy',
#   'location',
#   'though',
#   'get',
#   'love',
#   'A',
#   'neat',
#   'tidy',
#   'beach',
#   'life',
#   'guard',
#   'available',
#   'help',
#   'time',
#   'We',
#   'really',
#   'fun',
#   'host',
#   'amazing'],
#  ['Just',
#   'came',
#   'back',
#   '2',
#   'day',
#   'stay',
#   'getaway',
#   'Blue',
#   'Diamond',
#   'Firstly',
#   'communication',
#   '100',
#   'All',
#   'question',
#   'prior',
#   'booking',
#   'answered',
#   'well',
#   'time',
#   'WhatsApp',
#   'The',
#   'outside',
#   'Arriving',
#   'resort',
#   'easy',
#   'informed',
#   'arrival',
#   'someone',
#   'met',
#   'u',
#   'gate',
#   'As',
#   'drive',
#   'feel',
#   'peace',
#   'serenity',
#   'resort',
#   'It',
#   'clean',
#   'beach',
#   'well',
#   'kept',
#   'lovely',
#   'palm',
#   'tree',
#   'shaded',
#   'seating',
#   'table',
#   'beach',
#   'side',
#   'The',
#   'Rooms',
#   'We',
#   'booked',
#   'conjoining',
#   'family',
#   'room',
#   'I',
#   'must',
#   'say',
#   'room',
#   'big',
#   'disappointment',
#   'The',
#   'room',
#   'extremely',
#   'basic',
#   'especially',
#   'price',
#   'paid',
#   'felt',
#   'inclined',
#   'chill',
#   'beach',
#   'till',
#   'time',
#   'go',
#   'bed',
#   'room',
#   'depressing',
#   'dark',
#   'bare',
#   'furniture',
#   'Food',
#   'Ordering',
#   'food',
#   'easy',
#   'A',
#   'quick',
#   'whatsapp',
#   'get',
#   'quick',
#   'response',
#   'However',
#   'food',
#   '5',
#   '10',
#   'overpriced',
#   'quality',
#   'Ordered',
#   'dinner',
#   'day',
#   'arrived',
#   'decided',
#   'find',
#   'local',
#   'make',
#   'meal',
#   'rest',
#   'trip',
#   'Cocktails',
#   'nice',
#   'The',
#   'blue',
#   'diamond',
#   'hit',
#   'So',
#   'Last',
#   'Prayer',
#   'Overall',
#   'tranquility',
#   'place',
#   'make',
#   'room',
#   'food',
#   'I',
#   'giving',
#   '4'],
#  ['Stephanie',
#   'absolute',
#   'hostess',
#   'efficient',
#   'via',
#   'WhatsApp',
#   'provided',
#   'clear',
#   'communication',
#   'address',
#   'every',
#   'situation',
#   'The',
#   'food',
#   'great',
#   'everything',
#   'menu',
#   'WAS',
#   'available',
#   'loved',
#   'grilled',
#   'lobster',
#   'prawn',
#   'provencal',
#   'sea',
#   'food',
#   'linguine',
#   'beach',
#   'front',
#   'amazing',
#   'absolutely',
#   'loved',
#   'eating',
#   'meal',
#   'right',
#   'beach',
#   'front',
#   'falling',
#   'asleep',
#   'sound',
#   'sea',
#   'beach',
#   'resort',
#   'worth',
#   'visiting',
#   'room',
#   'basic',
#   'beach',
#   'worth',
#   'I',
#   'would'],
#  ['Beautiful', 'place'],
#  ['I', 'enjoy', 'red', '_', 'heart'],
#  ['Great',
#   'place',
#   'nice',
#   'getaway',
#   'Accra',
#   'great',
#   'service',
#   'nice',
#   'food',
#   'nice',
#   'scenery',
#   'beach',
#   'great',
#   'hostess',
#   'PS',
#   'ask',
#   'bonfire'],
#  ['Neat', 'beach', 'good', 'food', 'great', 'customer', 'service'],
#  ['We',
#   'spent',
#   'week',
#   'Xmil',
#   'coast',
#   'The',
#   'splendid',
#   'sea',
#   'well',
#   'served',
#   'equipped',
#   'beach',
#   'The',
#   'excellent',
#   'catering',
#   'fresh',
#   'fish',
#   'excellent',
#   'pizza',
#   'courtesy',
#   'cleaning',
#   'place'],
#  ['Very',
#   'lovely',
#   'place',
#   'Was',
#   '2015',
#   'today',
#   'great',
#   'Will',
#   'always',
#   'recommend'],
#  ['Any',
#   'reason',
#   'pick',
#   'call',
#   'strictly',
#   'reservation',
#   'keep',
#   'phone',
#   'close'],
#  ['Worst',
#   'place',
#   'visit',
#   'Never',
#   'seen',
#   'zero',
#   'hospitality',
#   'life',
#   'You',
#   'even',
#   'enter',
#   'gate',
#   'reservation',
#   'What',
#   'nonsense',
#   'Why',
#   'allow',
#   'walk',
#   'customer',
#   'coming',
#   'way',
#   'Accra',
#   'lunch',
#   'What',
#   'precious',
#   'Inside',
#   'walk',
#   'customer',
#   'turned',
#   'away',
#   'gate',
#   'Ridiculous',
#   'behaviour',
#   'lady',
#   'manager',
#   'spoke',
#   'phone',
#   'Will',
#   'never',
#   'visit',
#   'recommend',
#   'place',
#   'one'],
#  ...]

# %%
model = Word2Vec(train, min_count = 1)

# %%
from gensim import matutils

def similarity_cosine(vec1, vec2):
    cosine_similarity = np.dot(matutils.unitvec(vec1), matutils.unitvec(vec2))
    return cosine_similarity

labels = ['food', 'service', 'ambiance', 'place']

# def label_similarity(labels, aspects, model):
#     distance_dict = {}
#     lemma_aspects = text_prep.lemmatizer(aspects)
#     for aspect in lemma_aspects:
#         try:
#             aspect_vec = model.wv[aspect]
#             label_dist = {}
#             for label in labels:
#                 label_vec = model.wv[label]
#                 distance = similarity_cosine(label_vec, aspect_vec)
#                 label_dist[label] = distance
#             distance_dict[aspect] = label_dist
#         except KeyError:
#             distance_dict[aspect] = None
#     return distance_dict

# %%
from textblob import TextBlob,Word

# %%
def label_similarity(labels, aspects, model):
    distance_dict = {}
    # aspect_list = [Word(word).lemmatize() for word in aspects]
    for aspect in aspects:
        word = Word(aspect).lemmatize()
        try:
            aspect_vec = model.wv[word]
            label_dist = {}
            for label in labels:
                try:
                    label_vec = model.wv[label]
                    similarity = similarity_cosine(aspect_vec, label_vec)
                    label_dist[label] = similarity
                except KeyError:
                    label_dist[label] = None
            distance_dict[aspect] = label_dist
        except KeyError:
            distance_dict[aspect] = None
    return distance_dict

# %%
distance_data = label_similarity(labels, aspects, model)

# %%
distance_data
# Out:
# {'rooms': {'food': 0.9861941,
#   'service': 0.9781899,
#   'ambiance': 0.7925868,
#   'place': 0.97021925},
#  'services': {'food': 0.98076385,
#   'service': 0.99999994,
#   'ambiance': 0.8101275,
#   'place': 0.9625935},
#  'stay': {'food': 0.9713695,
#   'service': 0.9636817,
#   'ambiance': 0.74281883,
#   'place': 0.9409532},
#  'environment': {'food': 0.92976105,
#   'service': 0.9392219,
#   'ambiance': 0.8415965,
#   'place': 0.96640515},
#  'times': {'food': 0.94512105,
#   'service': 0.9220104,
#   'ambiance': 0.7014184,
#   'place': 0.8987446},
#  'ambiance': {'food': 0.77862203,
#   'service': 0.8101275,
#   'ambiance': 1.0,
#   'place': 0.8045482},
#  'thumbs _ upthumbs': None,
#  'service': {'food': 0.98076385,
#   'service': 0.99999994,
#   'ambiance': 0.8101275,
#   'place': 0.9625935},
#  'food': {'food': 1.0,
#   'service': 0.98076385,
#   'ambiance': 0.77862203,
#   'place': 0.968114},
#  'Staff': {'food': 0.91457915,
#   'service': 0.9201209,
#   'ambiance': 0.7847642,
#   'place': 0.90100217},
#  'reception': {'food': 0.9608084,
#   'service': 0.94511116,
#   'ambiance': 0.73642516,
#   'place': 0.93965524},
#  'place': {'food': 0.968114,
#   'service': 0.9625935,
#   'ambiance': 0.8045482,
#   'place': 1.0},
#  'prices': {'food': 0.9618937,
#   'service': 0.9557201,
#   'ambiance': 0.7717568,
#   'place': 0.9360951},
#  'breakfast': {'food': 0.95891106,
#   'service': 0.9685059,
#   'ambiance': 0.7836771,
#   'place': 0.9340916},
#  'designs in': None,
#  'ventilation AC Fan rooms': None,
#  'events': {'food': 0.49954718,
#   'service': 0.51537156,
#   'ambiance': 0.33077413,
#   'place': 0.48941875},
#  'location': {'food': 0.964418,
#   'service': 0.97004235,
#   'ambiance': 0.8194264,
#   'place': 0.9768267},
#  'designs': {'food': 0.51257634,
#   'service': 0.51910806,
#   'ambiance': 0.48832148,
#   'place': 0.4894297},
#  'washrooms': {'food': 0.5649341,
#   'service': 0.57524,
#   'ambiance': 0.3929109,
#   'place': 0.5250349},
#  'drinks': {'food': 0.92560947,
#   'service': 0.9231979,
#   'ambiance': 0.7214128,
#   'place': 0.8876508},
#  'staff': {'food': 0.9708905,
#   'service': 0.9698686,
#   'ambiance': 0.7927303,
#   'place': 0.94709367},
#  'beach': {'food': 0.9728269,
#   'service': 0.95047,
#   'ambiance': 0.7471846,
#   'place': 0.95422316},
#  'maintenance': {'food': 0.55020064,
#   'service': 0.52734756,
#   'ambiance': 0.45519075,
#   'place': 0.5661744},
#  'landscape': {'food': 0.55081964,
#   'service': 0.533314,
#   'ambiance': 0.4848539,
#   'place': 0.5698019},
#  'accommodation': {'food': 0.8434742,
#   'service': 0.84088504,
#   'ambiance': 0.6475133,
#   'place': 0.8161568},
#  'kitchen': {'food': 0.31070614,
#   'service': 0.29531294,
#   'ambiance': 0.07260257,
#   'place': 0.27593994},
#  'hosts': {'food': 0.8432115,
#   'service': 0.82764995,
#   'ambiance': 0.64801097,
#   'place': 0.81323415},
#  'value': {'food': 0.7192818,
#   'service': 0.7085263,
#   'ambiance': 0.57019514,
#   'place': 0.6913254},
#  'wish': {'food': 0.454076,
#   'service': 0.45412457,
#   'ambiance': 0.3734596,
#   'place': 0.45136052},
#  'waiters': {'food': 0.8106972,
#   'service': 0.8127037,
#   'ambiance': 0.6556334,
#   'place': 0.77517545},
#  'menu': {'food': 0.7529825,
#   'service': 0.7544034,
#   'ambiance': 0.5518098,
#   'place': 0.7064383},
#  'appearance': {'food': 0.27058217,
#   'service': 0.29262355,
#   'ambiance': 0.34932834,
#   'place': 0.25785217},
#  'owner': {'food': 0.8950659,
#   'service': 0.91347975,
#   'ambiance': 0.7743112,
#   'place': 0.88068557},
#  'cuisine': {'food': 0.152001,
#   'service': 0.0998939,
#   'ambiance': -0.060510922,
#   'place': 0.11251713},
#  'views': {'food': 0.97219455,
#   'service': 0.9593287,
#   'ambiance': 0.7994894,
#   'place': 0.9816741},
#  'water': {'food': 0.67270184,
#   'service': 0.60547143,
#   'ambiance': 0.32761693,
#   'place': 0.6228126},
#  'shower': {'food': 0.7621403,
#   'service': 0.7251555,
#   'ambiance': 0.5370789,
#   'place': 0.73570025},
#  'tap': {'food': 0.08671452,
#   'service': 0.089851804,
#   'ambiance': 0.1330517,
#   'place': 0.09051212},
#  'traffic': {'food': 0.24306494,
#   'service': 0.2206353,
#   'ambiance': 0.20410404,
#   'place': 0.2474712},
#  'road': {'food': 0.91501963,
#   'service': 0.90824956,
#   'ambiance': 0.7042074,
#   'place': 0.90991235},
#  'meals': {'food': 0.95289385,
#   'service': 0.9345699,
#   'ambiance': 0.7267252,
#   'place': 0.9312995},
#  'of': None,
#  'manager owner': {'food': -0.17466933,
#   'service': -0.17093651,
#   'ambiance': -0.12879162,
#   'place': -0.21624067},
#  'beaches': {'food': 0.9728269,
#   'service': 0.95047,
#   'ambiance': 0.7471846,
#   'place': 0.95422316},
#  'personal': {'food': 0.042259112,
#   'service': 0.05997076,
#   'ambiance': 0.013404343,
#   'place': 0.11010948},
#  'ocean': {'food': 0.7887092,
#   'service': 0.77188164,
#   'ambiance': 0.55869585,
#   'place': 0.7868063},
#  'Chef': {'food': 0.010304287,
#   'service': 0.027186014,
#   'ambiance': 0.0851998,
#   'place': 0.016038835},
#  'meal': {'food': 0.95289385,
#   'service': 0.9345699,
#   'ambiance': 0.7267252,
#   'place': 0.9312995},
#  'atmosphere': {'food': 0.93593884,
#   'service': 0.94764173,
#   'ambiance': 0.82216364,
#   'place': 0.9582501},
#  'team': {'food': 0.26546592,
#   'service': 0.22391392,
#   'ambiance': -0.0048029535,
#   'place': 0.21114758},
#  'umbrella': {'food': -0.1652107,
#   'service': -0.20623523,
#   'ambiance': -0.19739205,
#   'place': -0.14484465},
#  'pricing': {'food': -0.028068587,
#   'service': -0.040347286,
#   'ambiance': -0.18873355,
#   'place': -0.026702296},
#  'design': {'food': 0.51257634,
#   'service': 0.51910806,
#   'ambiance': 0.48832148,
#   'place': 0.4894297},
#  'internet connection': {'food': 0.002808489,
#   'service': 0.005190432,
#   'ambiance': -0.00094201416,
#   'place': -0.017492525},
#  'sea beach': {'food': 0.16374704,
#   'service': 0.14282107,
#   'ambiance': 0.123293936,
#   'place': 0.15125486},
#  'area': {'food': 0.947611,
#   'service': 0.9439901,
#   'ambiance': 0.78692484,
#   'place': 0.9463147},
#  'bread': {'food': -0.034505196,
#   'service': -0.05066591,
#   'ambiance': -0.13276348,
#   'place': -0.026277144},
#  'spot': {'food': 0.6571864,
#   'service': 0.658983,
#   'ambiance': 0.589292,
#   'place': 0.6319968},
#  'Food': {'food': 0.9468897,
#   'service': 0.93275833,
#   'ambiance': 0.72334373,
#   'place': 0.9133687},
#  'Rooms': {'food': 0.678235,
#   'service': 0.64573693,
#   'ambiance': 0.45399624,
#   'place': 0.6626251},
#  'people': {'food': 0.94001555,
#   'service': 0.92254436,
#   'ambiance': 0.74572253,
#   'place': 0.9278716},
#  'Atmosphere': {'food': 0.25064275,
#   'service': 0.2592095,
#   'ambiance': 0.18655421,
#   'place': 0.24861902},
#  'sunsets': {'food': 0.00864666,
#   'service': -0.0055011325,
#   'ambiance': -0.043052755,
#   'place': -0.012849506},
#  'breeze': {'food': 0.7829261,
#   'service': 0.7787533,
#   'ambiance': 0.66695213,
#   'place': 0.8232276},
#  'guys': {'food': 0.59811556,
#   'service': 0.5610839,
#   'ambiance': 0.34587127,
#   'place': 0.5817454},
#  'view': {'food': 0.97219455,
#   'service': 0.9593287,
#   'ambiance': 0.7994894,
#   'place': 0.9816741},
#  'facilities': {'food': 0.9539773,
#   'service': 0.95643234,
#   'ambiance': 0.81010115,
#   'place': 0.94371736},
#  'workers': {'food': 0.80294096,
#   'service': 0.8187225,
#   'ambiance': 0.746144,
#   'place': 0.80802536},
#  'dinner': {'food': 0.7025866,
#   'service': 0.6768944,
#   'ambiance': 0.49860236,
#   'place': 0.6519685},
#  'Beach': {'food': 0.64055043,
#   'service': 0.60746735,
#   'ambiance': 0.36287153,
#   'place': 0.6211998},
#  'privacy': {'food': -0.22234777,
#   'service': -0.2406869,
#   'ambiance': -0.25156876,
#   'place': -0.20877737},
#  'leisure': {'food': 0.038889542,
#   'service': 0.017272782,
#   'ambiance': -0.09791678,
#   'place': -0.0055498853},
#  'facilities rooms': None,
#  'exclamation food Room s': None,
#  'amenities rooms': None,
#  'Garden': {'food': 0.3949592,
#   'service': 0.40044066,
#   'ambiance': 0.44455072,
#   'place': 0.3933187},
#  'host': {'food': 0.8432115,
#   'service': 0.82764995,
#   'ambiance': 0.64801097,
#   'place': 0.81323415},
#  'Aircon': {'food': 0.07593091,
#   'service': 0.07491693,
#   'ambiance': 0.10341512,
#   'place': 0.084774986},
#  'bar': {'food': 0.9102824,
#   'service': 0.9031968,
#   'ambiance': 0.7006371,
#   'place': 0.86601007},
#  'veggie food': {'food': 0.04854363,
#   'service': 0.042759337,
#   'ambiance': 0.087521106,
#   'place': 0.090989515},
#  'chickens': {'food': 0.5290295,
#   'service': 0.50913787,
#   'ambiance': 0.3899908,
#   'place': 0.48242494},
#  'Green garden eco lodge': None,
#  'vibes': {'food': 0.76686937,
#   'service': 0.766266,
#   'ambiance': 0.644356,
#   'place': 0.7583873},
#  'space': {'food': 0.495421,
#   'service': 0.42195222,
#   'ambiance': 0.23732421,
#   'place': 0.47963265},
#  'gardening': {'food': 0.17602703,
#   'service': 0.19658524,
#   'ambiance': 0.05144657,
#   'place': 0.15132786},
#  'indian food': {'food': 0.13503243,
#   'service': 0.121770725,
#   'ambiance': 0.04793652,
#   'place': 0.11973779},
#  'International cuisine': {'food': 0.17868818,
#   'service': 0.15880248,
#   'ambiance': 0.15137741,
#   'place': 0.1555166},
#  'coffee shop': {'food': 0.0325925,
#   'service': 0.03095964,
#   'ambiance': 0.04043267,
#   'place': 0.008214168},
#  'shared lounge': {'food': 0.09581779,
#   'service': 0.08732821,
#   'ambiance': 0.09089282,
#   'place': 0.07866478},
#  'Ghana': {'food': 0.87923265,
#   'service': 0.8512306,
#   'ambiance': 0.59546185,
#   'place': 0.8413889},
#  'green zion garden': None,
#  'Zion': {'food': 0.24089108,
#   'service': 0.24901727,
#   'ambiance': 0.28334457,
#   'place': 0.24486223},
#  'garden': {'food': 0.78187746,
#   'service': 0.7663636,
#   'ambiance': 0.6351367,
#   'place': 0.7973373},
#  'vegetarian cooking': {'food': -0.064817786,
#   'service': -0.060388703,
#   'ambiance': -0.009208029,
#   'place': -0.06029199},
#  'colors': {'food': 0.023563262,
#   'service': 0.03938223,
#   'ambiance': 0.0812522,
#   'place': 0.03777319},
#  'coconut': {'food': 0.008234444,
#   'service': -0.0381855,
#   'ambiance': -0.18387279,
#   'place': -0.018308572},
#  'Green zion garden': None,
#  'Pancakes': {'food': -0.0056071933,
#   'service': -0.0071576387,
#   'ambiance': -0.00049163774,
#   'place': -0.03839197},
#  'refreshment': {'food': 0.12897308,
#   'service': 0.14241904,
#   'ambiance': 0.05884896,
#   'place': 0.12934333},
#  'night': {'food': 0.93005055,
#   'service': 0.9192338,
#   'ambiance': 0.7164556,
#   'place': 0.89687514},
#  'pool': {'food': 0.9699679,
#   'service': 0.9647704,
#   'ambiance': 0.7813612,
#   'place': 0.96104085},
#  'parking space': {'food': 0.22093362,
#   'service': 0.2171625,
#   'ambiance': 0.1852072,
#   'place': 0.2015006},
#  'security': {'food': 0.8713204,
#   'service': 0.87800217,
#   'ambiance': 0.7652024,
#   'place': 0.8669702},
#  'hotel': {'food': 0.9707154,
#   'service': 0.9662155,
#   'ambiance': 0.77366626,
#   'place': 0.96619135},
#  'plce': {'food': -0.013443265,
#   'service': 0.006391622,
#   'ambiance': -0.006859757,
#   'place': -0.011567973},
#  'amenities room poolside restaurant': None,
#  'environment services': None,
#  'manager': {'food': 0.76178753,
#   'service': 0.7499311,
#   'ambiance': 0.6461239,
#   'place': 0.751788},
#  'Front Desk': {'food': -0.048058197,
#   'service': -0.05129861,
#   'ambiance': 0.0352562,
#   'place': -0.025862724},
#  'furniture': {'food': 0.27280837,
#   'service': 0.27288026,
#   'ambiance': 0.16964732,
#   'place': 0.25873256},
#  'bathroom': {'food': 0.8728008,
#   'service': 0.89352435,
#   'ambiance': 0.7840853,
#   'place': 0.86364317},
#  'business': {'food': 0.61708105,
#   'service': 0.6152347,
#   'ambiance': 0.47384498,
#   'place': 0.6450288},
#  'experience': {'food': 0.96969897,
#   'service': 0.9682553,
#   'ambiance': 0.7667227,
#   'place': 0.9644351},
#  'breakfast buffet': {'food': 0.35148135,
#   'service': 0.30316705,
#   'ambiance': 0.12172106,
#   'place': 0.33400294},
#  'options': {'food': 0.7166158,
#   'service': 0.6984049,
#   'ambiance': 0.54241115,
#   'place': 0.70653623},
#  'hotels': {'food': 0.9707154,
#   'service': 0.9662155,
#   'ambiance': 0.77366626,
#   'place': 0.96619135},
#  'learning': {'food': 0.07938448,
#   'service': 0.068337664,
#   'ambiance': 0.022783795,
#   'place': 0.078449085},
#  'time': {'food': 0.94512105,
#   'service': 0.9220104,
#   'ambiance': 0.7014184,
#   'place': 0.8987446},
#  'staying': {'food': 0.39230543,
#   'service': 0.3806704,
#   'ambiance': 0.3318712,
#   'place': 0.37680286},
#  'mattress': {'food': 0.45943052,
#   'service': 0.44590092,
#   'ambiance': 0.39627707,
#   'place': 0.45689705},
#  'window': {'food': 0.31549418,
#   'service': 0.30721813,
#   'ambiance': 0.13309136,
#   'place': 0.3130142},
#  'toilet seat': {'food': 0.035474606,
#   'service': 0.01702159,
#   'ambiance': -0.038323976,
#   'place': -0.0055144504},
#  'lodge': {'food': 0.87953025,
#   'service': 0.90696955,
#   'ambiance': 0.8185471,
#   'place': 0.8948774},
#  'front desk staff': None,
#  'conference rooms': None,
#  'ambience': {'food': 0.8334656,
#   'service': 0.83402926,
#   'ambiance': 0.66546714,
#   'place': 0.8246175},
#  'buffet dinner': {'food': -0.043847643,
#   'service': -0.011532891,
#   'ambiance': -0.088564605,
#   'place': -0.03975926},
#  'goose': {'food': 0.020859845,
#   'service': -0.0013875514,
#   'ambiance': -0.10315614,
#   'place': -0.053230055},
#  'room': {'food': 0.9861941,
#   'service': 0.9781899,
#   'ambiance': 0.7925868,
#   'place': 0.97021925},
#  'Furniture': {'food': -0.008440942,
#   'service': 0.027059909,
#   'ambiance': 0.012629693,
#   'place': 0.03158483},
#  'bedstead': {'food': -0.10265446,
#   'service': -0.1395439,
#   'ambiance': -0.073675424,
#   'place': -0.13354728},
#  'bedding': {'food': -0.07176733,
#   'service': -0.07605247,
#   'ambiance': -0.09422955,
#   'place': -0.09738974},
#  'Washroom housekeeping': {'food': -0.020900026,
#   'service': -0.04621868,
#   'ambiance': 0.0863359,
#   'place': -0.0115523115},
#  'live band music': None,
#  'spring rolls': None,
#  'takodi': {'food': -0.0034139343,
#   'service': -0.037263755,
#   'ambiance': -0.17188501,
#   'place': 0.034144368},
#  'globe': {'food': -0.58195996,
#   'service': -0.64111894,
#   'ambiance': -0.61649436,
#   'place': -0.5769886},
#  'inn': {'food': 0.13072337,
#   'service': 0.12329047,
#   'ambiance': -0.013041729,
#   'place': 0.10201289},
#  'Wifi': {'food': 0.49849457,
#   'service': 0.49902803,
#   'ambiance': 0.44399428,
#   'place': 0.4435947},
#  'staff reception': {'food': 0.07551128,
#   'service': 0.08080688,
#   'ambiance': -0.01215829,
#   'place': 0.07158087},
#  'buffet breakfast menu': None,
#  'view of the': None,
#  'Pizza': {'food': 0.08567015,
#   'service': 0.05760411,
#   'ambiance': -0.106522456,
#   'place': 0.07247144},
#  'amenities': {'food': 0.52429736,
#   'service': 0.5283992,
#   'ambiance': 0.41810635,
#   'place': 0.49128842},
#  'management': {'food': 0.6493518,
#   'service': 0.6471374,
#   'ambiance': 0.47746372,
#   'place': 0.6506362},
#  'price': {'food': 0.9618937,
#   'service': 0.9557201,
#   'ambiance': 0.7717568,
#   'place': 0.9360951},
#  'seaview': {'food': 0.17925215,
#   'service': 0.16364497,
#   'ambiance': 0.029751074,
#   'place': 0.16399872},
#  'swimming pool lounge chairs': None,
#  'pool beds': None,
#  'showers': {'food': 0.7621403,
#   'service': 0.7251555,
#   'ambiance': 0.5370789,
#   'place': 0.73570025},
#  'power': {'food': 0.22965181,
#   'service': 0.21936359,
#   'ambiance': 0.20570615,
#   'place': 0.23953548},
#  'Air conditioning': {'food': -0.12594128,
#   'service': -0.11354247,
#   'ambiance': -0.009961728,
#   'place': -0.14517093},
#  'Pillows': {'food': 0.27863884,
#   'service': 0.30463308,
#   'ambiance': 0.19409178,
#   'place': 0.25487617},
#  'clean rooms': None,
#  'resort': {'food': 0.958107,
#   'service': 0.9489223,
#   'ambiance': 0.77984357,
#   'place': 0.94678223},
#  'selection of food': None,
#  'onsite entertainment': {'food': 0.16830443,
#   'service': 0.19686253,
#   'ambiance': 0.22054349,
#   'place': 0.15787691},
#  'Service': {'food': 0.34000674,
#   'service': 0.30382338,
#   'ambiance': 0.15194494,
#   'place': 0.2908705},
#  'arranged apartments': None,
#  'comfort': {'food': 0.53192896,
#   'service': 0.5229665,
#   'ambiance': 0.3163592,
#   'place': 0.4795213},
#  'dinners': {'food': 0.7025866,
#   'service': 0.6768944,
#   'ambiance': 0.49860236,
#   'place': 0.6519685},
#  'Services': {'food': 0.08333182,
#   'service': 0.08219074,
#   'ambiance': 0.068539575,
#   'place': 0.11558956},
#  'interior design': {'food': -0.05863852,
#   'service': -0.040837947,
#   'ambiance': -0.058183234,
#   'place': -0.03616058},
#  'Clean room Staff': None,
#  'bed': {'food': 0.91470015,
#   'service': 0.9022907,
#   'ambiance': 0.68412286,
#   'place': 0.87548417},
#  'living room': {'food': -0.13073345,
#   'service': -0.10771236,
#   'ambiance': -0.087990165,
#   'place': -0.11598101},
#  'kitchenette': {'food': 0.16330233,
#   'service': 0.16450775,
#   'ambiance': 0.17205659,
#   'place': 0.13277422},
#  'freezer': {'food': -0.06480563,
#   'service': -0.059298426,
#   'ambiance': -0.012858802,
#   'place': -0.04199381},
#  'place Apartments': {'food': -0.09595595,
#   'service': -0.0997182,
#   'ambiance': -0.0936207,
#   'place': -0.09180995},
#  'catering services': None,
#  'daily room cleaning': None,
#  'waitresses': {'food': 0.27961105,
#   'service': 0.26760393,
#   'ambiance': 0.23197386,
#   'place': 0.25702244},
#  'bar area': {'food': -0.045819454,
#   'service': -0.07236059,
#   'ambiance': -0.17506889,
#   'place': -0.08217853},
#  'Place': {'food': 0.48308063,
#   'service': 0.4849661,
#   'ambiance': 0.49108618,
#   'place': 0.4760331},
#  'home': {'food': 0.85617375,
#   'service': 0.83485556,
#   'ambiance': 0.672927,
#   'place': 0.8555274},
#  'Compound': {'food': 0.056835223,
#   'service': 0.040287532,
#   'ambiance': 0.010662675,
#   'place': 0.041715227},
#  'size beds': None,
#  'LODGE': {'food': 0.08936981,
#   'service': 0.10553935,
#   'ambiance': 0.11525928,
#   'place': 0.12284717},
#  'Environment': {'food': 0.510957,
#   'service': 0.5249263,
#   'ambiance': 0.49370295,
#   'place': 0.5640303},
#  'managed lodge': {'food': 0.18115543,
#   'service': 0.14515652,
#   'ambiance': 0.16215208,
#   'place': 0.15696166},
#  'Boarding facility': {'food': 0.046543892,
#   'service': 0.028223231,
#   'ambiance': 0.08319041,
#   'place': 0.008599363},
#  'view of': None,
#  'wifi': {'food': 0.36157322,
#   'service': 0.3442737,
#   'ambiance': 0.36846954,
#   'place': 0.36451754},
#  'address': {'food': 0.4078552,
#   'service': 0.4260663,
#   'ambiance': 0.36683303,
#   'place': 0.41244227},
#  'sea view': {'food': 0.07885761,
#   'service': -0.011364892,
#   'ambiance': -0.16997279,
#   'place': 0.068624504},
#  'corridor': {'food': 0.25827858,
#   'service': 0.25134224,
#   'ambiance': 0.17448577,
#   'place': 0.2645359},
#  'Room': {'food': 0.32824108,
#   'service': 0.36936218,
#   'ambiance': 0.27458778,
#   'place': 0.33432248},
#  'residing': {'food': -0.04323688,
#   'service': -0.012853589,
#   'ambiance': -0.06068287,
#   'place': -0.06486671},
#  'WiFi': {'food': 0.6085942,
#   'service': 0.5916523,
#   'ambiance': 0.57177335,
#   'place': 0.60512114},
#  'guest': {'food': 0.8535654,
#   'service': 0.82553947,
#   'ambiance': 0.5919947,
#   'place': 0.8068806},
#  'offers': {'food': 0.8344443,
#   'service': 0.84289443,
#   'ambiance': 0.67579234,
#   'place': 0.81080925},
#  'Vacation': {'food': -0.19466865,
#   'service': -0.2098098,
#   'ambiance': -0.22469352,
#   'place': -0.23934293},
#  'swim': {'food': 0.6626419,
#   'service': 0.6546411,
#   'ambiance': 0.6133377,
#   'place': 0.6578325},
#  'STAFF': {'food': 0.1194,
#   'service': 0.114584275,
#   'ambiance': 0.11585593,
#   'place': 0.13313927},
#  'ENVIRONMENT': {'food': 0.16899599,
#   'service': 0.1304816,
#   'ambiance': 0.073378466,
#   'place': 0.12731782},
#  'fitness center': {'food': -0.18074258,
#   'service': -0.21176106,
#   'ambiance': -0.31044576,
#   'place': -0.21046576},
#  'swimming pool': {'food': 0.4772864,
#   'service': 0.39965388,
#   'ambiance': 0.1372354,
#   'place': 0.4292533},
#  'safe rooms': None,
#  'managers': {'food': 0.76178753,
#   'service': 0.7499311,
#   'ambiance': 0.6461239,
#   'place': 0.751788},
#  'Room service': {'food': 0.12639877,
#   'service': 0.11511266,
#   'ambiance': 0.119441524,
#   'place': 0.118145645},
#  'serving Breakfast': {'food': -0.012023717,
#   'service': -0.033276647,
#   'ambiance': 0.016658656,
#   'place': -0.01608254},
#  'common toilets': None,
#  'soap': {'food': 0.1513845,
#   'service': 0.12391505,
#   'ambiance': 0.07099669,
#   'place': 0.12016083},
#  'Rates': {'food': 0.04070618,
#   'service': 0.04903459,
#   'ambiance': 0.072591856,
#   'place': -0.0048887115},
#  'Facilities': {'food': 0.42529678,
#   'service': 0.4021565,
#   'ambiance': 0.35596472,
#   'place': 0.44003177},
#  'bar services': None,
#  'Guest House': {'food': 0.083686896,
#   'service': 0.06840602,
#   'ambiance': 0.083495766,
#   'place': 0.070320286},
#  'receptionist': {'food': 0.74736947,
#   'service': 0.75024104,
#   'ambiance': 0.62977326,
#   'place': 0.7384589},
#  'rates': {'food': 0.6541319,
#   'service': 0.64015424,
#   'ambiance': 0.53550667,
#   'place': 0.60932124},
#  'rooms breakfast': None,
#  'night manager': {'food': 0.10246489,
#   'service': 0.09118497,
#   'ambiance': 0.12092061,
#   'place': 0.08632189},
#  'Hospitality': {'food': 0.16157514,
#   'service': 0.19429901,
#   'ambiance': 0.09622978,
#   'place': 0.18532066},
#  'drink': {'food': 0.92560947,
#   'service': 0.9231979,
#   'ambiance': 0.7214128,
#   'place': 0.8876508},
#  'Staf': {'food': 0.08361622,
#   'service': 0.09533322,
#   'ambiance': -0.017917037,
#   'place': 0.06589634},
#  'Fredrick': {'food': 0.12013891,
#   'service': 0.09782947,
#   'ambiance': 0.038002834,
#   'place': 0.09541355},
#  'energy': {'food': 0.116563246,
#   'service': 0.11219788,
#   'ambiance': 0.09640877,
#   'place': 0.09227503},
#  'Beach House': {'food': 0.04604122,
#   'service': 0.022633402,
#   'ambiance': 0.005444601,
#   'place': 0.022971887},
#  'surf school': {'food': 0.36263788,
#   'service': 0.39656818,
#   'ambiance': 0.35287243,
#   'place': 0.35817912},
#  'chef': {'food': 0.48451403,
#   'service': 0.46624398,
#   'ambiance': 0.3351068,
#   'place': 0.46903527},
#  'cocktails': {'food': 0.3637774,
#   'service': 0.33420467,
#   'ambiance': 0.15047637,
#   'place': 0.3215345},
#  'akpetesthie': {'food': 0.29537576,
#   'service': 0.3182155,
#   'ambiance': 0.3233039,
#   'place': 0.32646263},
#  'restaurant': {'food': 0.9537225,
#   'service': 0.94075775,
#   'ambiance': 0.71232766,
#   'place': 0.9038011},
#  'vegetarian options': None,
#  'owners dog': None,
#  'owner Julia': {'food': -0.05627687,
#   'service': -0.071208335,
#   'ambiance': -0.04708776,
#   'place': -0.07833491},
#  'living': {'food': 0.09545654,
#   'service': 0.107997626,
#   'ambiance': 0.064569205,
#   'place': 0.11955087},
#  'eco lodge': {'food': 0.30858696,
#   'service': 0.286422,
#   'ambiance': 0.23109075,
#   'place': 0.31110048},
#  'scenery': {'food': 0.7367165,
#   'service': 0.7378333,
#   'ambiance': 0.55939746,
#   'place': 0.746542},
#  'destination': {'food': 0.6434008,
#   'service': 0.63083696,
#   'ambiance': 0.46923572,
#   'place': 0.611382},
#  'natural environment': {'food': -0.12535064,
#   'service': -0.16430888,
#   'ambiance': -0.19566783,
#   'place': -0.12119927},
#  'fufu': {'food': 0.0799597,
#   'service': 0.05401075,
#   'ambiance': 0.021354899,
#   'place': 0.078585856},
#  'vibe': {'food': 0.76686937,
#   'service': 0.766266,
#   'ambiance': 0.644356,
#   'place': 0.7583873},
#  'hospitality': {'food': 0.8712046,
#   'service': 0.8717082,
#   'ambiance': 0.7167716,
#   'place': 0.88274693},
#  'climate': {'food': 0.017920278,
#   'service': 0.014163163,
#   'ambiance': -0.016788475,
#   'place': 0.019763354},
#  'plates': {'food': 0.082032844,
#   'service': 0.058338504,
#   'ambiance': 0.059709065,
#   'place': 0.045444354},
#  'waves': {'food': -0.17068428,
#   'service': -0.25543606,
#   'ambiance': -0.3426541,
#   'place': -0.20663747},
#  'Lodge': {'food': 0.8125135,
#   'service': 0.84005666,
#   'ambiance': 0.74162817,
#   'place': 0.8404242},
#  'caipirinha': {'food': -0.11521895,
#   'service': -0.13184273,
#   'ambiance': -0.20073652,
#   'place': -0.11746391},
#  'decorated place': {'food': 0.017503202,
#   'service': 0.038942225,
#   'ambiance': 0.009417003,
#   'place': -0.020851614},
#  'oatmeal breakfast': {'food': 0.081610374,
#   'service': 0.06584076,
#   'ambiance': -0.033855192,
#   'place': 0.079632565},
#  'air': {'food': 0.6530714,
#   'service': 0.62934506,
#   'ambiance': 0.3787535,
#   'place': 0.6066507},
#  'outside walls': None,
#  'accommodations': {'food': 0.8434742,
#   'service': 0.84088504,
#   'ambiance': 0.6475133,
#   'place': 0.8161568},
#  'fumigation': {'food': 0.13847779,
#   'service': 0.15215291,
#   'ambiance': 0.026934877,
#   'place': 0.15920237},
#  'sunrise': {'food': -0.10859749,
#   'service': -0.15123518,
#   'ambiance': -0.22309226,
#   'place': -0.12917045},
#  'Great': {'food': 0.90533644,
#   'service': 0.9349495,
#   'ambiance': 0.82111454,
#   'place': 0.90810037},
#  'lunch': {'food': 0.3889764,
#   'service': 0.3499757,
#   'ambiance': 0.1558448,
#   'place': 0.29822105},
#  'hideout': {'food': 0.7496834,
#   'service': 0.7618122,
#   'ambiance': 0.7161504,
#   'place': 0.8095609},
#  'environment Breakfast': {'food': 0.20684695,
#   'service': 0.1880042,
#   'ambiance': 0.112969704,
#   'place': 0.1632016},
#  'Swimming': {'food': 0.29849863,
#   'service': 0.31323946,
#   'ambiance': 0.26812115,
#   'place': 0.31814313},
#  'hot water': {'food': 0.11250303,
#   'service': 0.078215286,
#   'ambiance': 0.022536658,
#   'place': 0.096761756},
#  'linen': {'food': -0.051020972,
#   'service': -0.054340612,
#   'ambiance': 0.044475485,
#   'place': -0.061718214},
#  'Bathroom': {'food': -0.29347122,
#   'service': -0.2972229,
#   'ambiance': -0.3055451,
#   'place': -0.32161444},
#  'compound': {'food': 0.27417648,
#   'service': 0.27275252,
#   'ambiance': 0.19141328,
#   'place': 0.27396044},
#  'programs': {'food': 0.41998816,
#   'service': 0.37864378,
#   'ambiance': 0.23507228,
#   'place': 0.43806964},
#  'Drinks': {'food': 0.4237349,
#   'service': 0.4726553,
#   'ambiance': 0.4585457,
#   'place': 0.45010418},
#  'Eye': {'food': -0.1396279,
#   'service': -0.13500895,
#   'ambiance': -0.10127798,
#   'place': -0.10199599},
#  'sleep': {'food': 0.6930772,
#   'service': 0.7114891,
#   'ambiance': 0.61167,
#   'place': 0.6924687},
#  'environmental': {'food': 0.016749173,
#   'service': 0.018628135,
#   'ambiance': 0.15682547,
#   'place': 0.016909566},
#  'lighting aircondirion': {'food': -0.18560492,
#   'service': -0.21176553,
#   'ambiance': -0.20815785,
#   'place': -0.23672998},
#  'Home': {'food': 0.3176909,
#   'service': 0.2927581,
#   'ambiance': 0.31136355,
#   'place': 0.3550496},
#  'beverages': {'food': 0.13529062,
#   'service': 0.14007333,
#   'ambiance': 0.14225097,
#   'place': 0.13903326},
#  'pictures': {'food': 0.5296086,
#   'service': 0.5535106,
#   'ambiance': 0.5300139,
#   'place': 0.55079347},
#  'affordable': {'food': 0.92585605,
#   'service': 0.94272876,
#   'ambiance': 0.79436165,
#   'place': 0.94482255},
#  'Reservations': {'food': 0.098012835,
#   'service': 0.07085197,
#   'ambiance': 0.07059953,
#   'place': 0.08705337},
#  'car park': {'food': 0.18306872,
#   'service': 0.15084803,
#   'ambiance': 0.09391184,
#   'place': 0.20059411},
#  'worker': {'food': 0.80294096,
#   'service': 0.8187225,
#   'ambiance': 0.746144,
#   'place': 0.80802536},
#  'nature': {'food': 0.7039932,
#   'service': 0.65698355,
#   'ambiance': 0.52310425,
#   'place': 0.684859},
#  'electricity supply': {'food': 0.059286818,
#   'service': 0.032924563,
#   'ambiance': -0.052442536,
#   'place': 0.04636356},
#  'expensive': {'food': 0.8475628,
#   'service': 0.85066533,
#   'ambiance': 0.7490371,
#   'place': 0.83741724},
#  'events arena': None,
#  'conference': {'food': 0.82200515,
#   'service': 0.8552003,
#   'ambiance': 0.7542589,
#   'place': 0.8222778},
#  'Eco': {'food': 0.5816151,
#   'service': 0.59764117,
#   'ambiance': 0.49174786,
#   'place': 0.5716207},
#  'relaxation beaming _ face': None,
#  'live band': {'food': -0.1488634,
#   'service': -0.17795238,
#   'ambiance': -0.1684929,
#   'place': -0.13532756},
#  'doors': {'food': 0.3256395,
#   'service': 0.31640196,
#   'ambiance': 0.19251704,
#   'place': 0.338183},
#  'gym': {'food': 0.5438373,
#   'service': 0.5522824,
#   'ambiance': 0.44618946,
#   'place': 0.5017387},
#  'area Access': {'food': 0.056849066,
#   'service': 0.055817522,
#   'ambiance': 0.108813055,
#   'place': 0.05004222},
#  'hide': {'food': 0.67053634,
#   'service': 0.68620735,
#   'ambiance': 0.6632949,
#   'place': 0.7116792},
#  'suits': {'food': 0.027262043,
#   'service': 0.014556117,
#   'ambiance': 0.046075586,
#   'place': 0.076354116},
#  'size': {'food': 0.45304716,
#   'service': 0.46628106,
#   'ambiance': 0.35597122,
#   'place': 0.46758988},
#  'continental dishes': None,
#  'Breakfast': {'food': 0.55830103,
#   'service': 0.53137267,
#   'ambiance': 0.34432173,
#   'place': 0.55180025},
#  'client': {'food': 0.52487206,
#   'service': 0.5118139,
#   'ambiance': 0.40644786,
#   'place': 0.4991896},
#  'washroom': {'food': 0.5649341,
#   'service': 0.57524,
#   'ambiance': 0.3929109,
#   'place': 0.5250349},
#  'outdoor area': {'food': -0.06398362,
#   'service': -0.107848555,
#   'ambiance': -0.046266187,
#   'place': -0.06687288},
#  'roof terrace': {'food': 0.2510868,
#   'service': 0.26779675,
#   'ambiance': 0.16592765,
#   'place': 0.23749697},
#  'lighting': {'food': 0.22906163,
#   'service': 0.2295407,
#   'ambiance': 0.25309846,
#   'place': 0.2395131},
#  'benjee': {'food': -0.03540641,
#   'service': -0.0345305,
#   'ambiance': -0.07972289,
#   'place': -0.039627753},
#  'Ressort': {'food': 0.16171588,
#   'service': 0.15449344,
#   'ambiance': 0.08034128,
#   'place': 0.16215292},
#  'rooftop': {'food': 0.26665366,
#   'service': 0.27147532,
#   'ambiance': 0.18602498,
#   'place': 0.28307307},
#  'guy': {'food': 0.59811556,
#   'service': 0.5610839,
#   'ambiance': 0.34587127,
#   'place': 0.5817454},
#  'coconuts': {'food': 0.008234444,
#   'service': -0.0381855,
#   'ambiance': -0.18387279,
#   'place': -0.018308572},
#  'towels': {'food': 0.4828189,
#   'service': 0.40202183,
#   'ambiance': 0.21245821,
#   'place': 0.4435833},
#  'outdoor shower': {'food': 0.18098402,
#   'service': 0.17365542,
#   'ambiance': 0.07409701,
#   'place': 0.14625159},
#  'vegan food': {'food': -0.091189295,
#   'service': -0.110597745,
#   'ambiance': -0.15688947,
#   'place': -0.1151322},
#  'dish': {'food': 0.8085575,
#   'service': 0.7952255,
#   'ambiance': 0.5486699,
#   'place': 0.76346505},
#  'athmo': {'food': 0.08704583,
#   'service': 0.090130955,
#   'ambiance': 0.034977213,
#   'place': 0.087205015},
#  'FOOD': {'food': 0.31663185,
#   'service': 0.302809,
#   'ambiance': 0.22823676,
#   'place': 0.2702634},
#  'avocado toast': {'food': -0.09098735,
#   'service': -0.10883837,
#   'ambiance': -0.17264003,
#   'place': -0.11830559},
#  'portions': {'food': 0.04552321,
#   'service': 0.057905033,
#   'ambiance': 0.07166793,
#   'place': 0.07711091},
#  'staff Shower': {'food': -0.0004300885,
#   'service': -0.045547746,
#   'ambiance': -0.08395223,
#   'place': 0.01340672},
#  'lettuce': {'food': -0.06366457,
#   'service': -0.040576495,
#   'ambiance': -0.023478236,
#   'place': -0.08447768},
#  'Goat': {'food': -0.050225906,
#   'service': -0.038117692,
#   'ambiance': -0.07548054,
#   'place': -0.020228788},
#  'massage': {'food': -0.29552785,
#   'service': -0.36477345,
#   'ambiance': -0.38951072,
#   'place': -0.3064984},
#  'ingredients': {'food': 0.2937544,
#   'service': 0.30137208,
#   'ambiance': 0.27766508,
#   'place': 0.29572275},
#  'setting': {'food': 0.66397536,
#   'service': 0.6644076,
#   'ambiance': 0.53877586,
#   'place': 0.6646623},
#  'employees': {'food': 0.3010975,
#   'service': 0.31233385,
#   'ambiance': 0.2814781,
#   'place': 0.30706298},
#  'veggie burgers': None,
#  'slices of potato': None,
#  'banana pancakes': None,
#  'Laughing Goat': {'food': -0.092953265,
#   'service': -0.09410368,
#   'ambiance': -0.09048871,
#   'place': -0.10649634},
#  'ital food': {'food': -0.03173186,
#   'service': -0.023009628,
#   'ambiance': -0.02828062,
#   'place': -0.039689697},
#  'luggage': {'food': 0.063396014,
#   'service': 0.05708044,
#   'ambiance': 0.0020089056,
#   'place': 0.10499296},
#  'sink': {'food': -0.06416978,
#   'service': -0.08143011,
#   'ambiance': -0.045178726,
#   'place': -0.06849931},
#  'sign': {'food': -0.6942054,
#   'service': -0.75240576,
#   'ambiance': -0.744928,
#   'place': -0.7098759},
#  'activities': {'food': 0.6264648,
#   'service': 0.6377869,
#   'ambiance': 0.43381184,
#   'place': 0.59715307},
#  'Lizzy': {'food': 0.078352466,
#   'service': 0.05696918,
#   'ambiance': 0.069374956,
#   'place': 0.07270892},
#  'James': {'food': 0.09220307,
#   'service': 0.09334572,
#   'ambiance': 0.006715117,
#   'place': 0.09269064},
#  'swimming beach Food': None,
#  'mosquito': {'food': -0.05503267,
#   'service': -0.08717129,
#   'ambiance': -0.2160686,
#   'place': -0.08217004},
#  'sea': {'food': 0.9500686,
#   'service': 0.9435662,
#   'ambiance': 0.76751137,
#   'place': 0.9498685},
#  'site': {'food': 0.73644435,
#   'service': 0.73625445,
#   'ambiance': 0.7142389,
#   'place': 0.7422521},
#  'Robberies': {'food': 0.03393663,
#   'service': 0.011684716,
#   'ambiance': 0.021408893,
#   'place': 0.07380534},
#  'caretaker': {'food': 0.2528866,
#   'service': 0.23512886,
#   'ambiance': 0.26625302,
#   'place': 0.23357144},
#  'bays': {'food': 0.22331446,
#   'service': 0.23364565,
#   'ambiance': 0.29976457,
#   'place': 0.22049199},
#  'relaxation': {'food': 0.7981002,
#   'service': 0.82164764,
#   'ambiance': 0.7308393,
#   'place': 0.8362009},
#  'personnel': {'food': 0.26395237,
#   'service': 0.22864197,
#   'ambiance': 0.088774204,
#   'place': 0.26829508},
#  'quality': {'food': 0.80582106,
#   'service': 0.8256925,
#   'ambiance': 0.7269371,
#   'place': 0.79533297},
#  'attractions': {'food': 0.5153797,
#   'service': 0.5167793,
#   'ambiance': 0.4120774,
#   'place': 0.51548505},
#  'Olivier': {'food': 0.062853634,
#   'service': 0.042109624,
#   'ambiance': -0.042644743,
#   'place': 0.024739876},
#  'honeymoon': {'food': 0.35215336,
#   'service': 0.34720135,
#   'ambiance': 0.2718616,
#   'place': 0.3718904},
#  'Road': {'food': 0.003451638,
#   'service': 0.024922803,
#   'ambiance': 0.043634187,
#   'place': 0.026637327},
#  'Tilapia': {'food': 0.09225093,
#   'service': 0.053694807,
#   'ambiance': 0.0030873679,
#   'place': 0.07050591},
#  'Ambience': {'food': 0.17145213,
#   'service': 0.17202084,
#   'ambiance': 0.2447237,
#   'place': 0.15013722},
#  'Hotel': {'food': 0.94000345,
#   'service': 0.9299647,
#   'ambiance': 0.70041966,
#   'place': 0.9247186},
#  'parking lot': {'food': 0.20319618,
#   'service': 0.22367302,
#   'ambiance': 0.1478306,
#   'place': 0.22386007},
#  'staff Food': {'food': 0.142665,
#   'service': 0.1770939,
#   'ambiance': 0.2905897,
#   'place': 0.19424671},
#  'pool view Food': None,
#  'terrace': {'food': 0.32782,
#   'service': 0.30070034,
#   'ambiance': 0.17188072,
#   'place': 0.30551603},
#  'Dinner': {'food': -0.2658416,
#   'service': -0.2879625,
#   'ambiance': -0.21723989,
#   'place': -0.29616404},
#  'outdoors bar patio': None,
#  'owners': {'food': 0.8950659,
#   'service': 0.91347975,
#   'ambiance': 0.7743112,
#   'place': 0.88068557},
#  'Charcoal Grilled Lobster': None,
#  'weather': {'food': 0.32129347,
#   'service': 0.35847622,
#   'ambiance': 0.47640598,
#   'place': 0.3635429},
#  'corner': {'food': -0.08509391,
#   'service': -0.10135345,
#   'ambiance': -0.1809118,
#   'place': -0.09120723},
#  'Water': {'food': 0.2407951,
#   'service': 0.25874484,
#   'ambiance': 0.29707414,
#   'place': 0.2811358},
#  'electricity': {'food': -0.064539835,
#   'service': -0.06357992,
#   'ambiance': -0.051054653,
#   'place': -0.018131942},
#  'tilapia': {'food': 0.42404848,
#   'service': 0.4235654,
#   'ambiance': 0.43141788,
#   'place': 0.39734632},
#  'construction': {'food': 0.46918717,
#   'service': 0.4840829,
#   'ambiance': 0.32153136,
#   'place': 0.4777267},
#  'dorm': {'food': -0.027542407,
#   'service': -0.011190522,
#   'ambiance': -0.1053642,
#   'place': -0.07127173},
#  'cook': {'food': 0.72922987,
#   'service': 0.7391318,
#   'ambiance': 0.55630636,
#   'place': 0.69296837},
#  'houses': {'food': 0.7874887,
#   'service': 0.7882155,
#   'ambiance': 0.6494293,
#   'place': 0.76631534},
#  'surfing': {'food': -0.17963077,
#   'service': -0.23312145,
#   'ambiance': -0.3482353,
#   'place': -0.1924274},
#  'Gina cooks': None,
#  'Coffee': {'food': -0.08681772,
#   'service': -0.098315015,
#   'ambiance': -0.096103914,
#   'place': -0.06885926},
#  'juices': {'food': 0.43596283,
#   'service': 0.45651072,
#   'ambiance': 0.33340627,
#   'place': 0.40002275},
#  'sand': {'food': 0.016226165,
#   'service': 0.010276236,
#   'ambiance': 0.03695617,
#   'place': 0.032005392},
#  'hostess': {'food': 0.19406658,
#   'service': 0.18578307,
#   'ambiance': 0.14539215,
#   'place': 0.18686348},
#  'authorities': {'food': -0.31020176,
#   'service': -0.36072224,
#   'ambiance': -0.27830288,
#   'place': -0.32354447},
#  'plugs': {'food': 0.07297085,
#   'service': 0.06631165,
#   'ambiance': 0.056979865,
#   'place': 0.05664202},
#  'stadium': {'food': -0.029849915,
#   'service': -0.019858534,
#   'ambiance': -0.016777823,
#   'place': -0.042602483},
#  'rate': {'food': 0.6541319,
#   'service': 0.64015424,
#   'ambiance': 0.53550667,
#   'place': 0.60932124},
#  'staffs': {'food': 0.9708905,
#   'service': 0.9698686,
#   'ambiance': 0.7927303,
#   'place': 0.94709367},
#  'house staff': {'food': 0.24722359,
#   'service': 0.2512563,
#   'ambiance': 0.28165072,
#   'place': 0.2504898},
#  'air conditioning': {'food': 0.24052645,
#   'service': 0.19442774,
#   'ambiance': 0.1495477,
#   'place': 0.22882836},
#  'Hot water option': None,
#  'open air roof top': None,
#  'mini bar': {'food': 0.05171451,
#   'service': 0.02598207,
#   'ambiance': -0.02472014,
#   'place': 0.009566426},
#  'hide out place': None,
#  'entertainment': {'food': 0.30197164,
#   'service': 0.32921433,
#   'ambiance': 0.30350393,
#   'place': 0.3096265},
#  'bathrooms': {'food': 0.8728008,
#   'service': 0.89352435,
#   'ambiance': 0.7840853,
#   'place': 0.86364317},
#  'clean': {'food': 0.94826025,
#   'service': 0.96677727,
#   'ambiance': 0.8323405,
#   'place': 0.9482486},
#  'places': {'food': 0.968114,
#   'service': 0.9625935,
#   'ambiance': 0.8045482,
#   'place': 1.0},
#  'plants': {'food': 0.21987769,
#   'service': 0.20383604,
#   'ambiance': 0.19308306,
#   'place': 0.19740707},
#  'culture': {'food': 0.018260848,
#   'service': 0.0057456046,
#   'ambiance': -0.030681212,
#   'place': 0.07291439},
#  'environment Staff': {'food': 0.16092454,
#   'service': 0.14266017,
#   'ambiance': -0.0012688567,
#   'place': 0.11617859},
#  'eden': {'food': -0.13180599,
#   'service': -0.13644695,
#   'ambiance': -0.19063914,
#   'place': -0.11710994},
#  'pool environment': {'food': 0.020076066,
#   'service': 0.022344433,
#   'ambiance': 0.04210762,
#   'place': 0.022300212},
#  'greenery': {'food': 0.121481635,
#   'service': 0.13603841,
#   'ambiance': 0.16356811,
#   'place': 0.1549856},
#  'green': {'food': 0.56775403,
#   'service': 0.55601656,
#   'ambiance': 0.33420658,
#   'place': 0.5597862},
#  'reservations': {'food': 0.4284354,
#   'service': 0.44576326,
#   'ambiance': 0.32620075,
#   'place': 0.43827075},
#  'seenoevil': {'food': -0.14318796,
#   'service': -0.17336743,
#   'ambiance': -0.09307297,
#   'place': -0.12713647},
#  'map': {'food': 0.015131529,
#   'service': 0.009718705,
#   'ambiance': 0.04490883,
#   'place': 0.027824048},
#  'Guest': {'food': 0.11469513,
#   'service': 0.072010964,
#   'ambiance': -0.045596614,
#   'place': 0.10289254},
#  'AC': {'food': 0.38030887,
#   'service': 0.3784449,
#   'ambiance': 0.29879123,
#   'place': 0.3742321},
#  'reservation': {'food': 0.4284354,
#   'service': 0.44576326,
#   'ambiance': 0.32620075,
#   'place': 0.43827075},
#  'facility': {'food': 0.9539773,
#   'service': 0.95643234,
#   'ambiance': 0.81010115,
#   'place': 0.94371736},
#  'the place': None,
#  'Club': {'food': 0.31934378,
#   'service': 0.34048834,
#   'ambiance': 0.36943612,
#   'place': 0.3462407},
#  'clubs': {'food': 0.32741255,
#   'service': 0.32276446,
#   'ambiance': 0.29469132,
#   'place': 0.28368184},
#  'Comfort': {'food': 0.07307457,
#   'service': 0.07521422,
#   'ambiance': 0.12502897,
#   'place': 0.041971},
#  'Air conditioned rooms': None,
#  'park': {'food': 0.5609164,
#   'service': 0.55529016,
#   'ambiance': 0.39623854,
#   'place': 0.60431504},
#  'receptionists': {'food': 0.74736947,
#   'service': 0.75024104,
#   'ambiance': 0.62977326,
#   'place': 0.7384589},
#  'hall area': {'food': 0.06671104,
#   'service': 0.04597736,
#   'ambiance': -0.015812367,
#   'place': 0.057465695},
#  'rooms price': None,
#  'bathroom toilet': {'food': -0.22274293,
#   'service': -0.24518406,
#   'ambiance': -0.11901319,
#   'place': -0.2109937},
#  'star': {'food': 0.48689437,
#   'service': 0.4149866,
#   'ambiance': 0.19670218,
#   'place': 0.41041124},
#  'safe': {'food': 0.5312112,
#   'service': 0.55396056,
#   'ambiance': 0.3877406,
#   'place': 0.5341787},
#  'attendants': {'food': 0.48261648,
#   'service': 0.522866,
#   'ambiance': 0.48796198,
#   'place': 0.4685163},
#  'served': {'food': 0.28524172,
#   'service': 0.21296921,
#   'ambiance': 0.030787483,
#   'place': 0.21313378},
#  'beds': {'food': 0.91470015,
#   'service': 0.9022907,
#   'ambiance': 0.68412286,
#   'place': 0.87548417},
#  'evironment': {'food': 0.026661165,
#   'service': 0.06234733,
#   'ambiance': 0.077607945,
#   'place': 0.051148266},
#  'service team': {'food': 0.020871036,
#   'service': 0.026990904,
#   'ambiance': -0.12296631,
#   'place': -0.028546136},
#  'choices': {'food': 0.4306662,
#   'service': 0.46733296,
#   'ambiance': 0.43048364,
#   'place': 0.43749112},
#  'dishes': {'food': 0.8085575,
#   'service': 0.7952255,
#   'ambiance': 0.5486699,
#   'place': 0.76346505},
#  'taste': {'food': 0.64771,
#   'service': 0.63765067,
#   'ambiance': 0.5346797,
#   'place': 0.61201864},
#  'seafood fante': {'food': 0.11779244,
#   'service': 0.09460494,
#   'ambiance': 0.09739825,
#   'place': 0.11729401},
#  'bed service': {'food': -0.041071378,
#   'service': -0.05287152,
#   'ambiance': -0.08776828,
#   'place': -0.024459347},
#  'location Food': {'food': 0.0067380443,
#   'service': -0.0026908033,
#   'ambiance': -0.07522785,
#   'place': -0.01881162},
#  'staff service': {'food': 0.20726606,
#   'service': 0.16486917,
#   'ambiance': 0.105743274,
#   'place': 0.15145403},
#  'Cost': {'food': -0.047708776,
#   'service': -0.06758172,
#   'ambiance': -0.06938304,
#   'place': -0.03573867},
#  'dining room': {'food': 0.040249992,
#   'service': 0.038671248,
#   'ambiance': 0.035340905,
#   'place': 0.040522147},
#  'sauces': {'food': -0.025047153,
#   'service': -0.052375242,
#   'ambiance': -0.1636878,
#   'place': -0.054307915},
#  'guest rooms': None,
#  'waiter': {'food': 0.8106972,
#   'service': 0.8127037,
#   'ambiance': 0.6556334,
#   'place': 0.77517545},
#  'table': {'food': 0.54062414,
#   'service': 0.50498176,
#   'ambiance': 0.3166365,
#   'place': 0.5077122},
#  'outdoor programmes': None,
#  'pools': {'food': 0.9699679,
#   'service': 0.9647704,
#   'ambiance': 0.7813612,
#   'place': 0.96104085},
#  'Ironing': {'food': 0.1620738,
#   'service': 0.20501933,
#   'ambiance': 0.095066905,
#   'place': 0.20115374},
#  'service delivery': {'food': 0.022336898,
#   'service': 0.05113486,
#   'ambiance': 0.005585829,
#   'place': 0.021194573},
#  'Accommodation': {'food': -0.09423841,
#   'service': -0.06762583,
#   'ambiance': -0.08219489,
#   'place': -0.06721545},
#  'tv': {'food': 0.42389506,
#   'service': 0.4165593,
#   'ambiance': 0.3357497,
#   'place': 0.4201206},
#  'Travellers': {'food': 0.008029737,
#   'service': 0.019293755,
#   'ambiance': -0.020687163,
#   'place': 0.0044026524},
#  'room Sanitation': {'food': -0.05798483,
#   'service': -0.06289913,
#   'ambiance': 0.05490624,
#   'place': -0.048954424},
#  'bathroom furnishings': None,
#  'Potato chips': None,
#  'chicken': {'food': 0.5290295,
#   'service': 0.50913787,
#   'ambiance': 0.3899908,
#   'place': 0.48242494},
#  'bath shower TV': None,
#  'collective terrace': {'food': -0.21541509,
#   'service': -0.22029723,
#   'ambiance': -0.07310958,
#   'place': -0.17979519},
#  'shower pressure': {'food': -0.10095304,
#   'service': -0.11694974,
#   'ambiance': -0.09041121,
#   'place': -0.09941442},
#  'Teacher': {'food': -0.0046165176,
#   'service': -0.036631882,
#   'ambiance': 0.031948492,
#   'place': -0.024733134},
#  'roof': {'food': 0.14621173,
#   'service': 0.093923435,
#   'ambiance': 0.092437744,
#   'place': 0.13242745},
#  'hostel': {'food': 0.1952979,
#   'service': 0.18090273,
#   'ambiance': 0.21292049,
#   'place': 0.22799541},
#  'conference room': {'food': 0.15580806,
#   'service': 0.10517529,
#   'ambiance': -0.036049366,
#   'place': 0.1106078},
#  'club': {'food': 0.32741255,
#   'service': 0.32276446,
#   'ambiance': 0.29469132,
#   'place': 0.28368184},
#  'standard room': {'food': -0.11723007,
#   'service': -0.15764096,
#   'ambiance': -0.2121773,
#   'place': -0.114529535},
#  'air condition': {'food': -0.26657134,
#   'service': -0.28627133,
#   'ambiance': -0.28954634,
#   'place': -0.24811228},
#  'water heater': {'food': 0.09347318,
#   'service': 0.08563374,
#   'ambiance': 0.10539593,
#   'place': 0.12143476},
#  'service Prices': {'food': -0.02172175,
#   'service': -0.023745209,
#   'ambiance': 0.12436756,
#   'place': 0.0017779693},
#  'accessibility': {'food': 0.38693285,
#   'service': 0.38948017,
#   'ambiance': 0.25354594,
#   'place': 0.33999482},
#  'rooms Water heater': None,
#  'ambience rooms': None,
#  'reception Mrs Hooper': None,
#  'managerial': {'food': 0.20599495,
#   'service': 0.21552098,
#   'ambiance': 0.22216742,
#   'place': 0.22487646},
#  'toilet facilities': None,
#  'Location': {'food': 0.6585531,
#   'service': 0.6234472,
#   'ambiance': 0.40493727,
#   'place': 0.6340557},
#  'Bed': {'food': 0.32142675,
#   'service': 0.32529706,
#   'ambiance': 0.21812181,
#   'place': 0.30622214},
#  'fans': {'food': 0.12793896,
#   'service': 0.12849967,
#   'ambiance': 0.14638619,
#   'place': 0.09741318},
#  'cleaning': {'food': 0.41644627,
#   'service': 0.43305188,
#   'ambiance': 0.31165376,
#   'place': 0.41242403},
#  'Hot water': {'food': -0.2803913,
#   'service': -0.3184253,
#   'ambiance': -0.42274815,
#   'place': -0.27115035},
#  'matteress': {'food': 0.06716278,
#   'service': 0.06502706,
#   'ambiance': 0.016002275,
#   'place': 0.08908473},
#  'sockets': {'food': 0.09621465,
#   'service': 0.080086395,
#   'ambiance': 0.042459957,
#   'place': 0.10338299},
#  'mirror': {'food': 0.11977745,
#   'service': 0.07900983,
#   'ambiance': 0.058076497,
#   'place': 0.10467839},
#  'WC Fans': {'food': -0.05097846,
#   'service': -0.047961675,
#   'ambiance': 0.035803836,
#   'place': -0.044135265},
#  'plumbing': {'food': 0.014612325,
#   'service': -0.014376231,
#   'ambiance': -0.044457942,
#   'place': -0.041305948},
#  'Breakfast service': {'food': -0.038650654,
#   'service': -0.02583266,
#   'ambiance': -0.07326388,
#   'place': -0.018616943},
#  'building management': {'food': 0.19144902,
#   'service': 0.16644382,
#   'ambiance': 0.17157322,
#   'place': 0.21206397},
#  'bathroom facilities': None,
#  'interior': {'food': 0.03257852,
#   'service': 0.033114918,
#   'ambiance': -0.011626729,
#   'place': 0.022083402},
#  'guest house': {'food': 0.28904358,
#   'service': 0.29795003,
#   'ambiance': 0.19373275,
#   'place': 0.33755076},
#  'television': {'food': 0.28166568,
#   'service': 0.3018089,
#   'ambiance': 0.21479593,
#   'place': 0.29566875},
#  'bathtubs': {'food': 0.05542689,
#   'service': 0.023091558,
#   'ambiance': 0.019313917,
#   'place': 0.06836103},
#  'renovation': {'food': 0.4489779,
#   'service': 0.44771668,
#   'ambiance': 0.3865545,
#   'place': 0.4559287},
#  'network': {'food': 0.4088269,
#   'service': 0.41598988,
#   'ambiance': 0.29508793,
#   'place': 0.45485494},
#  'water heaters': None,
#  'toiletries breakfast': None,
#  'outfit': {'food': 0.16935222,
#   'service': 0.21780047,
#   'ambiance': 0.2763884,
#   'place': 0.23317206},
#  'Architect': {'food': -0.116127566,
#   'service': -0.16185132,
#   'ambiance': -0.07009828,
#   'place': -0.1271106},
#  'A C': {'food': -0.05593254,
#   'service': -0.09109424,
#   'ambiance': -0.14948584,
#   'place': -0.054374374},
#  'changed': {'food': 0.22551207,
#   'service': 0.17355919,
#   'ambiance': 0.03227052,
#   'place': 0.17128322},
#  'Savoy': {'food': 0.08576958,
#   'service': 0.06630626,
#   'ambiance': 0.05481971,
#   'place': 0.035392582},
#  'savoy': {'food': 0.035629462,
#   'service': 0.059653215,
#   'ambiance': 0.09377461,
#   'place': 0.025064666},
#  'crash': {'food': 0.16388778,
#   'service': 0.16179621,
#   'ambiance': 0.11537051,
#   'place': 0.16546598},
#  'school': {'food': 0.4384182,
#   'service': 0.40217397,
#   'ambiance': 0.31855285,
#   'place': 0.38902903},
#  'garden play areas': None,
#  'water pressure': {'food': 0.101777315,
#   'service': 0.07480711,
#   'ambiance': -0.00039078714,
#   'place': 0.11605794},
#  'fried eggs': None,
#  'soup': {'food': 0.25367057,
#   'service': 0.2537466,
#   'ambiance': 0.1297293,
#   'place': 0.25448808},
#  'with': None,
#  'pop corn': {'food': -0.0052902866,
#   'service': 0.011577569,
#   'ambiance': 0.06895025,
#   'place': 0.014701695},
#  'CEO': {'food': 0.33672082,
#   'service': 0.31971198,
#   'ambiance': 0.29202008,
#   'place': 0.3511665},
#  'jollof rice': {'food': -9.159744e-05,
#   'service': -0.0031016842,
#   'ambiance': -0.06709665,
#   'place': -0.02818492},
#  'owner madam': {'food': 0.012380708,
#   'service': 0.014778696,
#   'ambiance': -0.04609241,
#   'place': 0.03290043},
#  'place toilet': {'food': 0.16870853,
#   'service': 0.176631,
#   'ambiance': 0.20616661,
#   'place': 0.16903624},
#  'view of the lake': None,
#  'policy': {'food': 0.33457792,
#   'service': 0.3609391,
#   'ambiance': 0.27661744,
#   'place': 0.32381365},
#  'lake': {'food': 0.7666256,
#   'service': 0.73937666,
#   'ambiance': 0.5954089,
#   'place': 0.7858079},
#  'Staffs': {'food': 0.3439006,
#   'service': 0.3807889,
#   'ambiance': 0.3817785,
# ...
#  'Amy': {'food': -0.017674465,
#   'service': -0.010947581,
#   'ambiance': -0.02236119,
#   'place': -0.019186597},
#  'environment Staffs': {'food': 0.27361068,
#   'service': 0.25298524,
#   'ambiance': 0.21413371,
#   'place': 0.2565954},
#  'espresso coffee': {'food': -0.08324593,
#   'service': -0.103512675,
#   'ambiance': -0.21404655,
#   'place': -0.06441027},
#  'toilets': {'food': 0.630667,
#   'service': 0.6390893,
#   'ambiance': 0.54590344,
#   'place': 0.6221826},
#  'plastic': {'food': 0.337724,
#   'service': 0.2855418,
#   'ambiance': 0.18688276,
#   'place': 0.27139825},
#  'trip': {'food': 0.7741772,
#   'service': 0.7689562,
#   'ambiance': 0.5977386,
#   'place': 0.75648636},
#  'choice': {'food': 0.4306662,
#   'service': 0.46733296,
#   'ambiance': 0.43048364,
#   'place': 0.43749112},
#  'bathroom hot water': None,
#  'table tennis': {'food': -0.10543188,
#   'service': -0.12445094,
#   'ambiance': -0.11005399,
#   'place': -0.11725609},
#  'beach volleyball': {'food': -0.0665185,
#   'service': -0.08673702,
#   'ambiance': -0.08027933,
#   'place': -0.07643367},
#  'Coast Castle': {'food': -0.026528675,
#   'service': -0.028991187,
#   'ambiance': -0.14495024,
#   'place': -0.01605514},
#  'room service Breakfast': None,
#  'hôtel': {'food': 0.024624065,
#   'service': 0.037982333,
#   'ambiance': 0.080464676,
#   'place': 0.067385525},
#  'bed and breakfast place': None,
#  'Parking space': {'food': 0.12064365,
#   'service': 0.10705692,
#   'ambiance': 0.07349339,
#   'place': 0.11275786},
#  'breakfast Airconditioners': {'food': -0.014332484,
#   'service': -0.02385318,
#   'ambiance': -0.045398124,
#   'place': -0.02856953},
#  'PLACE': {'food': 0.27484953,
#   'service': 0.27166307,
#   'ambiance': 0.16892883,
#   'place': 0.29599112},
#  'location Service': {'food': 0.07748788,
#   'service': 0.090790585,
#   'ambiance': 0.024373492,
#   'place': 0.08973787},
#  'coffee': {'food': 0.3456074,
#   'service': 0.32918176,
#   'ambiance': 0.27399454,
#   'place': 0.35402536},
#  'Service personnel': {'food': 0.0066766534,
#   'service': 0.021115342,
#   'ambiance': 0.17351145,
#   'place': 0.040208805},
#  'room rates': None,
#  'spot lights': None,
#  'juice': {'food': 0.43596283,
#   'service': 0.45651072,
#   'ambiance': 0.33340627,
#   'place': 0.40002275},
#  'club sandwich': {'food': -0.17459251,
#   'service': -0.18565163,
#   'ambiance': -0.08846799,
#   'place': -0.18310063},
#  'section': {'food': -0.032943383,
#   'service': -0.042772014,
#   'ambiance': -0.14939061,
#   'place': -0.015145408},
#  'parking area Pool table': None,
#  'staff Location': {'food': -0.21513538,
#   'service': -0.22706151,
#   'ambiance': -0.08556643,
#   'place': -0.22507963},
#  'Scenery': {'food': -0.099572904,
#   'service': -0.07381563,
#   'ambiance': -0.0035318695,
#   'place': -0.11558573},
#  'zoo': {'food': 0.10152674,
#   'service': 0.10203229,
#   'ambiance': 0.10676758,
#   'place': 0.08801986},
#  'finishing': {'food': 0.14124158,
#   'service': 0.14147052,
#   'ambiance': 0.11388073,
#   'place': 0.17377888},
#  'sinks': {'food': -0.06416978,
#   'service': -0.08143011,
#   'ambiance': -0.045178726,
#   'place': -0.06849931},
#  'plumbing system': {'food': 0.026017219,
#   'service': 0.01575163,
#   'ambiance': -0.049379855,
#   'place': 0.04782746},
#  'ceilings': {'food': 0.12682769,
#   'service': 0.10630133,
#   'ambiance': 0.11477651,
#   'place': 0.12921266},
#  'fixtures and fittings': None,
#  'stress': {'food': 0.12548652,
#   'service': 0.099574596,
#   'ambiance': 0.007154241,
#   'place': 0.1515936},
#  'breezes': {'food': 0.7829261,
#   'service': 0.7787533,
#   'ambiance': 0.66695213,
#   'place': 0.8232276},
#  'tilapia with pepper': None,
#  'event': {'food': 0.49954718,
#   'service': 0.51537156,
#   'ambiance': 0.33077413,
#   'place': 0.48941875},
#  'swimming Tennis court': None,
#  'Experience': {'food': 0.3621304,
#   'service': 0.3586049,
#   'ambiance': 0.21738404,
#   'place': 0.31856304},
#  'dishes Room': None,
#  'environment Club': {'food': -0.13675654,
#   'service': -0.14452752,
#   'ambiance': -0.124494255,
#   'place': -0.12798655},
#  'Family Boat': {'food': 0.10445726,
#   'service': 0.08355354,
#   'ambiance': 0.043266505,
#   'place': 0.091726236},
#  'administration': {'food': 0.031426877,
#   'service': 0.03791012,
#   'ambiance': 0.065249234,
#   'place': 0.058332473},
#  'environmentsmiling': {'food': -0.24217732,
#   'service': -0.25491607,
#   'ambiance': -0.22470604,
#   'place': -0.2752456},
#  'eating area': {'food': 0.21173581,
#   'service': 0.19836721,
#   'ambiance': 0.14636493,
#   'place': 0.20648685},
#  'lines': {'food': 0.18503508,
#   'service': 0.194388,
#   'ambiance': 0.13595222,
#   'place': 0.17463559},
#  'price service': {'food': -0.06924716,
#   'service': -0.039627634,
#   'ambiance': -0.028321866,
#   'place': -0.04725884},
#  'maps': {'food': 0.015131529,
#   'service': 0.009718705,
#   'ambiance': 0.04490883,
#   'place': 0.027824048},
#  'accommodation meals': None,
#  'hostilities': {'food': -0.033770215,
#   'service': -0.022796433,
#   'ambiance': 0.037624024,
#   'place': -0.019133147},
#  'location Staffs': {'food': -0.01764558,
#   'service': -0.057959832,
#   'ambiance': 0.010122646,
#   'place': -0.016054742},
#  'driving': {'food': 0.024989512,
#   'service': -0.027599694,
#   'ambiance': -0.012472382,
#   'place': 0.041733753},
#  'transport': {'food': 0.39302468,
#   'service': 0.3992525,
#   'ambiance': 0.36851448,
#   'place': 0.41605693},
#  'Home service': {'food': -0.030853968,
#   'service': -0.026801433,
#   'ambiance': -0.108032614,
#   'place': -0.070179},
#  'genset': {'food': -0.05723585,
#   'service': -0.045679897,
#   'ambiance': 0.021016896,
#   'place': 0.011652723},
#  'countryside': {'food': 0.18278499,
#   'service': 0.17737609,
#   'ambiance': 0.17238316,
#   'place': 0.17425612},
#  'curtains': {'food': -0.04816419,
#   'service': -0.057652306,
#   'ambiance': -0.036155798,
#   'place': -0.05602697},
#  'cleaner': {'food': 0.41546977,
#   'service': 0.42509145,
#   'ambiance': 0.33952385,
#   'place': 0.42260006},
#  'non alcoholic': {'food': -0.0028533824,
#   'service': -0.006025426,
#   'ambiance': -0.041603453,
#   'place': 0.014935646},
#  'outdoor nature': {'food': -0.09602566,
#   'service': -0.11509189,
#   'ambiance': -0.07614371,
#   'place': -0.09315785},
#  'taps': {'food': 0.08671452,
#   'service': 0.089851804,
#   'ambiance': 0.1330517,
#   'place': 0.09051212},
#  'food portions': None,
#  'phone': {'food': 0.58157057,
#   'service': 0.56927836,
#   'ambiance': 0.48159626,
#   'place': 0.5739136},
#  'grid': {'food': -0.09460145,
#   'service': -0.10489634,
#   'ambiance': -0.03806816,
#   'place': -0.12195301},
#  'Tap': {'food': 0.078384385,
#   'service': 0.045108788,
#   'ambiance': 0.029832013,
#   'place': 0.052596014},
#  'mattress Manager': {'food': -0.088648126,
#   'service': -0.102975376,
#   'ambiance': -0.14400339,
#   'place': -0.10956982},
#  'organic food': {'food': 0.11286032,
#   'service': 0.095787875,
#   'ambiance': 0.19248524,
#   'place': 0.122290075},
#  'lemon grass tea': None,
#  'Hosts': {'food': -0.014168467,
#   'service': -0.042586464,
#   'ambiance': -0.18576151,
#   'place': -0.029962115},
#  'grilled chicken with sautéed veggies': None,
#  'Government': {'food': -0.0655057,
#   'service': -0.059877492,
#   'ambiance': -0.10590193,
#   'place': -0.11077998},
#  'days': {'food': 0.84281385,
#   'service': 0.8031564,
#   'ambiance': 0.53420204,
#   'place': 0.7991773},
#  'fresh air': {'food': 0.19786885,
#   'service': 0.20365998,
#   'ambiance': 0.17085013,
#   'place': 0.19557405},
#  'toilet space': {'food': 0.1538535,
#   'service': 0.1598656,
#   'ambiance': 0.15124495,
#   'place': 0.17879298},
#  'hygiene': {'food': 0.12937057,
#   'service': 0.14225088,
#   'ambiance': 0.12901817,
#   'place': 0.12461258},
#  'customer services': None,
#  'toilet sheets': None,
#  'hide out': None,
#  'getaway': {'food': 0.8270937,
#   'service': 0.84337306,
#   'ambiance': 0.681378,
#   'place': 0.8617194},
#  'foodsface _': {'food': -0.024479693,
#   'service': -0.024528448,
#   'ambiance': -0.07743308,
#   'place': 0.00026189908},
#  'canopy walkway': {'food': 0.010037705,
#   'service': -0.015257344,
#   'ambiance': 0.02142896,
#   'place': 0.027717084},
#  'special meal': {'food': -0.07815961,
#   'service': -0.061442547,
#   'ambiance': -0.091176294,
#   'place': -0.02455391},
#  'suite': {'food': 0.06836645,
#   'service': 0.020642322,
#   'ambiance': 0.04107685,
#   'place': 0.066957},
#  'mudfish': {'food': 0.032635424,
#   'service': 0.02709229,
#   'ambiance': -0.038010508,
#   'place': 0.04147623},
#  'goat meal': {'food': -0.069330566,
#   'service': -0.077329606,
#   'ambiance': -0.05948198,
#   'place': -0.06250965},
#  'meat': {'food': -0.42442483,
#   'service': -0.46458703,
#   'ambiance': -0.4771234,
#   'place': -0.43709832},
#  'corn drink': {'food': 0.050630145,
#   'service': 0.052545,
#   'ambiance': -0.028241053,
#   'place': 0.029235523},
#  'play area': {'food': -0.019763866,
#   'service': -0.005588703,
#   'ambiance': 0.01881234,
#   'place': -0.02486528},
#  'Okra stew': {'food': 0.112352446,
#   'service': 0.12144767,
#   'ambiance': 0.13658378,
#   'place': 0.115386195},
#  'baby': {'food': 0.03981115,
#   'service': 0.068743445,
#   'ambiance': -0.006933421,
#   'place': 0.053901047},
#  'goat light soup': None,
#  'starter': {'food': -0.03748491,
#   'service': -0.054477606,
#   'ambiance': -0.026914619,
#   'place': -0.072772086},
#  'plain rice sauce': None,
#  'grilled pork': {'food': -0.08109222,
#   'service': -0.0693587,
#   'ambiance': -0.15553778,
#   'place': -0.09690577},
#  'Guinea Fowls': {'food': -0.050343864,
#   'service': -0.058997903,
#   'ambiance': -0.051341817,
#   'place': -0.044773605},
#  'ACCOMMODATION': {'food': 0.0005379282,
#   'service': 0.010027222,
#   'ambiance': -0.0044024177,
#   'place': 0.016545914},
#  'animals': {'food': 0.5623932,
#   'service': 0.5438281,
#   'ambiance': 0.45796674,
#   'place': 0.5862305},
#  'Food prices': None,
#  'outdoor gathering': {'food': -0.15893088,
#   'service': -0.167411,
#   'ambiance': -0.2116068,
#   'place': -0.1639899},
#  'ostrich': {'food': 0.1654572,
#   'service': 0.12973908,
#   'ambiance': 0.2292784,
#   'place': 0.18145925},
#  'protein': {'food': 0.37542072,
#   'service': 0.3709253,
#   'ambiance': 0.3339566,
#   'place': 0.35972363},
#  'recreational place': {'food': 0.04962168,
#   'service': 0.03774718,
#   'ambiance': 0.06880003,
#   'place': 0.055281237},
#  'renovated': {'food': 0.18244708,
#   'service': 0.22131488,
#   'ambiance': 0.14544365,
#   'place': 0.19349405},
#  'local dishes': None,
#  'custo': {'food': 0.25357968,
#   'service': 0.29505393,
#   'ambiance': 0.22374478,
#   'place': 0.27548766},
#  'quiet': {'food': 0.90547776,
#   'service': 0.93067473,
#   'ambiance': 0.8454869,
#   'place': 0.9292056},
#  'sleeping': {'food': 0.42373037,
#   'service': 0.4288717,
#   'ambiance': 0.35400486,
#   'place': 0.40320313},
#  'stuff': {'food': 0.61477876,
#   'service': 0.645028,
#   'ambiance': 0.60357624,
#   'place': 0.6306192},
#  'noise': {'food': 0.39889634,
#   'service': 0.419832,
#   'ambiance': 0.30383575,
#   'place': 0.4080558},
#  'sound': {'food': 0.21212685,
#   'service': 0.22814319,
#   'ambiance': 0.20100383,
#   'place': 0.18596137},
#  'sites': {'food': 0.73644435,
#   'service': 0.73625445,
#   'ambiance': 0.7142389,
#   'place': 0.7422521},
#  'looks': {'food': 0.86543083,
#   'service': 0.84123546,
#   'ambiance': 0.63370943,
#   'place': 0.8508645},
#  'Operational': {'food': 0.06218775,
#   'service': 0.02805634,
#   'ambiance': 0.04977782,
#   'place': 0.0224582},
#  'water front view': None,
#  'lagoon': {'food': 0.17675258,
#   'service': 0.12913999,
#   'ambiance': 0.031839944,
#   'place': 0.1598548},
#  'recreation': {'food': 0.037021026,
#   'service': 0.067985676,
#   'ambiance': 0.1378078,
#   'place': 0.02473191},
#  'vase space': {'food': -0.09868105,
#   'service': -0.09938744,
#   'ambiance': -0.08756777,
#   'place': -0.13738811},
#  'siren': {'food': 0.054354478,
#   'service': 0.05664324,
#   'ambiance': 0.124110565,
#   'place': 0.066944},
#  'town': {'food': 0.7837499,
#   'service': 0.7807189,
#   'ambiance': 0.68740857,
#   'place': 0.78245693},
#  'Personnel': {'food': 0.05812977,
#   'service': 0.083930686,
#   'ambiance': 0.047289692,
#   'place': 0.06534011},
#  'buffet breakfast': {'food': 0.16563691,
#   'service': 0.14670487,
#   'ambiance': 0.025922855,
#   'place': 0.11315877},
#  'anything': {'food': 0.36130846,
#   'service': 0.3390382,
#   'ambiance': 0.22082178,
#   'place': 0.272439},
#  'swiming pool': {'food': -0.16098195,
#   'service': -0.16821085,
#   'ambiance': -0.15576021,
#   'place': -0.18067819},
#  'place entertainment': {'food': 0.00781139,
#   'service': 0.01308652,
#   'ambiance': -0.022749193,
#   'place': 0.031803653},
#  'Pool system': {'food': 0.12856552,
#   'service': 0.13880686,
#   'ambiance': 0.112488285,
#   'place': 0.18006724},
#  'city': {'food': 0.8658402,
#   'service': 0.8494195,
#   'ambiance': 0.63125277,
#   'place': 0.8497792},
#  'mobile network': {'food': -0.04398629,
#   'service': -0.031421784,
#   'ambiance': 0.06395776,
#   'place': -0.051424757},
#  'bulbs': {'food': 0.01366768,
#   'service': -0.00095385313,
#   'ambiance': -0.029789437,
#   'place': 0.01820705},
#  'grilled barracuda': {'food': 0.17369029,
#   'service': 0.17335281,
#   'ambiance': 0.1305299,
#   'place': 0.20238268},
#  'reception area': {'food': 0.17376494,
#   'service': 0.14186531,
#   'ambiance': 0.051029414,
#   'place': 0.15098895},
#  'fishing': {'food': 0.42888075,
#   'service': 0.3980862,
#   'ambiance': 0.2694398,
#   'place': 0.4179268},
#  'Vibe': {'food': 0.26450825,
#   'service': 0.23058835,
#   'ambiance': 0.08412812,
#   'place': 0.15802255},
#  'upgrades': {'food': -0.121638596,
#   'service': -0.09723394,
#   'ambiance': -0.08863824,
#   'place': -0.09709456},
#  'Chairs': {'food': 0.090411454,
#   'service': 0.086701274,
#   'ambiance': 0.009454101,
#   'place': 0.09212503},
#  'Dish': {'food': 0.06253298,
#   'service': 0.055274837,
#   'ambiance': 0.038817525,
#   'place': 0.033636626},
#  'concept': {'food': 0.26018018,
#   'service': 0.26493058,
#   'ambiance': 0.17198339,
#   'place': 0.22055656},
#  'Annie': {'food': 0.17102319,
#   'service': 0.16471526,
#   'ambiance': 0.20513213,
#   'place': 0.20010468},
#  'environment location food rooms': None,
#  'vibes lunching': None,
#  'apartment': {'food': 0.32170904,
#   'service': 0.34755638,
#   'ambiance': 0.24520218,
#   'place': 0.36322194},
#  'outdoor space': {'food': 0.13429184,
#   'service': 0.12048064,
#   'ambiance': 0.1974542,
#   'place': 0.116677254},
#  'recreational centers': None,
#  'layout': {'food': 0.09464954,
#   'service': 0.081178285,
#   'ambiance': 0.09101939,
#   'place': 0.14518467},
#  'location service': {'food': -0.2180512,
#   'service': -0.17992091,
#   'ambiance': -0.23135835,
#   'place': -0.19430727},
#  'front desk personnels': None,
#  'Ambiance': {'food': -0.36228007,
#   'service': -0.3933143,
#   'ambiance': -0.41312045,
#   'place': -0.39356643},
#  'open access to the sea': None,
#  'water pump': {'food': -0.08177559,
#   'service': -0.075048186,
#   'ambiance': -0.06508575,
#   'place': -0.09138816},
#  'games': {'food': -0.11150627,
#   'service': -0.1512291,
#   'ambiance': -0.2178174,
#   'place': -0.09574281},
#  'birds': {'food': 0.3458923,
#   'service': 0.29338706,
#   'ambiance': 0.17338347,
#   'place': 0.3380007},
#  'numbers': {'food': 0.019990893,
#   'service': -0.02326264,
#   'ambiance': -0.17772621,
#   'place': -0.040405937},
#  'Resort Spa': {'food': 0.43898016,
#   'service': 0.46251476,
#   'ambiance': 0.4404432,
#   'place': 0.45337245},
#  'royal hideout': {'food': 0.13178042,
#   'service': 0.16262363,
#   'ambiance': 0.18420222,
#   'place': 0.14383438},
#  'property': {'food': 0.5600581,
#   'service': 0.56017685,
#   'ambiance': 0.48170707,
#   'place': 0.55624825},
#  'resorts': {'food': 0.958107,
#   'service': 0.9489223,
#   'ambiance': 0.77984357,
#   'place': 0.94678223},
#  'security guys': None,
#  'beach bar pool': None,
#  'sun loungers': None,
#  'beach huts': None,
#  'spa treatment': {'food': 0.04780574,
#   'service': 0.07251271,
#   'ambiance': 0.06913374,
#   'place': 0.053320054},
#  'hall mark': {'food': 0.05489506,
#   'service': 0.09429781,
#   'ambiance': 0.10794361,
#   'place': 0.07151432},
#  'seating': {'food': 0.19158937,
#   'service': 0.19844188,
#   'ambiance': 0.21133065,
#   'place': 0.16379268},
#  'pool by the beach': None,
#  'neet': {'food': -0.055336237,
#   'service': -0.04990898,
#   'ambiance': 0.024366707,
#   'place': -0.04535161},
#  'housing': {'food': 0.094451636,
#   'service': 0.0939673,
#   'ambiance': 0.18490078,
#   'place': 0.07127838},
#  'Affordable': {'food': 0.3868803,
#   'service': 0.38294238,
#   'ambiance': 0.39883113,
#   'place': 0.43671837},
#  ...}

# %%
aspect_labels = {}
for record, values in distance_data.items():
    if values == None:
        aspect_labels[record] = None
    else:
        scores = []
        keys = []
        for key, score in values.items():
            keys.append(key)
            scores.append(score)
        max_index = scores.index(max(scores))
        aspect_labels[record] = keys[max_index]

# %%
aspect_labels
# Out:
# {'rooms': 'food',
#  'services': 'service',
#  'stay': 'food',
#  'environment': 'place',
#  'times': 'food',
#  'ambiance': 'ambiance',
#  'thumbs _ upthumbs': None,
#  'service': 'service',
#  'food': 'food',
#  'Staff': 'service',
#  'reception': 'food',
#  'place': 'place',
#  'prices': 'food',
#  'breakfast': 'service',
#  'designs in': None,
#  'ventilation AC Fan rooms': None,
#  'events': 'service',
#  'location': 'place',
#  'designs': 'service',
#  'washrooms': 'service',
#  'drinks': 'food',
#  'staff': 'food',
#  'beach': 'food',
#  'maintenance': 'place',
#  'landscape': 'place',
#  'accommodation': 'food',
#  'kitchen': 'food',
#  'hosts': 'food',
#  'value': 'food',
#  'wish': 'service',
#  'waiters': 'service',
#  'menu': 'service',
#  'appearance': 'ambiance',
#  'owner': 'service',
#  'cuisine': 'food',
#  'views': 'place',
#  'water': 'food',
#  'shower': 'food',
#  'tap': 'ambiance',
#  'traffic': 'place',
#  'road': 'food',
#  'meals': 'food',
#  'of': None,
#  'manager owner': 'ambiance',
#  'beaches': 'food',
#  'personal': 'place',
#  'ocean': 'food',
#  'Chef': 'ambiance',
#  'meal': 'food',
#  'atmosphere': 'place',
#  'team': 'food',
#  'umbrella': 'place',
#  'pricing': 'place',
#  'design': 'service',
#  'internet connection': 'service',
#  'sea beach': 'food',
#  'area': 'food',
#  'bread': 'place',
#  'spot': 'service',
#  'Food': 'food',
#  'Rooms': 'food',
#  'people': 'food',
#  'Atmosphere': 'service',
#  'sunsets': 'food',
#  'breeze': 'place',
#  'guys': 'food',
#  'view': 'place',
#  'facilities': 'service',
#  'workers': 'service',
#  'dinner': 'food',
#  'Beach': 'food',
#  'privacy': 'place',
#  'leisure': 'food',
#  'facilities rooms': None,
#  'exclamation food Room s': None,
#  'amenities rooms': None,
#  'Garden': 'ambiance',
#  'host': 'food',
#  'Aircon': 'ambiance',
#  'bar': 'food',
#  'veggie food': 'place',
#  'chickens': 'food',
#  'Green garden eco lodge': None,
#  'vibes': 'food',
#  'space': 'food',
#  'gardening': 'service',
#  'indian food': 'food',
#  'International cuisine': 'food',
#  'coffee shop': 'ambiance',
#  'shared lounge': 'food',
#  'Ghana': 'food',
#  'green zion garden': None,
#  'Zion': 'ambiance',
#  'garden': 'place',
#  'vegetarian cooking': 'ambiance',
#  'colors': 'ambiance',
#  'coconut': 'food',
#  'Green zion garden': None,
#  'Pancakes': 'ambiance',
#  'refreshment': 'service',
#  'night': 'food',
#  'pool': 'food',
#  'parking space': 'food',
#  'security': 'service',
#  'hotel': 'food',
#  'plce': 'service',
#  'amenities room poolside restaurant': None,
#  'environment services': None,
#  'manager': 'food',
#  'Front Desk': 'ambiance',
#  'furniture': 'service',
#  'bathroom': 'service',
#  'business': 'place',
#  'experience': 'food',
#  'breakfast buffet': 'food',
#  'options': 'food',
#  'hotels': 'food',
#  'learning': 'food',
#  'time': 'food',
#  'staying': 'food',
#  'mattress': 'food',
#  'window': 'food',
#  'toilet seat': 'food',
#  'lodge': 'service',
#  'front desk staff': None,
#  'conference rooms': None,
#  'ambience': 'service',
#  'buffet dinner': 'service',
#  'goose': 'food',
#  'room': 'food',
#  'Furniture': 'place',
#  'bedstead': 'ambiance',
#  'bedding': 'food',
#  'Washroom housekeeping': 'ambiance',
#  'live band music': None,
#  'spring rolls': None,
#  'takodi': 'place',
#  'globe': 'place',
#  'inn': 'food',
#  'Wifi': 'service',
#  'staff reception': 'service',
#  'buffet breakfast menu': None,
#  'view of the': None,
#  'Pizza': 'food',
#  'amenities': 'service',
#  'management': 'place',
#  'price': 'food',
#  'seaview': 'food',
#  'swimming pool lounge chairs': None,
#  'pool beds': None,
#  'showers': 'food',
#  'power': 'place',
#  'Air conditioning': 'ambiance',
#  'Pillows': 'service',
#  'clean rooms': None,
#  'resort': 'food',
#  'selection of food': None,
#  'onsite entertainment': 'ambiance',
#  'Service': 'food',
#  'arranged apartments': None,
#  'comfort': 'food',
#  'dinners': 'food',
#  'Services': 'place',
#  'interior design': 'place',
#  'Clean room Staff': None,
#  'bed': 'food',
#  'living room': 'ambiance',
#  'kitchenette': 'ambiance',
#  'freezer': 'ambiance',
#  'place Apartments': 'place',
#  'catering services': None,
#  'daily room cleaning': None,
#  'waitresses': 'food',
#  'bar area': 'food',
#  'Place': 'ambiance',
#  'home': 'food',
#  'Compound': 'food',
#  'size beds': None,
#  'LODGE': 'place',
#  'Environment': 'place',
#  'managed lodge': 'food',
#  'Boarding facility': 'ambiance',
#  'view of': None,
#  'wifi': 'ambiance',
#  'address': 'service',
#  'sea view': 'food',
#  'corridor': 'place',
#  'Room': 'service',
#  'residing': 'service',
#  'WiFi': 'food',
#  'guest': 'food',
#  'offers': 'service',
#  'Vacation': 'food',
#  'swim': 'food',
#  'STAFF': 'place',
#  'ENVIRONMENT': 'food',
#  'fitness center': 'food',
#  'swimming pool': 'food',
#  'safe rooms': None,
#  'managers': 'food',
#  'Room service': 'food',
#  'serving Breakfast': 'ambiance',
#  'common toilets': None,
#  'soap': 'food',
#  'Rates': 'ambiance',
#  'Facilities': 'place',
#  'bar services': None,
#  'Guest House': 'food',
#  'receptionist': 'service',
#  'rates': 'food',
#  'rooms breakfast': None,
#  'night manager': 'ambiance',
#  'Hospitality': 'service',
#  'drink': 'food',
#  'Staf': 'service',
#  'Fredrick': 'food',
#  'energy': 'food',
#  'Beach House': 'food',
#  'surf school': 'service',
#  'chef': 'food',
#  'cocktails': 'food',
#  'akpetesthie': 'place',
#  'restaurant': 'food',
#  'vegetarian options': None,
#  'owners dog': None,
#  'owner Julia': 'ambiance',
#  'living': 'place',
#  'eco lodge': 'place',
#  'scenery': 'place',
#  'destination': 'food',
#  'natural environment': 'place',
#  'fufu': 'food',
#  'vibe': 'food',
#  'hospitality': 'place',
#  'climate': 'place',
#  'plates': 'food',
#  'waves': 'food',
#  'Lodge': 'place',
#  'caipirinha': 'food',
#  'decorated place': 'service',
#  'oatmeal breakfast': 'food',
#  'air': 'food',
#  'outside walls': None,
#  'accommodations': 'food',
#  'fumigation': 'place',
#  'sunrise': 'food',
#  'Great': 'service',
#  'lunch': 'food',
#  'hideout': 'place',
#  'environment Breakfast': 'food',
#  'Swimming': 'place',
#  'hot water': 'food',
#  'linen': 'ambiance',
#  'Bathroom': 'food',
#  'compound': 'food',
#  'programs': 'place',
#  'Drinks': 'service',
#  'Eye': 'ambiance',
#  'sleep': 'service',
#  'environmental': 'ambiance',
#  'lighting aircondirion': 'food',
#  'Home': 'place',
#  'beverages': 'ambiance',
#  'pictures': 'service',
#  'affordable': 'place',
#  'Reservations': 'food',
#  'car park': 'place',
#  'worker': 'service',
#  'nature': 'food',
#  'electricity supply': 'food',
#  'expensive': 'service',
#  'events arena': None,
#  'conference': 'service',
#  'Eco': 'service',
#  'relaxation beaming _ face': None,
#  'live band': 'place',
#  'doors': 'place',
#  'gym': 'service',
#  'area Access': 'ambiance',
#  'hide': 'place',
#  'suits': 'place',
#  'size': 'place',
#  'continental dishes': None,
#  'Breakfast': 'food',
#  'client': 'food',
#  'washroom': 'service',
#  'outdoor area': 'ambiance',
#  'roof terrace': 'service',
#  'lighting': 'ambiance',
#  'benjee': 'service',
#  'Ressort': 'place',
#  'rooftop': 'place',
#  'guy': 'food',
#  'coconuts': 'food',
#  'towels': 'food',
#  'outdoor shower': 'food',
#  'vegan food': 'food',
#  'dish': 'food',
#  'athmo': 'service',
#  'FOOD': 'food',
#  'avocado toast': 'food',
#  'portions': 'place',
#  'staff Shower': 'place',
#  'lettuce': 'ambiance',
#  'Goat': 'place',
#  'massage': 'food',
#  'ingredients': 'service',
#  'setting': 'place',
#  'employees': 'service',
#  'veggie burgers': None,
#  'slices of potato': None,
#  'banana pancakes': None,
#  'Laughing Goat': 'ambiance',
#  'ital food': 'service',
#  'luggage': 'place',
#  'sink': 'ambiance',
#  'sign': 'food',
#  'activities': 'service',
#  'Lizzy': 'food',
#  'James': 'service',
#  'swimming beach Food': None,
#  'mosquito': 'food',
#  'sea': 'food',
#  'site': 'place',
#  'Robberies': 'place',
#  'caretaker': 'ambiance',
#  'bays': 'ambiance',
#  'relaxation': 'place',
#  'personnel': 'place',
#  'quality': 'service',
#  'attractions': 'service',
#  'Olivier': 'food',
#  'honeymoon': 'place',
#  'Road': 'ambiance',
#  'Tilapia': 'food',
#  'Ambience': 'ambiance',
#  'Hotel': 'food',
#  'parking lot': 'place',
#  'staff Food': 'ambiance',
#  'pool view Food': None,
#  'terrace': 'food',
#  'Dinner': 'ambiance',
#  'outdoors bar patio': None,
#  'owners': 'service',
#  'Charcoal Grilled Lobster': None,
#  'weather': 'ambiance',
#  'corner': 'food',
#  'Water': 'ambiance',
#  'electricity': 'place',
#  'tilapia': 'ambiance',
#  'construction': 'service',
#  'dorm': 'service',
#  'cook': 'service',
#  'houses': 'service',
#  'surfing': 'food',
#  'Gina cooks': None,
#  'Coffee': 'place',
#  'juices': 'service',
#  'sand': 'ambiance',
#  'hostess': 'food',
#  'authorities': 'ambiance',
#  'plugs': 'food',
#  'stadium': 'ambiance',
#  'rate': 'food',
#  'staffs': 'food',
#  'house staff': 'ambiance',
#  'air conditioning': 'food',
#  'Hot water option': None,
#  'open air roof top': None,
#  'mini bar': 'food',
#  'hide out place': None,
#  'entertainment': 'service',
#  'bathrooms': 'service',
#  'clean': 'service',
#  'places': 'place',
#  'plants': 'food',
#  'culture': 'place',
#  'environment Staff': 'food',
#  'eden': 'place',
#  'pool environment': 'ambiance',
#  'greenery': 'ambiance',
#  'green': 'food',
#  'reservations': 'service',
#  'seenoevil': 'ambiance',
#  'map': 'ambiance',
#  'Guest': 'food',
#  'AC': 'food',
#  'reservation': 'service',
#  'facility': 'service',
#  'the place': None,
#  'Club': 'ambiance',
#  'clubs': 'food',
#  'Comfort': 'ambiance',
#  'Air conditioned rooms': None,
#  'park': 'place',
#  'receptionists': 'service',
#  'hall area': 'food',
#  'rooms price': None,
#  'bathroom toilet': 'ambiance',
#  'star': 'food',
#  'safe': 'service',
#  'attendants': 'service',
#  'served': 'food',
#  'beds': 'food',
#  'evironment': 'ambiance',
#  'service team': 'service',
#  'choices': 'service',
#  'dishes': 'food',
#  'taste': 'food',
#  'seafood fante': 'food',
#  'bed service': 'place',
#  'location Food': 'food',
#  'staff service': 'food',
#  'Cost': 'place',
#  'dining room': 'place',
#  'sauces': 'food',
#  'guest rooms': None,
#  'waiter': 'service',
#  'table': 'food',
#  'outdoor programmes': None,
#  'pools': 'food',
#  'Ironing': 'service',
#  'service delivery': 'service',
#  'Accommodation': 'place',
#  'tv': 'food',
#  'Travellers': 'service',
#  'room Sanitation': 'ambiance',
#  'bathroom furnishings': None,
#  'Potato chips': None,
#  'chicken': 'food',
#  'bath shower TV': None,
#  'collective terrace': 'ambiance',
#  'shower pressure': 'ambiance',
#  'Teacher': 'ambiance',
#  'roof': 'food',
#  'hostel': 'place',
#  'conference room': 'food',
#  'club': 'food',
#  'standard room': 'place',
#  'air condition': 'place',
#  'water heater': 'place',
#  'service Prices': 'ambiance',
#  'accessibility': 'service',
#  'rooms Water heater': None,
#  'ambience rooms': None,
#  'reception Mrs Hooper': None,
#  'managerial': 'place',
#  'toilet facilities': None,
#  'Location': 'food',
#  'Bed': 'service',
#  'fans': 'ambiance',
#  'cleaning': 'service',
#  'Hot water': 'place',
#  'matteress': 'place',
#  'sockets': 'place',
#  'mirror': 'food',
#  'WC Fans': 'ambiance',
#  'plumbing': 'food',
#  'Breakfast service': 'place',
#  'building management': 'place',
#  'bathroom facilities': None,
#  'interior': 'service',
#  'guest house': 'place',
#  'television': 'service',
#  'bathtubs': 'place',
#  'renovation': 'place',
#  'network': 'place',
#  'water heaters': None,
#  'toiletries breakfast': None,
#  'outfit': 'ambiance',
#  'Architect': 'ambiance',
#  'A C': 'place',
#  'changed': 'food',
#  'Savoy': 'food',
#  'savoy': 'ambiance',
#  'crash': 'place',
#  'school': 'food',
#  'garden play areas': None,
#  'water pressure': 'place',
#  'fried eggs': None,
#  'soup': 'place',
#  'with': None,
#  'pop corn': 'ambiance',
#  'CEO': 'place',
#  'jollof rice': 'food',
#  'owner madam': 'place',
#  'place toilet': 'ambiance',
#  'view of the lake': None,
#  'policy': 'service',
#  'lake': 'place',
#  'Staffs': 'ambiance',
#  'wildwin drinks': None,
#  'grounds': 'food',
#  'course': 'food',
#  'the lake': None,
#  'waiting service': 'place',
#  'customer': 'service',
#  'booking': 'place',
#  'bbq': 'service',
#  'mini fridge': 'food',
#  'floor': 'food',
#  'Service staff': 'place',
#  'place Place': 'food',
#  'beer': 'ambiance',
#  'Cocktails': 'place',
#  'sea food linguine': None,
#  'beach front': 'food',
#  'sceneries': 'place',
#  'catering': 'service',
#  'fish': 'food',
#  'pizza': 'food',
#  'courtesy': 'place',
#  'lady manager': 'service',
#  'Setting': 'ambiance',
#  'Location access': 'ambiance',
#  'beach soccer': 'ambiance',
#  'wifi tv': 'food',
#  'cocktail': 'food',
#  'patio': 'service',
#  'music': 'food',
#  'crowds': 'food',
#  'Spa': 'place',
#  'beach food': 'ambiance',
#  'Owner': 'place',
#  'glass': 'ambiance',
#  'snacks': 'place',
#  'Mattresses': 'ambiance',
#  'priced food': 'food',
#  'Lobster': 'service',
#  'chalets': 'place',
#  'hammocks': 'place',
#  'family atmosphere': 'food',
#  'sea food': 'ambiance',
#  'beach Lodge': 'food',
#  'place Service': 'food',
#  'cooks': 'service',
#  'Accomodations': 'ambiance',
#  'selection of beers': None,
#  'view of the sea': None,
#  'stuffs': 'service',
#  'fishing activity': 'ambiance',
#  'saround': 'place',
#  'VIEW': 'food',
#  'laundry service': 'service',
#  'sea breeze': 'food',
#  'architecture': 'food',
#  'shama': 'ambiance',
#  'golf course': 'food',
#  'outside design': 'service',
#  'inside design': 'food',
#  'room Bed': 'food',
#  'outdoor jacuzzi': 'ambiance',
#  'equipment': 'service',
#  'lawns': 'food',
#  'Internet access': 'food',
#  'public areas': None,
#  'pool areas': None,
#  'View': 'place',
#  'water sports': None,
#  'TV': 'service',
#  'bathroom wash sink': None,
#  'rice': 'place',
#  'oil': 'service',
#  'wait': 'food',
#  'mattresses': 'food',
#  'Nature': 'food',
#  'staff Owner': 'ambiance',
#  'egg': 'ambiance',
#  'beach access': 'food',
#  'coconut water': 'place',
#  'African traditional': 'food',
#  'place Everyone': 'ambiance',
#  'top bar': 'ambiance',
#  'delivery time': 'ambiance',
#  'internet connectivity': 'service',
#  'food service staff': None,
#  'beach view': 'food',
#  'beach towels': None,
#  'pizza fish': 'place',
#  'sea Rooms': 'ambiance',
#  'waiting time': 'food',
#  'Tables': 'ambiance',
#  'spaced rooms': None,
#  'accommodation amenities Price': None,
#  'heaven': 'food',
#  'Paradise': 'ambiance',
#  'Surrounding': 'food',
#  'garden sit outs': None,
#  'corporate events': None,
#  'Red Plantain': 'ambiance',
#  'beans': 'ambiance',
#  'chicken stew': 'service',
#  'portion': 'place',
#  'Management': 'service',
#  'venue': 'service',
#  'closure': 'food',
#  'roads': 'food',
#  'community': 'food',
#  'villas': 'food',
#  'wine list': 'place',
#  'champagne': 'place',
#  'closed': 'service',
#  'Seafood platter': 'service',
#  'Prices': 'place',
#  'booked': 'food',
#  'Butler': 'ambiance',
#  'sea defence': 'ambiance',
#  'Reception': 'service',
#  'complex': 'ambiance',
#  'reception hall': 'ambiance',
#  'Lunch': 'ambiance',
#  'seafood': 'service',
#  'Vienna sausages': None,
#  'hearts': 'food',
#  'buffet': 'service',
#  'sea view balcony': None,
#  'environment Workers': 'food',
#  'holiday': 'place',
#  'Axim Beach': 'place',
#  'lobster': 'service',
#  'cost': 'food',
#  'serenity': 'service',
#  'front desk': 'service',
#  'Manager': 'place',
#  'located': 'service',
#  'maintained': 'service',
#  'eggs': 'ambiance',
#  'mushroom sauce': 'service',
#  'beef': 'service',
#  'wine': 'place',
#  'fork': 'food',
#  'plate': 'food',
#  'beauty': 'service',
#  'location Prices': 'ambiance',
#  'football': 'place',
#  'monica': 'food',
#  'Amenities': 'food',
#  'service food': 'food',
#  'island villas': None,
#  'spring mattresses': None,
#  'seafood dinners': None,
#  'face _ blowing': None,
#  'money': 'food',
#  'dining area': 'place',
#  'Luxury': 'ambiance',
#  'tours': 'food',
#  'soups': 'place',
#  'butler': 'food',
#  'watersport facilities': None,
#  'sandwiches': 'food',
#  'bowl of chips': None,
#  'food service': 'service',
#  'food Staff': 'service',
#  'sun bed': 'place',
#  'Deluxe Room': 'food',
#  'deluxe rooms': None,
#  'quietness': 'ambiance',
#  'ankobra beach': 'place',
#  'playground': 'service',
#  'grilled lobsters': None,
#  'food services': None,
#  'serves': 'ambiance',
#  'surroundings': 'ambiance',
#  'local cuisine': 'service',
#  'waitress': 'food',
#  'beach side': 'ambiance',
#  'sundowners': 'place',
#  'Foods': 'service',
#  'situated': 'food',
#  'smell of wood': None,
#  'smell': 'place',
#  'package': 'food',
#  'delivery': 'service',
#  'variety of dishes': None,
#  'juices served': None,
#  'band': 'food',
#  'Water dispenser': 'food',
#  'house keeping': 'ambiance',
#  'Stilt Village': 'food',
#  'Lemon Beach Resort': None,
#  'internet access': 'ambiance',
#  'internet service': 'place',
#  'Lemon Beach': 'food',
#  'check': 'food',
#  'check out': None,
#  'view of the sea beach': None,
#  'servers': 'service',
#  'ocean waves': None,
#  'eco friendliness': 'food',
#  'Standalone Design': 'food',
#  'beach golf course': None,
#  'security personnel': 'food',
#  'front desk personnel': None,
#  'atmosphere servers': None,
#  'welcome': 'food',
#  'poolside': 'service',
#  'people Dennis': 'ambiance',
#  'Reservation': 'food',
#  'Swan bed': 'service',
#  'waitering service': 'service',
#  'service Food': 'food',
#  'Workers': 'service',
#  'room service': 'food',
#  'outside': 'food',
#  'toilet': 'service',
#  'fridge': 'place',
#  'bar of soap': None,
#  'a c': None,
#  'cleanliness': 'ambiance',
#  'breakfast rate': 'food',
#  'rest': 'place',
#  'hall': 'food',
#  'structures': 'place',
#  'settings': 'place',
#  'people food': 'ambiance',
#  'veiw': 'place',
#  'straw mattresses': None,
#  'ocean view': 'food',
#  'reggae music': 'ambiance',
#  'Coast castle': 'ambiance',
#  'veranda': 'place',
#  'Kobi': 'service',
#  'drumming': 'food',
#  'dorms': 'service',
#  'peace': 'place',
#  'owner kobi': 'ambiance',
#  'naturally built beds': None,
#  'lady': 'service',
#  'internet': 'service',
#  'aircon': 'ambiance',
#  'breakfast egg': 'place',
#  'cats': 'food',
#  'attendant': 'service',
#  'cozy': 'service',
#  'contract': 'service',
#  'Conference room': 'place',
#  'family rooms': None,
#  'infrastructure': 'service',
#  'mosquitoes food': None,
#  'grade': 'food',
#  'mechanic': 'food',
#  'balloon suspension': 'ambiance',
#  'TVs': 'service',
#  'carpark': 'place',
#  'WiFi system': 'place',
#  'security system': 'place',
#  'neighbourhood': 'ambiance',
#  'persons': 'food',
#  'walking': 'place',
#  'rooms food': None,
#  'bedroom': 'place',
#  'site lounge': 'place',
#  'oasis': 'place',
#  'environment Security': 'place',
#  'Kettle': 'service',
#  'tea': 'ambiance',
#  'bottles of water': None,
#  'toiletries': 'food',
#  'desk space': 'service',
#  'ventilation': 'place',
#  'food rooms': None,
#  'Food ambience staff': None,
#  'tuna sala': 'service',
#  'seafood fante fante': None,
#  'assistants': 'place',
#  'Beds': 'ambiance',
#  'white bread with scrambled eggs': None,
#  'women': 'ambiance',
#  'sheets': 'food',
#  'TOILET': 'ambiance',
#  'WIFI': 'ambiance',
#  'BREAKFAST': 'food',
#  'WAITING': 'food',
#  'BED': 'food',
#  'room hot water': None,
#  'personell': 'ambiance',
#  'Eggs': 'ambiance',
#  'Internet Cafe': 'ambiance',
#  'Castle': 'service',
#  'Situated': 'ambiance',
#  'executive room': 'place',
#  'water supply': 'place',
#  'bathroom shower': 'place',
#  'parking space Interior': None,
#  'Stairway': 'food',
#  'lobby Bar': 'service',
#  'flowers': 'ambiance',
#  'out door programs': None,
#  'dressing': 'ambiance',
#  'place people': 'place',
#  'priced': 'service',
#  'fridges': 'place',
#  'fixtures plumbing': None,
#  'ceiling': 'place',
#  'Toilet': 'ambiance',
#  'hot water heaters': None,
#  'bed frame': 'food',
#  'light fixtures': None,
#  'lodging': 'food',
#  'rose': 'place',
#  'premises': 'food',
#  'TV Air conditioning': None,
#  'washrooms Water heater': None,
#  'ceiling lights Ceiling fan': None,
#  'Table': 'service',
#  'Fridge': 'food',
#  'towels Washroom mirror': None,
#  'garden view': 'food',
#  'outdoor': 'place',
#  'bright room': 'service',
#  'breakfast corect Personal': None,
#  'festival': 'ambiance',
#  'Price': 'place',
#  'friday': 'service',
#  'woman': 'ambiance',
#  'surrounding': 'ambiance',
#  'banku': 'service',
#  'outdoor activities': None,
#  'open air Restaurant': None,
#  'breakfast room service': None,
#  'range': 'ambiance',
#  'lunch break': 'ambiance',
#  'lodgings': 'food',
#  'mix': 'food',
#  'selection': 'service',
#  'GM': 'place',
#  'comfort rooms food': None,
#  'refuse': 'service',
#  'pool architecture': 'ambiance',
#  'chlorine': 'service',
#  'deejay': 'ambiance',
#  'ambience environment': 'place',
#  'grilled prawns': None,
#  'Amy': 'service',
#  'environment Staffs': 'food',
#  'espresso coffee': 'place',
#  'toilets': 'service',
#  'plastic': 'food',
#  'trip': 'food',
#  'choice': 'service',
#  'bathroom hot water': None,
#  'table tennis': 'food',
#  'beach volleyball': 'food',
#  'Coast Castle': 'place',
#  'room service Breakfast': None,
#  'hôtel': 'ambiance',
#  'bed and breakfast place': None,
#  'Parking space': 'food',
#  'breakfast Airconditioners': 'food',
#  'PLACE': 'place',
#  'location Service': 'service',
#  'coffee': 'place',
#  'Service personnel': 'ambiance',
#  'room rates': None,
#  'spot lights': None,
#  'juice': 'service',
#  'club sandwich': 'ambiance',
#  'section': 'place',
#  'parking area Pool table': None,
#  'staff Location': 'ambiance',
#  'Scenery': 'ambiance',
#  'zoo': 'ambiance',
#  'finishing': 'place',
#  'sinks': 'ambiance',
#  'plumbing system': 'place',
#  'ceilings': 'place',
#  'fixtures and fittings': None,
#  'stress': 'place',
#  'breezes': 'place',
#  'tilapia with pepper': None,
#  'event': 'service',
#  'swimming Tennis court': None,
#  'Experience': 'food',
#  'dishes Room': None,
#  'environment Club': 'ambiance',
#  'Family Boat': 'food',
#  'administration': 'ambiance',
#  'environmentsmiling': 'ambiance',
#  'eating area': 'food',
#  'lines': 'service',
#  'price service': 'ambiance',
#  'maps': 'ambiance',
#  'accommodation meals': None,
#  'hostilities': 'ambiance',
#  'location Staffs': 'ambiance',
#  'driving': 'place',
#  'transport': 'place',
#  'Home service': 'service',
#  'genset': 'ambiance',
#  'countryside': 'food',
#  'curtains': 'ambiance',
#  'cleaner': 'service',
#  'non alcoholic': 'place',
#  'outdoor nature': 'ambiance',
#  'taps': 'ambiance',
#  'food portions': None,
#  'phone': 'food',
#  'grid': 'ambiance',
#  'Tap': 'food',
#  'mattress Manager': 'food',
#  'organic food': 'ambiance',
#  'lemon grass tea': None,
#  'Hosts': 'food',
#  'grilled chicken with sautéed veggies': None,
#  'Government': 'service',
#  'days': 'food',
#  'fresh air': 'service',
#  'toilet space': 'place',
#  'hygiene': 'service',
#  'customer services': None,
#  'toilet sheets': None,
#  'hide out': None,
#  'getaway': 'place',
#  'foodsface _': 'place',
#  'canopy walkway': 'place',
#  'special meal': 'place',
#  'suite': 'food',
#  'mudfish': 'place',
#  'goat meal': 'ambiance',
#  'meat': 'food',
#  'corn drink': 'service',
#  'play area': 'ambiance',
#  'Okra stew': 'ambiance',
#  'baby': 'service',
#  'goat light soup': None,
#  'starter': 'ambiance',
#  'plain rice sauce': None,
#  'grilled pork': 'service',
#  'Guinea Fowls': 'place',
#  'ACCOMMODATION': 'place',
#  'animals': 'place',
#  'Food prices': None,
#  'outdoor gathering': 'food',
#  'ostrich': 'ambiance',
#  'protein': 'food',
#  'recreational place': 'ambiance',
#  'renovated': 'service',
#  'local dishes': None,
#  'custo': 'service',
#  'quiet': 'service',
#  'sleeping': 'service',
#  'stuff': 'service',
#  'noise': 'service',
#  'sound': 'service',
#  'sites': 'place',
#  'looks': 'food',
#  'Operational': 'food',
#  'water front view': None,
#  'lagoon': 'food',
#  'recreation': 'ambiance',
#  'vase space': 'ambiance',
#  'siren': 'ambiance',
#  'town': 'food',
#  'Personnel': 'service',
#  'buffet breakfast': 'food',
#  'anything': 'food',
#  'swiming pool': 'ambiance',
#  'place entertainment': 'place',
#  'Pool system': 'place',
#  'city': 'food',
#  'mobile network': 'ambiance',
#  'bulbs': 'place',
#  'grilled barracuda': 'place',
#  'reception area': 'food',
#  'fishing': 'food',
#  'Vibe': 'food',
#  'upgrades': 'ambiance',
#  'Chairs': 'place',
#  'Dish': 'food',
#  'concept': 'service',
#  'Annie': 'ambiance',
#  'environment location food rooms': None,
#  'vibes lunching': None,
#  'apartment': 'place',
#  'outdoor space': 'ambiance',
#  'recreational centers': None,
#  'layout': 'place',
#  'location service': 'service',
#  'front desk personnels': None,
#  'Ambiance': 'food',
#  'open access to the sea': None,
#  'water pump': 'ambiance',
#  'games': 'place',
#  'birds': 'food',
#  'numbers': 'food',
#  'Resort Spa': 'service',
#  'royal hideout': 'ambiance',
#  'property': 'service',
#  'resorts': 'food',
#  'security guys': None,
#  'beach bar pool': None,
#  'sun loungers': None,
#  'beach huts': None,
#  'spa treatment': 'service',
#  'hall mark': 'ambiance',
#  'seating': 'ambiance',
#  'pool by the beach': None,
#  'neet': 'ambiance',
#  'housing': 'ambiance',
#  'Affordable': 'place',
#  ...}
